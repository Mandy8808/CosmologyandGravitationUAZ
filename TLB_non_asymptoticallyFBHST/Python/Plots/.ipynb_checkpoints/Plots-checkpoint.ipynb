# %%
import numpy as np
import matplotlib.pyplot as plt

# modulos que están en la carpeta
import text_curv as tc  # para añadir texto curveado
import plt_conf as conf  # modulo de configuración de gráfico

from AngleAnnotation import AngleAnnotation
from matplotlib.patches import Circle

# %%
# cargando el módulo particular de las configuraciones

conf.general()  # cargando configuración general
#conf.latex()  # cargando conf para guardar en formato latex

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 5),
                       sharex=False, sharey=False,
                       gridspec_kw=dict(hspace=0, wspace=.4)) # espacio vertical y horizontal entre los subplots

# ejes
vert1 = [[0.1, 1.4, 0.3], [1, 0.6, 0.6]]  # [[x], [y]]

plt1, = ax[0].plot(vert1[0], vert1[1], ls='', marker='o', markersize=6, color='#757373')

# triangle in flat space
ax[0].annotate(r'', xy=(vert1[0][2], vert1[1][1]), xytext=(vert1[0][1], vert1[1][1]), 
            arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='--'),
            horizontalalignment='center', verticalalignment='center'
           )
ax[0].annotate(r'', xy=(vert1[0][1], vert1[1][1]), xytext=(vert1[0][0], vert1[1][0]), 
            arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='--'),
            horizontalalignment='center', verticalalignment='center'
           )
ax[0].annotate(r'', xy=(vert1[0][0], vert1[1][0]), xytext=(vert1[0][2], vert1[1][1]), 
            arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='--'),
            horizontalalignment='center', verticalalignment='center'
           )

# triangle in curved space
ax[0].annotate(r'', xy=(vert1[0][2], vert1[1][1]), xytext=(vert1[0][1], vert1[1][1]), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3,rad=-0.1"),
               horizontalalignment='center', verticalalignment='center'
               )
ax[0].annotate(r'', xy=(vert1[0][1], vert1[1][1]), xytext=(vert1[0][0], vert1[1][0]), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3,rad=-0.1"),
            horizontalalignment='center', verticalalignment='center'
           )
ax[0].annotate(r'', xy=(vert1[0][0], vert1[1][0]), xytext=(vert1[0][2], vert1[1][1]), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3, rad=-0.1"),
            horizontalalignment='center', verticalalignment='center'
           )

# tangentes
ax[0].annotate(r'', xy=(vert1[0][1]-0.01, vert1[1][1]-0.0), xytext=(vert1[0][1]+0.15, vert1[1][1]+0.015), 
               arrowprops=dict(arrowstyle="<|-", facecolor='black', lw=1.5, ls='-'),
            horizontalalignment='center', verticalalignment='center'
           )
ax[0].annotate(r'', xy=(vert1[0][1]-0.01, vert1[1][1]-0.0), xytext=(vert1[0][1]-0.1, vert1[1][1]+0.055), 
               arrowprops=dict(arrowstyle="<|-", facecolor='black', lw=1.5, ls='-'),
            horizontalalignment='center', verticalalignment='center'
           )

#####
ax[0].annotate(r'', xy=(vert1[0][0]+0.02, vert1[1][0]-0.005), xytext=(vert1[0][0]-0.15, vert1[1][0]+0.03), 
               arrowprops=dict(arrowstyle="<|-", facecolor='black', lw=1.5, ls='-'),
            horizontalalignment='center', verticalalignment='center'
           )
ax[0].annotate(r'', xy=(vert1[0][0], vert1[1][0]), xytext=(vert1[0][0]-0.03, vert1[1][0]-0.055), 
               arrowprops=dict(arrowstyle="<|-", facecolor='black', lw=1.5, ls='-'),
            horizontalalignment='center', verticalalignment='center'
           )

#####
ax[0].annotate(r'', xy=(vert1[0][2]-0.005, vert1[1][1]+0.005), xytext=(vert1[0][2]+0.065, vert1[1][1]-0.06), 
               arrowprops=dict(arrowstyle="<|-", facecolor='black', lw=1.5, ls='-'),
            horizontalalignment='center', verticalalignment='center'
           )
ax[0].annotate(r'', xy=(vert1[0][2], vert1[1][1]), xytext=(vert1[0][2]+0.2, vert1[1][1]-0.015), 
               arrowprops=dict(arrowstyle="<|-", facecolor='black', lw=1.5, ls='-'),
            horizontalalignment='center', verticalalignment='center'
           )

# angle
center = [(vert1[0][1], vert1[1][1]),
          (vert1[0][0], vert1[1][0]),
          (vert1[0][2], vert1[1][1])]
p1 = [(vert1[0][1]+0.15, vert1[1][1]+0.015),
      (vert1[0][0]-0.15, vert1[1][0]+0.03), 
      (vert1[0][2]+0.065, vert1[1][1]-0.06)]
p2 = [(vert1[0][1]-0.1, vert1[1][1]+0.055),
      (vert1[0][0]-0.03, vert1[1][0]-0.055),
      (vert1[0][2]+0.2, vert1[1][1]-0.015)]

AngleAnnotation(center[2], p1[2], p2[2], ax=ax[0], size=28, text=r"$\theta_1$",
                textposition="outside",
                text_kw=dict(fontsize=12, color="#0a0101")) 
AngleAnnotation(center[0], p1[0], p2[0], ax=ax[0], size=28, text=r"$\theta_2$",
                textposition="outside",
                text_kw=dict(fontsize=12, color="#0a0101")) 
AngleAnnotation(center[1], p1[1], p2[1], ax=ax[0], size=28, text=r"$\theta_3$",
                textposition="outside",
                text_kw=dict(fontsize=12, color="#0a0101")) 


#p = [(1.45, 1.02), (1.3, 1.), (1.45, 0.98)]
#ax[0].plot(*zip(*p))
#am5 = AngleAnnotation(p[1], p[0], p[2], ax=ax[0], size=28, text=r"$\theta_{p}$",
#                      linestyle="--", color="gray", textposition="outside")
                      # text_kw=dict(fontsize=12, color="gray")

# text
#ax[0].text(0.8, 0.55, r'$C_1$', fontsize=12)
#ax[0].text(0.85, 0.84, r'$C_2$', fontsize=12)
#ax[0].text(0, 0.75, r'$C_3$', fontsize=12)

ax[0].text(0, 0.51, r'Equatorial Plane', fontsize=12)

# limit
ax[0].set_ylim(0.5, 1.05)
ax[0].set_xlim(-0.1, 1.6)


plt2, = ax[0].plot([], [], ls='--', c='k')
plt3, = ax[0].plot([], [], ls='-', c='k')
ax[0].legend(loc=(0.4, 0.8), handles=[plt1, plt3, plt2], labels=[r'Detectors', 
                                                 r'$C_{p}^{(1)}$ geodesics',
                                                 r'$C_{p}^{(2)}$ geodesics'],
             frameon=False, fontsize=12, labelspacing=0.3, handlelength=1.2)

ax[0].axis('off')


# ejes
vert2 = [[0.1, 1.3, 1.4], [0.7, 1.4, 0.7]]  # [[x], [y]]

plt1, = ax[1].plot(vert2[0], vert2[1], ls='', marker='o', markersize=6, color='#757373')

# triangle in curved space
ax[1].annotate(r'', xy=(vert2[0][0], vert2[1][0]), xytext=(vert2[0][2], vert2[1][2]), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3,rad=0.1"),
               horizontalalignment='center', verticalalignment='center'
               )
ax[1].annotate(r'', xy=(vert2[0][2], vert2[1][2]), xytext=(vert2[0][1], vert2[1][1]), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3,rad=-0.1"),
            horizontalalignment='center', verticalalignment='center'
           )
ax[1].annotate(r'', xy=(vert2[0][1], vert2[1][1]), xytext=(vert2[0][0], vert2[1][0]), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3, rad=-0.2"),
            horizontalalignment='center', verticalalignment='center'
           )

### extensiones
ax[1].annotate(r'', xy=(vert2[0][0]+0.01, vert2[1][0]),  xytext=(vert2[0][0]-0.15, vert2[1][0]-0.03), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3,rad=-0.04"),
               horizontalalignment='center', verticalalignment='center'
               )

ax[1].annotate(r'', xy=(vert2[0][2]-0.01, vert2[1][2]), xytext=(vert2[0][2]+0.15, vert2[1][2]-0.03), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3,rad=-0.04"),
               horizontalalignment='center', verticalalignment='center'
               )

##
ax[1].annotate(r'', xy=(vert2[0][2], vert2[1][2]+0.01), xytext=(vert2[0][2]-0.08, vert2[1][2]-0.7), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="angle3, angleA=0.2, angleB=88"),
            horizontalalignment='center', verticalalignment='center'
           )

ax[1].annotate(r'', xy=(vert2[0][1], vert2[1][1]), xytext=(vert2[0][1]-0.1, vert2[1][1]+0.2), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3,rad=0"),
            horizontalalignment='center', verticalalignment='center'
           )
##
ax[1].annotate(r'', xy=(vert2[0][1], vert2[1][1]), xytext=(vert2[0][1]+0.15, vert2[1][1]+0.03), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3, rad=0.05"),
            horizontalalignment='center', verticalalignment='center'
           )
ax[1].annotate(r'', xy=(vert2[0][0], vert2[1][0]), xytext=(vert2[0][0]-0.15, vert2[1][0]-0.15), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3, rad=-0.07"),
            horizontalalignment='center', verticalalignment='center'
              )



# limit
ax[1].set_ylim(-0.1, 1.6)
ax[1].set_xlim(-0.1, 1.6)

# angle
center = [(vert2[0][0], vert2[1][0]),
          (vert2[0][2], vert2[1][2]),
          (vert2[0][1], vert2[1][1])]

p1 = [(vert2[0][0]+3.0, vert2[1][0]),
      (vert2[0][0]-3, vert2[1][0]+35), 
      (vert2[0][2]-2, vert2[1][1]-.5)]

p2 = [(vert2[0][0]+3., vert2[1][0]+4.5),
      (vert2[0][0]-3, vert2[1][0]+0.1),
      (vert2[0][2]+2, vert2[1][1]-4)]

AngleAnnotation(center[0], p1[0], p2[0], ax=ax[1], size=28, text=r"$\beta_1^{(1)}$",
                textposition="outside",
                text_kw=dict(fontsize=12, color="#0a0101")) 
AngleAnnotation(center[1], p1[1], p2[1], ax=ax[1], size=28, text=r"$\beta_2^{(1)}$",
                textposition="outside",
                text_kw=dict(fontsize=12, color="#0a0101")) 
AngleAnnotation(center[2], p1[2], p2[2], ax=ax[1], size=28, text=r"$\beta_3^{(1)}$",
                textposition="outside",
                text_kw=dict(fontsize=12, color="#0a0101")) 

# Source
x1, y1 = 0.75, 0.2
ax[1].plot([x1], [y1], 'bo', alpha=0.2)
el = Circle((x1, y1), radius=0.1, angle=0, alpha=0.2)
ax[1].add_artist(el)

# factor de impacto
fx1, fy1 = 0.85, 0.77
fx2, fy2 = 0.5, 1.12
fx3, fy3 = 1.4, 0.3
# ax[1].plot([fx1], [fy1], 'o')
# ax[1].plot([fx2], [fy2], 'o')
# ax[1].plot([fx3], [fy3], 'o')


ax[1].annotate(r'', xy=(fx1-0.1, fy1), xytext=(fx1+0.1, fy1-0.008), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )
ax[1].annotate(r'', xy=(x1, y1), xytext=(fx1, fy1), 
               arrowprops=dict(arrowstyle="<|-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )


ax[1].annotate(r'', xy=(fx2-0.1, fy2-0.08), xytext=(fx2+0.1, fy2+0.05), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )
ax[1].annotate(r'', xy=(x1, y1), xytext=(fx2, fy2), 
               arrowprops=dict(arrowstyle="<|-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )

ax[1].annotate(r'', xy=(fx3-0.01, fy3-0.08), xytext=(fx3+0.004, fy3+0.08), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )
ax[1].annotate(r'', xy=(x1, y1), xytext=(fx3, fy3), 
               arrowprops=dict(arrowstyle="<|-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )


# text
ax[1].text(0, 0.05, r'$\mathcal{M}^{(1)}_{\mathrm{opt}}$ space', fontsize=12)
ax[1].text(0, -0.05, r'Equatorial Plane', fontsize=12)

ax[1].text(-0.1, 0.73, r'$C_1^{(1)}$', fontsize=12)
ax[1].text(1.38, 1.47, r'$C_3^{(1)}$', fontsize=12)
ax[1].text(1.37, 0.05, r'$C_2^{(1)}$', fontsize=12)


ax[1].text(0.83, 0.45, r'$b_1^{(1)}$', fontsize=12)
ax[1].text(1., 0.3, r'$b_2^{(1)}$', fontsize=12)
ax[1].text(0.53, 0.47, r'$b_3^{(1)}$', fontsize=12)


plt2, = ax[0].plot([], [], ls='-', c='k')
plt3, = ax[0].plot([], [], ls=':', c='k')
ax[1].legend(loc='upper left', handles=[plt1, plt3, plt2], labels=[r'Detectors',
                                                 r' $b_{p}^{(1)}$ impact parameters',
                                                 r'$C_{p}^{(1)}$ geodesics'],
             frameon=False, fontsize=12, labelspacing=0.3, handlelength=1.2)


ax[1].annotate(r'$x$', xy=(x1, y1), xytext=(x1+0.9, y1), 
               arrowprops=dict(arrowstyle="<-", facecolor='black', lw=1., ls='-.',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )

ax[1].axis('off')
# Out:
# /var/folders/mz/hm7z81f16nj6xj1h62y1k9zm0000gn/T/ipykernel_12984/3140233562.py:1: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 5),
# (-0.1, 1.6, -0.1, 1.6)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 5),
                       sharex=False, sharey=False,
                       gridspec_kw=dict(hspace=0, wspace=.4)) # espacio vertical y horizontal entre los subplots

# ejes
vert1 = [[0.1, 1.4, 0.3], [1, 0.6, 0.6]]  # [[x], [y]]

plt1, = ax[0].plot(vert1[0], vert1[1], ls='', marker='o', markersize=6, color='#757373')

# triangle in flat space
ax[0].annotate(r'', xy=(vert1[0][2], vert1[1][1]), xytext=(vert1[0][1], vert1[1][1]), 
            arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='--'),
            horizontalalignment='center', verticalalignment='center'
           )
ax[0].annotate(r'', xy=(vert1[0][1], vert1[1][1]), xytext=(vert1[0][0], vert1[1][0]), 
            arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='--'),
            horizontalalignment='center', verticalalignment='center'
           )
ax[0].annotate(r'', xy=(vert1[0][0], vert1[1][0]), xytext=(vert1[0][2], vert1[1][1]), 
            arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='--'),
            horizontalalignment='center', verticalalignment='center'
           )

# triangle in curved space
ax[0].annotate(r'', xy=(vert1[0][2], vert1[1][1]), xytext=(vert1[0][1], vert1[1][1]), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3,rad=-0.1"),
               horizontalalignment='center', verticalalignment='center'
               )
ax[0].annotate(r'', xy=(vert1[0][1], vert1[1][1]), xytext=(vert1[0][0], vert1[1][0]), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3,rad=-0.1"),
            horizontalalignment='center', verticalalignment='center'
           )
ax[0].annotate(r'', xy=(vert1[0][0], vert1[1][0]), xytext=(vert1[0][2], vert1[1][1]), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3, rad=-0.1"),
            horizontalalignment='center', verticalalignment='center'
           )

# tangentes
ax[0].annotate(r'', xy=(vert1[0][1]-0.01, vert1[1][1]-0.0), xytext=(vert1[0][1]+0.15, vert1[1][1]+0.015), 
               arrowprops=dict(arrowstyle="<|-", facecolor='black', lw=1.5, ls='-'),
            horizontalalignment='center', verticalalignment='center'
           )
ax[0].annotate(r'', xy=(vert1[0][1]-0.01, vert1[1][1]-0.0), xytext=(vert1[0][1]-0.1, vert1[1][1]+0.055), 
               arrowprops=dict(arrowstyle="<|-", facecolor='black', lw=1.5, ls='-'),
            horizontalalignment='center', verticalalignment='center'
           )

#####
ax[0].annotate(r'', xy=(vert1[0][0]+0.02, vert1[1][0]-0.005), xytext=(vert1[0][0]-0.15, vert1[1][0]+0.03), 
               arrowprops=dict(arrowstyle="<|-", facecolor='black', lw=1.5, ls='-'),
            horizontalalignment='center', verticalalignment='center'
           )
ax[0].annotate(r'', xy=(vert1[0][0], vert1[1][0]), xytext=(vert1[0][0]-0.03, vert1[1][0]-0.055), 
               arrowprops=dict(arrowstyle="<|-", facecolor='black', lw=1.5, ls='-'),
            horizontalalignment='center', verticalalignment='center'
           )

#####
ax[0].annotate(r'', xy=(vert1[0][2]-0.005, vert1[1][1]+0.005), xytext=(vert1[0][2]+0.065, vert1[1][1]-0.06), 
               arrowprops=dict(arrowstyle="<|-", facecolor='black', lw=1.5, ls='-'),
            horizontalalignment='center', verticalalignment='center'
           )
ax[0].annotate(r'', xy=(vert1[0][2], vert1[1][1]), xytext=(vert1[0][2]+0.2, vert1[1][1]-0.015), 
               arrowprops=dict(arrowstyle="<|-", facecolor='black', lw=1.5, ls='-'),
            horizontalalignment='center', verticalalignment='center'
           )

# angle
center = [(vert1[0][1], vert1[1][1]),
          (vert1[0][0], vert1[1][0]),
          (vert1[0][2], vert1[1][1])]
p1 = [(vert1[0][1]+0.15, vert1[1][1]+0.015),
      (vert1[0][0]-0.15, vert1[1][0]+0.03), 
      (vert1[0][2]+0.065, vert1[1][1]-0.06)]
p2 = [(vert1[0][1]-0.1, vert1[1][1]+0.055),
      (vert1[0][0]-0.03, vert1[1][0]-0.055),
      (vert1[0][2]+0.2, vert1[1][1]-0.015)]

AngleAnnotation(center[2], p1[2], p2[2], ax=ax[0], size=28, text=r"$\theta_1$",
                textposition="outside",
                text_kw=dict(fontsize=12, color="#0a0101")) 
AngleAnnotation(center[0], p1[0], p2[0], ax=ax[0], size=28, text=r"$\theta_2$",
                textposition="outside",
                text_kw=dict(fontsize=12, color="#0a0101")) 
AngleAnnotation(center[1], p1[1], p2[1], ax=ax[0], size=28, text=r"$\theta_3$",
                textposition="outside",
                text_kw=dict(fontsize=12, color="#0a0101")) 


#p = [(1.45, 1.02), (1.3, 1.), (1.45, 0.98)]
#ax[0].plot(*zip(*p))
#am5 = AngleAnnotation(p[1], p[0], p[2], ax=ax[0], size=28, text=r"$\theta_{p}$",
#                      linestyle="--", color="gray", textposition="outside")
                      # text_kw=dict(fontsize=12, color="gray")

# text
#ax[0].text(0.8, 0.55, r'$C_1$', fontsize=12)
#ax[0].text(0.85, 0.84, r'$C_2$', fontsize=12)
#ax[0].text(0, 0.75, r'$C_3$', fontsize=12)

ax[0].text(0, 0.51, r'Equatorial Plane', fontsize=12)

# limit
ax[0].set_ylim(0.5, 1.05)
ax[0].set_xlim(-0.1, 1.6)


plt2, = ax[0].plot([], [], ls='--', c='k')
plt3, = ax[0].plot([], [], ls='-', c='k')
ax[0].legend(loc=(0.4, 0.8), handles=[plt1, plt3, plt2], labels=[r'Vertex', 
                                                 r'$C_{p}^{(1)}$ geodesics',
                                                 r'$C_{p}^{(2)}$ geodesics'],
             frameon=False, fontsize=12, labelspacing=0.3, handlelength=1.2)

ax[0].axis('off')


# ejes
vert2 = [[0.1, 1.3, 1.4], [0.7, 1.4, 0.7]]  # [[x], [y]]

plt1, = ax[1].plot(vert2[0], vert2[1], ls='', marker='o', markersize=6, color='#757373')

# triangle in curved space
ax[1].annotate(r'', xy=(vert2[0][0], vert2[1][0]), xytext=(vert2[0][2], vert2[1][2]), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3,rad=0.1"),
               horizontalalignment='center', verticalalignment='center'
               )
ax[1].annotate(r'', xy=(vert2[0][2], vert2[1][2]), xytext=(vert2[0][1], vert2[1][1]), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3,rad=-0.1"),
            horizontalalignment='center', verticalalignment='center'
           )
ax[1].annotate(r'', xy=(vert2[0][1], vert2[1][1]), xytext=(vert2[0][0], vert2[1][0]), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3, rad=-0.2"),
            horizontalalignment='center', verticalalignment='center'
           )

### extensiones
ax[1].annotate(r'', xy=(vert2[0][0]+0.01, vert2[1][0]),  xytext=(vert2[0][0]-0.15, vert2[1][0]-0.03), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3,rad=-0.04"),
               horizontalalignment='center', verticalalignment='center'
               )

ax[1].annotate(r'', xy=(vert2[0][2]-0.01, vert2[1][2]), xytext=(vert2[0][2]+0.15, vert2[1][2]-0.03), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3,rad=-0.04"),
               horizontalalignment='center', verticalalignment='center'
               )

##
ax[1].annotate(r'', xy=(vert2[0][2], vert2[1][2]+0.01), xytext=(vert2[0][2]-0.08, vert2[1][2]-0.7), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="angle3, angleA=0.2, angleB=88"),
            horizontalalignment='center', verticalalignment='center'
           )

ax[1].annotate(r'', xy=(vert2[0][1], vert2[1][1]), xytext=(vert2[0][1]-0.1, vert2[1][1]+0.2), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3,rad=0"),
            horizontalalignment='center', verticalalignment='center'
           )
##
ax[1].annotate(r'', xy=(vert2[0][1], vert2[1][1]), xytext=(vert2[0][1]+0.15, vert2[1][1]+0.03), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3, rad=0.05"),
            horizontalalignment='center', verticalalignment='center'
           )
ax[1].annotate(r'', xy=(vert2[0][0], vert2[1][0]), xytext=(vert2[0][0]-0.15, vert2[1][0]-0.15), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3, rad=-0.07"),
            horizontalalignment='center', verticalalignment='center'
              )



# limit
ax[1].set_ylim(-0.1, 1.6)
ax[1].set_xlim(-0.1, 1.6)

# angle
center = [(vert2[0][0], vert2[1][0]),
          (vert2[0][2], vert2[1][2]),
          (vert2[0][1], vert2[1][1])]

p1 = [(vert2[0][0]+3.0, vert2[1][0]),
      (vert2[0][0]-3, vert2[1][0]+35), 
      (vert2[0][2]-2, vert2[1][1]-.5)]

p2 = [(vert2[0][0]+3., vert2[1][0]+4.5),
      (vert2[0][0]-3, vert2[1][0]+0.1),
      (vert2[0][2]+2, vert2[1][1]-4)]

AngleAnnotation(center[0], p1[0], p2[0], ax=ax[1], size=28, text=r"$\beta_1$",
                textposition="outside",
                text_kw=dict(fontsize=12, color="#0a0101")) 
AngleAnnotation(center[1], p1[1], p2[1], ax=ax[1], size=28, text=r"$\beta_2$",
                textposition="outside",
                text_kw=dict(fontsize=12, color="#0a0101")) 
AngleAnnotation(center[2], p1[2], p2[2], ax=ax[1], size=28, text=r"$\beta_3$",
                textposition="outside",
                text_kw=dict(fontsize=12, color="#0a0101")) 

# Source
x1, y1 = 0.75, 0.2
ax[1].plot([x1], [y1], 'bo', alpha=0.2)
el = Circle((x1, y1), radius=0.1, angle=0, alpha=0.2)
ax[1].add_artist(el)

# factor de impacto
fx1, fy1 = 0.85, 0.77
fx2, fy2 = 0.5, 1.12
fx3, fy3 = 1.4, 0.3
# ax[1].plot([fx1], [fy1], 'o')
# ax[1].plot([fx2], [fy2], 'o')
# ax[1].plot([fx3], [fy3], 'o')


ax[1].annotate(r'', xy=(fx1-0.1, fy1), xytext=(fx1+0.1, fy1-0.008), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )
ax[1].annotate(r'', xy=(x1, y1), xytext=(fx1, fy1), 
               arrowprops=dict(arrowstyle="<|-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )


ax[1].annotate(r'', xy=(fx2-0.1, fy2-0.08), xytext=(fx2+0.1, fy2+0.05), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )
ax[1].annotate(r'', xy=(x1, y1), xytext=(fx2, fy2), 
               arrowprops=dict(arrowstyle="<|-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )

ax[1].annotate(r'', xy=(fx3-0.01, fy3-0.08), xytext=(fx3+0.004, fy3+0.08), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )
ax[1].annotate(r'', xy=(x1, y1), xytext=(fx3, fy3), 
               arrowprops=dict(arrowstyle="<|-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )


# text
ax[1].text(0, 0.05, r'$\mathcal{M}_{\mathrm{opt}}$ space', fontsize=12)
ax[1].text(0, -0.05, r'Equatorial Plane', fontsize=12)

ax[1].text(-0.1, 0.73, r'$C_1$', fontsize=12)
ax[1].text(1.38, 1.47, r'$C_3$', fontsize=12)
ax[1].text(1.37, 0.05, r'$C_2$', fontsize=12)


ax[1].text(0.83, 0.45, r'$b_1$', fontsize=12)
ax[1].text(1., 0.3, r'$b_2$', fontsize=12)
ax[1].text(0.53, 0.47, r'$b_3$', fontsize=12)


plt2, = ax[0].plot([], [], ls='-', c='k')
plt3, = ax[0].plot([], [], ls=':', c='k')
ax[1].legend(loc='upper left', handles=[plt1, plt3, plt2], labels=[r'Vertex',
                                                 r' $b_{p}$ impact parameters',
                                                 r'$C_{p}$ geodesics'],
             frameon=False, fontsize=12, labelspacing=0.3, handlelength=1.2)


ax[1].annotate(r'$x$', xy=(x1, y1), xytext=(x1+0.9, y1), 
               arrowprops=dict(arrowstyle="<-", facecolor='black', lw=1., ls='-.',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )

ax[1].axis('off')
# Out:
# /var/folders/mz/hm7z81f16nj6xj1h62y1k9zm0000gn/T/ipykernel_8047/3399207869.py:1: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 5),
# (-0.1, 1.6, -0.1, 1.6)

# %%
fig.savefig('Esquemas.pdf', format='pdf', metadata=None, # dpi='figure',
        pad_inches=0.1,
        facecolor='auto', edgecolor='auto',
        backend=None, dpi=1000, 
        bbox_inches='tight'# Plot will be occupy a maximum of available space # bbox_inches=None,
       )

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 5),
                       sharex=False, sharey=False,
                       gridspec_kw=dict(hspace=0, wspace=.4)) # espacio vertical y horizontal entre los subplots



# Source
x1, y1 = 0.65, 0.1
ax[0].plot([x1], [y1], 'bo', alpha=0.2)
el = Circle((x1, y1), radius=0.08, angle=0, alpha=0.2)
ax[0].add_artist(el)

# axe
ax[0].annotate(r'$x$', xy=(x1, y1), xytext=(x1+0.4, y1), 
               arrowprops=dict(arrowstyle="<-", facecolor='black', lw=1., ls='-.',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )

# geodesic
ax[0].annotate(r'', xy=(0.75, 1.), xytext=(1.6, 0.1), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3, rad=0.15"),
               horizontalalignment='center', verticalalignment='center'
               )

# impact parameter
xb, yb = 1.23, 0.55
ax[0].annotate(r'', xy=(xb+0.1, yb), xytext=(xb, yb+0.1), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )
ax[0].annotate(r'', xy=(x1, y1), xytext=(xb+0.05, yb+0.05), 
               arrowprops=dict(arrowstyle="<|-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )
# angle
x3, y3 = 0.85, 0.1
ax[0].annotate(r'', xy=(x3+0.01, y3-0.01), xytext=(x3-0.06, y3+0.12), 
               arrowprops=dict(arrowstyle="<-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3, rad=-0.3"),
            horizontalalignment='center', verticalalignment='center'
              )


ax[0].text(.6, 0.6, r'Equatorial Plane', fontsize=12)
ax[0].text(.87, .17, r'$\phi=\pi/2+\delta_p$', fontsize=14)

ax[0].set_ylim(0., 1)
ax[0].set_xlim(0.5, 1.6)

ax[0].text(.72, 0.9, r'$C_{p}^{(I)}$', fontsize=12)
ax[0].text(.92, 0.38, r'$b_{p}^{(I)}$', fontsize=12)


# ejes
vert2 = [[0.91, 1.55], [0.9, 0.2]]  # [[x], [y]]
plt1, = ax[0].plot(vert2[0], vert2[1], ls='', marker='o', markersize=6, color='#757373')

plt2, = ax[0].plot([], [], ls=':', c='k')
plt3, = ax[0].plot([], [], ls='-', c='k')
ax[0].legend(loc=(0.52, 0.79), handles=[plt1, plt2, plt3], labels=[r'Detectors',
                                                 r'$b_{p}^{(I)}$ impact parameters',
                                                 r'$C_{p}^{(I)}$ geodesics'],
             frameon=False, fontsize=12, labelspacing=0.3, handlelength=1.2)


ax[0].axis('off')



##################
# ejes
vert2 = [[0.1, .75, 1.4], [0.7, 1.4, 0.7]]  # [[x], [y]]

plt1, = ax[1].plot(vert2[0], vert2[1], ls='', marker='o', markersize=6, color='#757373')

# triangle in curved space
ax[1].annotate(r'', xy=(vert2[0][0], vert2[1][0]), xytext=(vert2[0][2], vert2[1][2]), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3,rad=0.1"),
               horizontalalignment='center', verticalalignment='center'
               )
ax[1].annotate(r'', xy=(vert2[0][2], vert2[1][2]), xytext=(vert2[0][1], vert2[1][1]), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3,rad=-0.1"),
            horizontalalignment='center', verticalalignment='center'
           )
ax[1].annotate(r'', xy=(vert2[0][1], vert2[1][1]), xytext=(vert2[0][0], vert2[1][0]), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3, rad=-0.1"),
            horizontalalignment='center', verticalalignment='center'
           )

### extensiones
ax[1].annotate(r'', xy=(vert2[0][0]+0.01, vert2[1][0]),  xytext=(vert2[0][0]-0.15, vert2[1][0]-0.03), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3,rad=-0.04"),
               horizontalalignment='center', verticalalignment='center'
               )

ax[1].annotate(r'', xy=(vert2[0][2]-0.01, vert2[1][2]), xytext=(vert2[0][2]+0.15, vert2[1][2]-0.03), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3,rad=-0.04"),
               horizontalalignment='center', verticalalignment='center'
               )

##
ax[1].annotate(r'', xy=(vert2[0][2], vert2[1][2]), xytext=(vert2[0][2]+0.08, vert2[1][2]-0.15), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3, rad=0.05"),
            horizontalalignment='center', verticalalignment='center'
           )

ax[1].annotate(r'', xy=(vert2[0][1], vert2[1][1]), xytext=(vert2[0][1]-0.1, vert2[1][1]+0.08), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3,rad=0"),
            horizontalalignment='center', verticalalignment='center'
           )


##
ax[1].annotate(r'', xy=(vert2[0][1], vert2[1][1]), xytext=(vert2[0][1]+0.12, vert2[1][1]+0.08), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3, rad=0.05"),
            horizontalalignment='center', verticalalignment='center'
           )
ax[1].annotate(r'', xy=(vert2[0][0], vert2[1][0]), xytext=(vert2[0][0]-0.08, vert2[1][0]-0.13), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3, rad=-0.07"),
            horizontalalignment='center', verticalalignment='center'
              )


# limit
ax[1].set_ylim(-0.1, 1.6)
ax[1].set_xlim(-0.1, 1.6)

# Source
x1, y1 = 0.75, 0.2
ax[1].plot([x1], [y1], 'bo', alpha=0.2)
el = Circle((x1, y1), radius=0.1, angle=0, alpha=0.2)
ax[1].add_artist(el)

# factor de impacto
fx1, fy1 = 0.85, 0.77
fx2, fy2 = 0.5, 1.12
fx3, fy3 = 1.4, 0.3

ax[1].annotate(r'', xy=(x1-0.1, fy1), xytext=(x1+0.1, fy1), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )
ax[1].annotate(r'', xy=(x1, y1), xytext=(x1, fy1), 
               arrowprops=dict(arrowstyle="<|-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )
ax[1].text(x1+0.03, 0.57, r'$b_1^{(1)}$', fontsize=12)
ax[1].text(x1-0.14, fy1+0.05, r'$\phi=\pi/2$', fontsize=12)

ax[1].annotate(r'', xy=(1.06, 1.17), xytext=(1.22, .99), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )
ax[1].annotate(r'', xy=(x1, y1), xytext=(1.15, 1.09), 
               arrowprops=dict(arrowstyle="<|-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )
ax[1].text(.93, 0.45, r'$b_2^{(1)}$', fontsize=12)
ax[1].text(1.02, .97, r'$\phi=\pi/2-\delta$', fontsize=12, rotation=-50)

ax[1].annotate(r'', xy=(0.28, .99), xytext=(0.44, 1.17), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )
ax[1].annotate(r'', xy=(x1, y1), xytext=(0.36, 1.1), 
               arrowprops=dict(arrowstyle="<|-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )
ax[1].text(.45, 0.45, r'$b_3^{(1)}$', fontsize=12)
ax[1].text(.14, .97, r'$\phi=\pi/2+\delta$', fontsize=12, rotation=50)

# text
ax[1].text(0, 0.05, r'$\mathcal{M}^{(1)}_{\mathrm{opt}}$ space', fontsize=12)
ax[1].text(0, -0.05, r'Equatorial Plane', fontsize=12)


ax[1].annotate(r'$x$', xy=(x1, y1), xytext=(x1+0.9, y1), 
               arrowprops=dict(arrowstyle="<-", facecolor='black', lw=1., ls='-.',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )


ax[1].text(vert2[0][0]-0.55, vert2[1][0]-0.1, r'$\pi-\phi_0=\phi_1$', fontsize=12, rotation=1,
           transform_rotates_text=True)
ax[1].text(vert2[0][2]+0.1, vert2[1][2]-0.1, r'$\phi_2=\phi_0$', fontsize=12, rotation=-1,
          transform_rotates_text=True)
ax[1].text(vert2[0][1]-0.15, vert2[1][1]+0.12, r'$\phi_3=\pi/2$', fontsize=12, rotation=0)

# angle
x3, y3 = 0.75, 0.2
ax[1].annotate(r'', xy=(x3+0.14, y3-0.01), xytext=(x3-0.15, y3+0.05), 
               arrowprops=dict(arrowstyle="<-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3, rad=-0.8"),
            horizontalalignment='center', verticalalignment='center'
              )
ax[1].text(x3-0.2, y3, r'$\phi$', fontsize=15)

ax[1].text(-0.05, 0.73, r'$C_1^{(1)}$', fontsize=12)
ax[1].text(.85, 1.42, r'$C_3^{(1)}$', fontsize=12)
ax[1].text(1.41, 0.48, r'$C_2^{(1)}$', fontsize=12)

ax[1].axis('off')

plt2, = ax[1].plot([], [], ls='-', c='k')
plt3, = ax[1].plot([], [], ls=':', c='k')
ax[1].legend(loc=(0.75, 0.8), handles=[plt1, plt3, plt2], labels=[r'Detectors',
                                                 r' $b_{p}^{(1)}$ impact parameters',
                                                 r'$C_{p}^{(1)}$ geodesics'],
             frameon=False, fontsize=12, labelspacing=0.3, handlelength=1.2)
# Out:
# /var/folders/mz/hm7z81f16nj6xj1h62y1k9zm0000gn/T/ipykernel_12984/1343741694.py:1: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 5),

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 5),
                       sharex=False, sharey=False,
                       gridspec_kw=dict(hspace=0, wspace=.4)) # espacio vertical y horizontal entre los subplots



# Source
x1, y1 = 0.65, 0.1
ax[0].plot([x1], [y1], 'bo', alpha=0.2)
el = Circle((x1, y1), radius=0.08, angle=0, alpha=0.2)
ax[0].add_artist(el)

# axe
ax[0].annotate(r'$x$', xy=(x1, y1), xytext=(x1+0.4, y1), 
               arrowprops=dict(arrowstyle="<-", facecolor='black', lw=1., ls='-.',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )

# geodesic
ax[0].annotate(r'', xy=(0.75, 1.), xytext=(1.6, 0.1), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3, rad=0.15"),
               horizontalalignment='center', verticalalignment='center'
               )

# impact parameter
xb, yb = 1.23, 0.55
ax[0].annotate(r'', xy=(xb+0.1, yb), xytext=(xb, yb+0.1), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )
ax[0].annotate(r'', xy=(x1, y1), xytext=(xb+0.05, yb+0.05), 
               arrowprops=dict(arrowstyle="<|-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )
# angle
x3, y3 = 0.85, 0.1
ax[0].annotate(r'', xy=(x3+0.01, y3-0.01), xytext=(x3-0.06, y3+0.12), 
               arrowprops=dict(arrowstyle="<-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3, rad=-0.3"),
            horizontalalignment='center', verticalalignment='center'
              )


ax[0].text(.6, 0.6, r'Equatorial Plane', fontsize=12)
ax[0].text(.87, .17, r'$\phi_{b_{p}}=\pi/2+\delta_p$', fontsize=14)

ax[0].set_ylim(0., 1)
ax[0].set_xlim(0.5, 1.6)

ax[0].text(.72, 0.9, r'$C_{p}$', fontsize=12)
ax[0].text(.92, 0.38, r'$b_{p}$', fontsize=12)


# ejes
vert2 = [[0.91, 1.55], [0.9, 0.2]]  # [[x], [y]]
plt1, = ax[0].plot(vert2[0], vert2[1], ls='', marker='o', markersize=6, color='#757373')

plt2, = ax[0].plot([], [], ls=':', c='k')
plt3, = ax[0].plot([], [], ls='-', c='k')
ax[0].legend(loc=(0.52, 0.79), handles=[plt1, plt2, plt3], labels=[r'Vertex',
                                                 r'$b_{p}$ impact parameters',
                                                 r'$C_{p}$ geodesics'],
             frameon=False, fontsize=12, labelspacing=0.3, handlelength=1.2)


ax[0].axis('off')



##################
# ejes
vert2 = [[0.1, .75, 1.4], [0.7, 1.4, 0.7]]  # [[x], [y]]

plt1, = ax[1].plot(vert2[0], vert2[1], ls='', marker='o', markersize=6, color='#757373')

# triangle in curved space
ax[1].annotate(r'', xy=(vert2[0][0], vert2[1][0]), xytext=(vert2[0][2], vert2[1][2]), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3,rad=0.1"),
               horizontalalignment='center', verticalalignment='center'
               )
ax[1].annotate(r'', xy=(vert2[0][2], vert2[1][2]), xytext=(vert2[0][1], vert2[1][1]), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3,rad=-0.1"),
            horizontalalignment='center', verticalalignment='center'
           )
ax[1].annotate(r'', xy=(vert2[0][1], vert2[1][1]), xytext=(vert2[0][0], vert2[1][0]), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3, rad=-0.1"),
            horizontalalignment='center', verticalalignment='center'
           )

### extensiones
ax[1].annotate(r'', xy=(vert2[0][0]+0.01, vert2[1][0]),  xytext=(vert2[0][0]-0.15, vert2[1][0]-0.03), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3,rad=-0.04"),
               horizontalalignment='center', verticalalignment='center'
               )

ax[1].annotate(r'', xy=(vert2[0][2]-0.01, vert2[1][2]), xytext=(vert2[0][2]+0.15, vert2[1][2]-0.03), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3,rad=-0.04"),
               horizontalalignment='center', verticalalignment='center'
               )

##
ax[1].annotate(r'', xy=(vert2[0][2], vert2[1][2]), xytext=(vert2[0][2]+0.08, vert2[1][2]-0.15), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3, rad=0.05"),
            horizontalalignment='center', verticalalignment='center'
           )

ax[1].annotate(r'', xy=(vert2[0][1], vert2[1][1]), xytext=(vert2[0][1]-0.1, vert2[1][1]+0.08), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3,rad=0"),
            horizontalalignment='center', verticalalignment='center'
           )


##
ax[1].annotate(r'', xy=(vert2[0][1], vert2[1][1]), xytext=(vert2[0][1]+0.12, vert2[1][1]+0.08), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3, rad=0.05"),
            horizontalalignment='center', verticalalignment='center'
           )
ax[1].annotate(r'', xy=(vert2[0][0], vert2[1][0]), xytext=(vert2[0][0]-0.08, vert2[1][0]-0.13), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3, rad=-0.07"),
            horizontalalignment='center', verticalalignment='center'
              )


# limit
ax[1].set_ylim(-0.1, 1.6)
ax[1].set_xlim(-0.1, 1.6)

# Source
x1, y1 = 0.75, 0.2
ax[1].plot([x1], [y1], 'bo', alpha=0.2)
el = Circle((x1, y1), radius=0.1, angle=0, alpha=0.2)
ax[1].add_artist(el)

# factor de impacto
fx1, fy1 = 0.85, 0.77
fx2, fy2 = 0.5, 1.12
fx3, fy3 = 1.4, 0.3

ax[1].annotate(r'', xy=(x1-0.1, fy1), xytext=(x1+0.1, fy1), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )
ax[1].annotate(r'', xy=(x1, y1), xytext=(x1, fy1), 
               arrowprops=dict(arrowstyle="<|-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )
ax[1].text(x1+0.03, 0.57, r'$b_1$', fontsize=12)
ax[1].text(x1-0.14, fy1+0.05, r'$\phi_{b_1}=\pi/2$', fontsize=12)

ax[1].annotate(r'', xy=(1.06, 1.17), xytext=(1.22, .99), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )
ax[1].annotate(r'', xy=(x1, y1), xytext=(1.15, 1.09), 
               arrowprops=dict(arrowstyle="<|-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )
ax[1].text(.93, 0.45, r'$b_2$', fontsize=12)
ax[1].text(1.02, .97, r'$\phi_{b_2}=\pi/2-\delta$', fontsize=12, rotation=-50)

ax[1].annotate(r'', xy=(0.28, .99), xytext=(0.44, 1.17), 
               arrowprops=dict(arrowstyle="-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )
ax[1].annotate(r'', xy=(x1, y1), xytext=(0.36, 1.1), 
               arrowprops=dict(arrowstyle="<|-", facecolor='black', lw=1.5, ls=':',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )
ax[1].text(.45, 0.45, r'$b_3$', fontsize=12)
ax[1].text(.14, .97, r'$\phi_{b_3}=\pi/2+\delta$', fontsize=12, rotation=50)

# text
ax[1].text(0, 0.05, r'$\mathcal{M}_{\mathrm{opt}}$ space', fontsize=12)
ax[1].text(0, -0.05, r'Equatorial Plane', fontsize=12)


ax[1].annotate(r'$x$', xy=(x1, y1), xytext=(x1+0.9, y1), 
               arrowprops=dict(arrowstyle="<-", facecolor='black', lw=1., ls='-.',
                              connectionstyle="arc3, rad=0"),
            horizontalalignment='center', verticalalignment='center'
              )


ax[1].text(vert2[0][0]-0.6, vert2[1][0]-0.1, r'$\pi-\phi_{\mathrm{Min}}=\phi_1$', fontsize=12, rotation=1,
           transform_rotates_text=True)
ax[1].text(vert2[0][2]+0.1, vert2[1][2]-0.1, r'$\phi_2=\phi_{\mathrm{Min}}$', fontsize=12, rotation=-1,
          transform_rotates_text=True)
ax[1].text(vert2[0][1]-0.15, vert2[1][1]+0.12, r'$\phi_3=\pi/2$', fontsize=12, rotation=0)

# angle
x3, y3 = 0.75, 0.2
ax[1].annotate(r'', xy=(x3+0.14, y3-0.01), xytext=(x3-0.15, y3+0.05), 
               arrowprops=dict(arrowstyle="<-", facecolor='black', lw=1.5, ls='-',
                              connectionstyle="arc3, rad=-0.8"),
            horizontalalignment='center', verticalalignment='center'
              )
ax[1].text(x3-0.2, y3, r'$\phi$', fontsize=15)

ax[1].text(-0.05, 0.73, r'$C_1$', fontsize=12)
ax[1].text(.85, 1.42, r'$C_3$', fontsize=12)
ax[1].text(1.41, 0.48, r'$C_2$', fontsize=12)

ax[1].axis('off')

plt2, = ax[1].plot([], [], ls='-', c='k')
plt3, = ax[1].plot([], [], ls=':', c='k')
ax[1].legend(loc=(0.75, 0.8), handles=[plt1, plt3, plt2], labels=[r'Vertex',
                                                 r' $b_{p}$ impact parameters',
                                                 r'$C_{p}$ geodesics'],
             frameon=False, fontsize=12, labelspacing=0.3, handlelength=1.2)
# Out:
# /var/folders/mz/hm7z81f16nj6xj1h62y1k9zm0000gn/T/ipykernel_8047/3575521645.py:1: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 5),

# %%
fig.savefig('Esquemas2.pdf', format='pdf', metadata=None, # dpi='figure',
        pad_inches=0.1,
        facecolor='auto', edgecolor='auto',
        backend=None, dpi=1000, 
        bbox_inches='tight'# Plot will be occupy a maximum of available space # bbox_inches=None,
       )
