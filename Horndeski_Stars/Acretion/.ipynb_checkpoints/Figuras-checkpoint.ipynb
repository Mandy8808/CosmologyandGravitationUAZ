# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as font_manager
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
#from matplotlib.patches import Rectangle

from cycler import cycler

# %%
# estructura para latex
#mpl.use("pgf")

# estilo de linea y grosor
mpl.rcParams['lines.linestyle'] = '-'
mpl.rcParams['lines.linewidth'] = 2.

# orden de los colores que usará
mpl.rcParams['axes.prop_cycle'] = cycler('color', ['#1f77b4', '#ff7f0e', '#2ca02c', 
                                                   '#d62728', '#9467bd', '#8c564b', '#e377c2', 
                                                   '#7f7f7f', '#bcbd22', '#17becf'])
#cycler(color=['r', 'g', 'b', 'y'])

# latex modo math
mpl.rcParams['mathtext.fontset'] = 'cm'  # Should be 'dejavusans' (default),
                                         # 'dejavuserif', 'cm' (Computer Modern), 'stix',
                                         # 'stixsans' or 'custom'
        
mpl.rcParams['mathtext.fallback_to_cm']= True # When True, use symbols from the Computer Modern
                                              # fonts when a symbol can not be found in one of
                                              # the custom math fonts.
    
# Texto
mpl.rcParams['font.family'] = 'serif' # serif, sans-serif, cursive, fantasy, monospace
cmfont = font_manager.FontProperties(fname=mpl.get_data_path() + '/fonts/ttf/cmr10.ttf')
mpl.rcParams['font.serif']=cmfont.get_name()
mpl.rcParams['font.size'] = 16 # tamaño de la letra

###
#mpl.rcParams['pgf.texsystem'] = 'pdflatex'
mpl.rcParams['text.usetex'] = True
mpl.rcParams['pgf.rcfonts'] = False
mpl.rcParams['text.latex.preamble'] = [r'\usepackage{amssymb}'] # \usepackage{txfonts}


mpl.rcParams['pgf.preamble'] = ['\\usepackage{amssymb}']
###


#mpl.rcParams['axes.titlepad'] = 6.0     # pad between axes and title in points
mpl.rcParams['axes.labelpad'] = 3.0 #10.0     # space between label and axis
mpl.rcParams['axes.labelweight'] = 'normal'  # weight (grosor) of the x and y labels
mpl.rcParams['axes.labelcolor'] = 'black'
mpl.rcParams['axes.unicode_minus'] = False # use Unicode for the minus symbol
mpl.rcParams['axes.linewidth'] = 1     # edge linewidth, grosor del marco

#mpl.rcParams['axes.titlesize'] = 24
mpl.rcParams['axes.labelsize'] = 16
#mpl.rcParams['lines.markersize'] = 10


# display axis spines, muestra la linea de los marcos
mpl.rcParams['axes.spines.left'] = True
mpl.rcParams['axes.spines.bottom'] = True
mpl.rcParams['axes.spines.top'] = True
mpl.rcParams['axes.spines.right'] = True

# Figura
#mpl.rcParams['figure.dpi'] = 100 # figure dots per inch
mpl.rcParams['figure.figsize'] = [12, 9]# [4,3] # 
mpl.rcParams['figure.facecolor'] = 'white'     # figure facecolor
mpl.rcParams['figure.edgecolor'] = 'white'     # figure edgecolor
mpl.rcParams['savefig.dpi'] = 100

mpl.rcParams['xtick.labelsize'] = 15 #'large' # tamaño de los números de los ejes
mpl.rcParams['ytick.labelsize'] = 15 #'large'
mpl.rcParams['xtick.direction'] = 'out' # direction: {in, out, inout} señalamiento de los ejes
mpl.rcParams['ytick.direction'] = 'out' # direction: {in, out, inout}
mpl.rcParams['xtick.top'] = False # draw ticks on the top side
mpl.rcParams['ytick.right'] = False # draw ticks on the top side
#xtick.labeltop      : False   ## draw label on the top
mpl.rcParams['xtick.labelbottom'] = True    # draw label on the bottom

mpl.rcParams['xtick.major.bottom'] = True   # draw x axis bottom major ticks
#mpl.rcParams['xtick.major.top'] = True   # draw x axis top major ticks
mpl.rcParams['xtick.minor.bottom'] = False    ## draw x axis bottom minor ticks
#mpl.rcParams['xtick.minor.top'] = True    ## draw x axis top minor ticks

mpl.rcParams['xtick.minor.visible'] = True  # visibility of minor ticks on x-axis

#xtick.alignment     : center  ## alignment of xticks
#xtick.alignment     : center  ## alignment of xticks

# Legend
mpl.rcParams['legend.loc'] = 'best'
mpl.rcParams['legend.frameon'] = True # if True, draw the legend on a background patch
mpl.rcParams['legend.framealpha'] = 0.19 # 0.8 legend patch transparency
mpl.rcParams['legend.facecolor'] = 'inherit'  # inherit from axes.facecolor; or color spec
mpl.rcParams['legend.edgecolor'] = 'inherit' # background patch boundary color
mpl.rcParams['legend.fancybox'] = True     # if True, use a rounded box for the

#mpl.rcParams['legend.numpoints'] = 1 # the number of marker points in the legend line
#mpl.rcParams['legend.scatterpoints'] = 1 # number of scatter points
#mpl.rcParams['legend.markerscale'] = 1.0 # the relative size of legend markers vs. original
mpl.rcParams['legend.fontsize'] = 14 # 'medium' 'large'

## Dimensions as fraction of fontsize:
mpl.rcParams['legend.borderpad'] = 0.4  ## border whitespace espacio de los bordes con respecto al texto
mpl.rcParams['legend.labelspacing'] = 0.5  ## the vertical space between the legend entries
mpl.rcParams['legend.handlelength'] = 1.5  ## the length of the legend lines defauld 2
#mpl.rcParams['legend.handleheight'] = 0.7  ## the height of the legend handle
mpl.rcParams['legend.handletextpad'] = 0.8  ## the space between the legend line and legend text
#mpl.rcParams['legend.borderaxespad'] = 0.5  ## the border between the axes and legend edge
#mpl.rcParams['legend.columnspacing'] = 8.0  ## column separation
# Out:
# <ipython-input-3-a7fd5b3b4c70>:19: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   mpl.rcParams['mathtext.fallback_to_cm']= True # When True, use symbols from the Computer Modern
# <ipython-input-3-a7fd5b3b4c70>:19: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   mpl.rcParams['mathtext.fallback_to_cm']= True # When True, use symbols from the Computer Modern
# <ipython-input-3-a7fd5b3b4c70>:19: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   mpl.rcParams['mathtext.fallback_to_cm']= True # When True, use symbols from the Computer Modern
# ...

# %%
class OOMFormatter(mpl.ticker.ScalarFormatter):
    def __init__(self, order=0, fformat="%1.1f", offset=True, mathText=True):
        self.oom = order
        self.fformat = fformat
        mpl.ticker.ScalarFormatter.__init__(self,useOffset=offset,useMathText=mathText)
    
    def _set_orderOfMagnitude(self, nothing):
        self.orderOfMagnitude = self.oom
    
    def _set_format(self):
        self.format = self.fformat
        if self._useMathText:
            self.format = '$%s$' % mpl.ticker._mathdefault(self.format)

# %%
# Case Beyond Horndeski with X, 
# eta = -0.3

#####
# phi0 = 0.03
# masa95 = 0.647296
# radio95 = 8.9595

temp1 = np.loadtxt('Acrecion_BH03_T.dat', usecols=(0,1)) 
flu1 = np.loadtxt('Acrecion_BH03_F.dat', usecols=(0,1))
lum1 = np.loadtxt('Acrecion_BH03_L.dat', usecols=(0,1))
masa1 = np.loadtxt('DatosM_BH03.dat', usecols=(0,1))

#####
# phi0 = 0.02
# masa95 = 0.562171
# radio95 = 11.4516

temp11 = np.loadtxt('Acrecion_BH02_T.dat', usecols=(0,1)) 
flu11 = np.loadtxt('Acrecion_BH02_F.dat', usecols=(0,1))
lum11 = np.loadtxt('Acrecion_BH02_L.dat', usecols=(0,1))
masa11 = np.loadtxt('DatosM_BH02.dat', usecols=(0,1))


# eta = -0.7

#####
# phi0 = 0.0163
# masa95 = 0.569341
# radio95 = 13.0128

temp111 = np.loadtxt('Acrecion_BH0163_T.dat', usecols=(0,1)) 
flu111 = np.loadtxt('Acrecion_BH0163_F.dat', usecols=(0,1))
lum111 = np.loadtxt('Acrecion_BH0163_L.dat', usecols=(0,1))
masa111 = np.loadtxt('DatosM_BH0163.dat', usecols=(0,1))


# eta = -1.2

#####
# phi0 = 0.013
# masa95 = 0.553535
# radio95 = 14.6793

temp1111 = np.loadtxt('Acrecion_BH013_T.dat', usecols=(0,1)) 
flu1111 = np.loadtxt('Acrecion_BH013_F.dat', usecols=(0,1))
lum1111 = np.loadtxt('Acrecion_BH013_L.dat', usecols=(0,1))
masa1111 = np.loadtxt('DatosM_BH013.dat', usecols=(0,1))


# eta = -2

#####
# phi0 = 0.011
# masa95 = 0.565006
# radio95 = 16.4329

tempm2 = np.loadtxt('Acrecion_BH011_T.dat', usecols=(0,1)) 
flum2 = np.loadtxt('Acrecion_BH011_F.dat', usecols=(0,1))
lumm2 = np.loadtxt('Acrecion_BH011_L.dat', usecols=(0,1))
masam2 = np.loadtxt('DatosM_BH011.dat', usecols=(0,1))


#### Boson star
# phi0 = 0.03
# masa95 = 0.562329
# radio95 = 8.74764

temp2 = np.loadtxt('Acrecion_BS_T.dat', usecols=(0,1)) 
flu2 = np.loadtxt('Acrecion_BS_F.dat', usecols=(0,1))
lum2 = np.loadtxt('Acrecion_BS_L.dat', usecols=(0,1))
masa2 = np.loadtxt('DatosM_BS03.dat', usecols=(0,1))

#### Black hole
# masa95 = 0.562329
# r0 = 6 Masas

temp0 = np.loadtxt('Acrecion_BH_T.dat', usecols=(0,1)) 
flu0 = np.loadtxt('Acrecion_BH_F.dat', usecols=(0,1))
lum0 = np.loadtxt('Acrecion_BH_L.dat', usecols=(0,1))

# %%
fig, ax = plt.subplots(figsize=(12,9))

matplotlib.rcParams['font.size'] = 20

ax.plot(temp0[:,0], temp0[:,1],'-', color='blue',label='Black Hole',linewidth=2.5)
ax.plot(temp1[:,0], temp1[:,1],'-', color='0.5',label=r'Model I',linewidth=2.5)
ax.plot(temp2[:,0], temp2[:,1],'-',color='black', label=r'Boson star',linewidth=2.5)

#linea vertical
#ax.axvline(x=8.9595, color='lightcoral', linestyle=':')

#angle2=90
#plt.figtext(.185, .15, r'$\mathrm{R}_{95}=8.96$', {'color': 'lightcoral', 'fontsize': 15},
#            rotation=angle2, rotation_mode='anchor')

#ax.axvline(x=12.55, color='dimgrey', linestyle=':')

#angle2=90
#plt.figtext(.31, .15, r'$G_{N}\approx G$', {'color': 'dimgrey', 'fontsize': 15},
#            rotation=angle2, rotation_mode='anchor')

# These are in unitless percentages of the figure size. (0,0 is bottom left)
left, bottom, width, height = [0.53, 0.5, 0.34, 0.34]
ax1 = fig.add_axes([left, bottom, width, height])

ax1.plot(flu0[:,0], flu0[:,1],'-', color='blue',label='Black Hole',linewidth=2.5)
ax1.plot(flu1[:,0], flu1[:,1],'-', color='0.5',label=r'Boson star',linewidth=2.5)
ax1.plot(flu2[:,0], flu2[:,1],'-',color='black', label=r'Model I',linewidth=2.5)

#x1, x2, y1, y2 = 8.5, 13.3, 0, 0.04 #rs[-1]+1
ax1.set_xlim(-0.5, 40) # apply the x-limits
#ax1.set_ylim(y1, y2)

#x1, x2, y1, y2 =lens1[0,0], 30, lens1[0,1], 0.5 #
ax.set_xlim(-0.5, 40) # apply the x-limits
#ax.set_ylim(y1, y2)

ax1.set_ylabel(r'$\mathrm{F}\; [\mathrm{erg}\;\mathrm{s}^{-1}\;\mathrm{cm}^{-2}]$', fontsize=18)
ax.set_ylabel(r'T [K]')#, rotation=0, fontsize=20, labelpad=25)#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax.set_xlabel(r'$\bar{r}$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

matplotlib.rcParams['font.size'] = 20
#ax1.set_ylabel(r'$rel. diff$') #
#ax1.set_xlabel(r'$\bar{r}$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

matplotlib.rcParams['legend.fontsize'] = 20
ax.legend(loc='lower right',frameon=False)
#ax1.legend(('Numerical solution', 'Analitical solution'),loc='upper right',frameon=False)

ax.set_title(r'$\bar{\eta}=-0.3$', loc='right', fontsize=22)
ax.set_title(r'$\bar{\sigma}_{0}=0.03$', loc='left', fontsize=22)
# Out:
# Text(0.0, 1.0, '$\\bar{\\sigma}_{0}=0.03$')

# %%
fig, ax = plt.subplots(figsize=(12,9))

matplotlib.rcParams['font.size'] = 20

ax.plot(temp0[:,0], temp0[:,1],'-', color='blue',label='Black Hole',linewidth=2.5)
ax.plot(temp11[:,0], temp11[:,1],'-', color='black',label=r'Model I',linewidth=2.5)
ax.plot(temp2[:,0], temp2[:,1],'-',color='0.5', label=r'Boson star',linewidth=2.5)

#linea vertical
#ax.axvline(x=8.9595, color='lightcoral', linestyle=':')

angle2=65
plt.figtext(.18, .61, r'$\bar{\sigma}_{0}=0.02$', {'color': 'black', 'fontsize': 15},
            rotation=angle2, rotation_mode='anchor')

#ax.axvline(x=12.55, color='dimgrey', linestyle=':')

angle2=75
plt.figtext(.16, .7, r'$\bar{\sigma}_{0}=0.03$', {'color': 'dimgrey', 'fontsize': 15},
            rotation=angle2, rotation_mode='anchor')

# These are in unitless percentages of the figure size. (0,0 is bottom left)
left, bottom, width, height = [0.53, 0.5, 0.34, 0.34]
ax1 = fig.add_axes([left, bottom, width, height])

ax1.plot(flu0[:,0], flu0[:,1],'-', color='blue',label='Black Hole',linewidth=2.5)
ax1.plot(flu11[:,0], flu11[:,1],'-', color='0.5',label=r'Boson star',linewidth=2.5)
ax1.plot(flu2[:,0], flu2[:,1],'-',color='black', label=r'Model I',linewidth=2.5)

#x1, x2, y1, y2 = 8.5, 13.3, 0, 0.04 #rs[-1]+1
ax1.set_xlim(-0.5, 38) # apply the x-limits
#ax1.set_ylim(y1, y2)

#x1, x2, y1, y2 =lens1[0,0], 30, lens1[0,1], 0.5 #
ax.set_xlim(-0.5, 38) # apply the x-limits
#ax.set_ylim(y1, y2)

ax1.set_ylabel(r'$\mathrm{F}\; [\mathrm{erg}\;\mathrm{s}^{-1}\;\mathrm{cm}^{-2}]$', fontsize=18)
ax.set_ylabel(r'T [K]')#, rotation=0, fontsize=20, labelpad=25)#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax.set_xlabel(r'$\bar{r}$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

matplotlib.rcParams['font.size'] = 20
#ax1.set_ylabel(r'$rel. diff$') #
#ax1.set_xlabel(r'$\bar{r}$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

matplotlib.rcParams['legend.fontsize'] = 20
ax.legend(loc='lower right',frameon=False)
#ax1.legend(('Numerical solution', 'Analitical solution'),loc='upper right',frameon=False)

ax.set_title(r'$\bar{\eta}=-0.3$', loc='right', fontsize=22)
ax.set_title(r'$\mathrm{M}_{95}=0.562$', loc='left', fontsize=22)
# Out:
# Text(0.0, 1.0, '$\\mathrm{M}_{95}=0.562$')

# %%
fig, ax = plt.subplots(figsize=(12,9))

matplotlib.rcParams['font.size'] = 20

ax.plot(np.log10(lum0[:,0]), np.log10(lum0[:,1]),'-', color='blue',label='Black Hole',linewidth=2.5)
ax.plot(np.log10(lum1[:,0]), np.log10(lum1[:,1]),':', color='0.5',label=r'Model I',linewidth=2.5)
ax.plot(np.log10(lum2[:,0]), np.log10(lum2[:,1]),'--',color='black', label=r'Boson star',linewidth=0.5)

#x1, x2, y1, y2 =lens1[0,0], 30, lens1[0,1], 0.5 #
#ax.set_xlim(-0.5, 40) # apply the x-limits
#ax.set_ylim(y1, y2)

ax.set_ylabel(r'T')#, rotation=0, fontsize=20, labelpad=25)#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax.set_xlabel(r'$\bar{r}$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

matplotlib.rcParams['font.size'] = 20
#ax1.set_ylabel(r'$rel. diff$') #
#ax1.set_xlabel(r'$\bar{r}$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

matplotlib.rcParams['legend.fontsize'] = 20
ax.legend(loc='lower right',frameon=False)
#ax1.legend(('Numerical solution', 'Analitical solution'),loc='upper right',frameon=False)

ax.set_title(r'$\bar{\eta}=-0.3$', loc='right', fontsize=22)
ax.set_title(r'$\bar{\sigma}_{0}=0.03$', loc='left', fontsize=22)
# Out:
# Text(0.0, 1.0, '$\\bar{\\sigma}_{0}=0.03$')

# %%
fig, ax = plt.subplots(figsize=(12,9))

matplotlib.rcParams['font.size'] = 20

ax.plot(np.log10(lum0[:,0]), np.log10(lum0[:,1]),'-', color='blue',label='Black Hole',linewidth=2.5)
ax.plot(np.log10(lum11[:,0]), np.log10(lum11[:,1]),':', color='black',label=r'Model I',linewidth=2.5)
ax.plot(np.log10(lum2[:,0]), np.log10(lum2[:,1]),'--',color='0.5', label=r'Boson star',linewidth=0.5)

#x1, x2, y1, y2 =lens1[0,0], 30, lens1[0,1], 0.5 #
#ax.set_xlim(-0.5, 40) # apply the x-limits
#ax.set_ylim(y1, y2)

ax.set_ylabel(r'$\log_{10}\;\mathrm{\nu}\,\mathrm{L(\nu)}\;\;[\mathrm{erg}\;s^{-1}]$')#, rotation=0, fontsize=20, labelpad=25)#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax.set_xlabel(r'$\log_{10}\;\mathrm{\nu}\;\mathrm{[Hz]}$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

matplotlib.rcParams['font.size'] = 20
#ax1.set_ylabel(r'$rel. diff$') #
#ax1.set_xlabel(r'$\bar{r}$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

matplotlib.rcParams['legend.fontsize'] = 25
ax.legend(loc='lower left',frameon=False)
#ax1.legend(('Numerical solution', 'Analitical solution'),loc='upper right',frameon=False)

ax.set_title(r'$\bar{\eta}=-0.3$', loc='right', fontsize=22)
ax.set_title(r'$\mathrm{M}_{95}=0.562$', loc='left', fontsize=22)
# Out:
# Text(0.0, 1.0, '$\\mathrm{M}_{95}=0.562$')

# %%
fig, ax = plt.subplots(figsize=(12,9))

matplotlib.rcParams['font.size'] = 20

ax.plot(np.log10(lum2[:,0]), np.log10(lum2[:,1]),'-',color='0.5', label=r'Boson star',linewidth=1)
ax.plot(np.log10(lum11[:,0]), np.log10(lum11[:,1]),'-', color='black',label=r'Model I with $\bar{\eta}=-0.3$',linewidth=1)
ax.plot(np.log10(lum0[:,0]), np.log10(lum0[:,1]),'-', color='blue',label='Black Hole',linewidth=1)
ax.plot(np.log10(lumm2[:,0]), np.log10(lumm2[:,1]),'-', color='red',label=r'Model I with $\bar{\eta}=-2$',linewidth=1)

#ax.plot(np.log10(lum1111[:,0]), np.log10(lum1111[:,1]),'-', color='red',label=r'Model I with $\bar{\eta}=-2$',linewidth=1)



#x1, x2, y1, y2 =lens1[0,0], 30, lens1[0,1], 0.5 #
#ax.set_xlim(-0.5, 40) # apply the x-limits
#ax.set_ylim(y1, y2)

ax.set_ylabel(r'$\log_{10}\;\mathrm{\nu}\,\mathrm{L(\nu)}\;\;[\mathrm{erg}\;s^{-1}]$', fontsize=25)#, rotation=0, fontsize=20, labelpad=25)#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax.set_xlabel(r'$\log_{10}\;\mathrm{\nu}\;\mathrm{[Hz]}$',fontsize=25)#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

matplotlib.rcParams['font.size'] = 20
#ax1.set_ylabel(r'$rel. diff$') #
#ax1.set_xlabel(r'$\bar{r}$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

matplotlib.rcParams['legend.fontsize'] = 25
ax.legend(loc='lower left',frameon=False)
#ax1.legend(('Numerical solution', 'Analitical solution'),loc='upper right',frameon=False)

angle2=0
plt.figtext(.15, .42, r'$\mathrm{M}_{95}=0.562$', {'color': 'black', 'fontsize': 25},
            rotation=angle2, rotation_mode='anchor')


angle2=-85
plt.figtext(.863, .25, r'$\bar{\sigma}_{0}=0.011$', {'color': 'red', 'fontsize': 15},
            rotation=angle2, rotation_mode='anchor')

angle2=-83
plt.figtext(.855, .6, r'$\bar{\sigma}_{0}=0.03$', {'color': 'dimgrey', 'fontsize': 15},
            rotation=angle2, rotation_mode='anchor')


angle2=-83
plt.figtext(.86, .465, r'$\bar{\sigma}_{0}=0.02$', {'color': 'black', 'fontsize': 15},
            rotation=angle2, rotation_mode='anchor')



#ax.set_title(r'$\bar{\eta}=-0.3$', loc='right', fontsize=22)
#ax.set_title(r'$\mathrm{M}_{95}=0.562$', loc='left', fontsize=22)
# Out:
# Text(0.86, 0.465, '$\\bar{\\sigma}_{0}=0.02$')

# %%
fig, ax = plt.subplots(figsize=(10,7))

ax.plot(np.log10(lum2[:,0]), np.log10(lum2[:,1]), color='#566874', 
                label=r'$c_{4}^{(1)}=d_{4}^{(-1)}=0\;(\Lambda_3=\infty)$')

line, = ax.plot(np.log10(lum11[:,0]), np.log10(lum11[:,1]),'-', color='#b45c1f',
                label=r'$c_{4}^{(1)} = 1/2,\, d_{4}^{(-1)}=1\;(\Lambda_3 = 1.5 \, M_{\mathrm{Pl}}^{1/3} m^{2/3})$')
line.set_dashes([10, 3, 2, 5, 6, 1]) # 5 points on, 2 off, 3 on, 1 off

ax.plot(np.log10(lum0[:,0]), np.log10(lum0[:,1]),'--', color='black',label='Black Hole') # Black Hole

ax.plot(np.log10(lumm2[:,0]), np.log10(lumm2[:,1]),':', color='#b45c1f',
        label=r'$c_{4}^{(1)} = 1/2,\, d_{4}^{(-1)}=1\; (\Lambda_3 = 0.79 \, M_{\mathrm{Pl}}^{1/3} m^{2/3})$')

#ax.plot(np.log10(lum1111[:,0]), np.log10(lum1111[:,1]),'-', color='red',label=r'Model I with $\bar{\eta}=-2$',linewidth=1)


angle2=0
plt.figtext(.15, .38, r'$\mathrm{M} \approx 6.3\times 10^9\;\mathrm{M}_{\odot} $', {'color': 'black'},
            rotation=angle2, rotation_mode='anchor')

ax.set_ylabel(r'$\log_{10}\;\mathrm{\nu}\,\mathrm{L(\nu)}\;\;[\mathrm{erg}\;s^{-1}]$')
ax.set_xlabel(r'$\log_{10}\;\mathrm{\nu}\;\mathrm{[Hz]}$')

ax.legend(loc='best',frameon=False)

ax.set_xlim(12, 14.55)
ax.set_ylim(34, 40)
# Out:
# (34.0, 40.0)

# %%
plt.savefig('Lum1.pgf', 
            #This is simple recomendation for publication plots
            dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

#plt.savefig('rho_profile.pgf')
plt.savefig("Lum1.png",dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

# %%
fig, ax = plt.subplots(figsize=(10,7))

ax.plot(np.log10(lum2[:,0]), np.log10(lum2[:,1]), color='#566874', 
                label=r'$c_1=d_1=0\;(\Lambda_3=\infty)$')

line, = ax.plot(np.log10(lum11[:,0]), np.log10(lum11[:,1]),'-', color='#b45c1f',
                label=r'$c_1 = 1/2,\, d_1=1\;(\Lambda_3 = 1.5 \, M_{\mathrm{Pl}}^{1/3} m^{2/3})$')
line.set_dashes([10, 3, 2, 5, 6, 1]) # 5 points on, 2 off, 3 on, 1 off

ax.plot(np.log10(lum0[:,0]), np.log10(lum0[:,1]),'--', color='black',label='Agujero Negro') # Black Hole

ax.plot(np.log10(lumm2[:,0]), np.log10(lumm2[:,1]),':', color='#b45c1f',
        label=r'$c_1 = 1/2,\, d_1=1\; (\Lambda_3 = 0.79 \, M_{\mathrm{Pl}}^{1/3} m^{2/3})$')

#ax.plot(np.log10(lum1111[:,0]), np.log10(lum1111[:,1]),'-', color='red',label=r'Model I with $\bar{\eta}=-2$',linewidth=1)


angle2=0
plt.figtext(.15, .38, r'$\mathrm{M} \approx 6.3\times 10^9\;\mathrm{M}_{\odot} $', {'color': 'black'},
            rotation=angle2, rotation_mode='anchor')

ax.set_ylabel(r'$\log_{10}\;\mathrm{\nu}\,\mathrm{L(\nu)}\;\;[\mathrm{erg}\;s^{-1}]$')
ax.set_xlabel(r'$\log_{10}\;\mathrm{\nu}\;\mathrm{[Hz]}$')

ax.legend(loc='best',frameon=False)

ax.set_xlim(12, 14.55)
ax.set_ylim(34, 40)
# Out:
# (34.0, 40.0)

# %%
plt.savefig('Num43.pgf', 
            #This is simple recomendation for publication plots
            dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

#plt.savefig('rho_profile.pgf')
plt.savefig("Num43.png",dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

# %%
10**(36.5-34)
# Out:
# 316.22776601683796

# %%
36.5-34
# Out:
# 2.5
