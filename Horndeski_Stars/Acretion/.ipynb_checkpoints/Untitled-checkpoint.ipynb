# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as font_manager
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
#from matplotlib.patches import Rectangle

from cycler import cycler

# %%
# estructura para latex
#mpl.use("pgf")

# estilo de linea y grosor
mpl.rcParams['lines.linestyle'] = '-'
mpl.rcParams['lines.linewidth'] = 2.

# orden de los colores que usará
mpl.rcParams['axes.prop_cycle'] = cycler('color', ['#1f77b4', '#ff7f0e', '#2ca02c', 
                                                   '#d62728', '#9467bd', '#8c564b', '#e377c2', 
                                                   '#7f7f7f', '#bcbd22', '#17becf'])
#cycler(color=['r', 'g', 'b', 'y'])

# latex modo math
mpl.rcParams['mathtext.fontset'] = 'cm'  # Should be 'dejavusans' (default),
                                         # 'dejavuserif', 'cm' (Computer Modern), 'stix',
                                         # 'stixsans' or 'custom'
        
mpl.rcParams['mathtext.fallback_to_cm']= True # When True, use symbols from the Computer Modern
                                              # fonts when a symbol can not be found in one of
                                              # the custom math fonts.
    
# Texto
mpl.rcParams['font.family'] = 'serif' # serif, sans-serif, cursive, fantasy, monospace
cmfont = font_manager.FontProperties(fname=mpl.get_data_path() + '/fonts/ttf/cmr10.ttf')
mpl.rcParams['font.serif']=cmfont.get_name()
mpl.rcParams['font.size'] = 16 # tamaño de la letra

###
#mpl.rcParams['pgf.texsystem'] = 'pdflatex'
mpl.rcParams['text.usetex'] = True
mpl.rcParams['pgf.rcfonts'] = False
mpl.rcParams['text.latex.preamble'] = [r'\usepackage{amssymb}'] # \usepackage{txfonts}


mpl.rcParams['pgf.preamble'] = ['\\usepackage{amssymb}']
###


#mpl.rcParams['axes.titlepad'] = 6.0     # pad between axes and title in points
mpl.rcParams['axes.labelpad'] = 3.0 #10.0     # space between label and axis
mpl.rcParams['axes.labelweight'] = 'normal'  # weight (grosor) of the x and y labels
mpl.rcParams['axes.labelcolor'] = 'black'
mpl.rcParams['axes.unicode_minus'] = False # use Unicode for the minus symbol
mpl.rcParams['axes.linewidth'] = 1     # edge linewidth, grosor del marco

#mpl.rcParams['axes.titlesize'] = 24
mpl.rcParams['axes.labelsize'] = 16
#mpl.rcParams['lines.markersize'] = 10


# display axis spines, muestra la linea de los marcos
mpl.rcParams['axes.spines.left'] = True
mpl.rcParams['axes.spines.bottom'] = True
mpl.rcParams['axes.spines.top'] = True
mpl.rcParams['axes.spines.right'] = True

# Figura
#mpl.rcParams['figure.dpi'] = 100 # figure dots per inch
mpl.rcParams['figure.figsize'] = [12, 9]# [4,3] # 
mpl.rcParams['figure.facecolor'] = 'white'     # figure facecolor
mpl.rcParams['figure.edgecolor'] = 'white'     # figure edgecolor
mpl.rcParams['savefig.dpi'] = 100

mpl.rcParams['xtick.labelsize'] = 15 #'large' # tamaño de los números de los ejes
mpl.rcParams['ytick.labelsize'] = 15 #'large'
mpl.rcParams['xtick.direction'] = 'out' # direction: {in, out, inout} señalamiento de los ejes
mpl.rcParams['ytick.direction'] = 'out' # direction: {in, out, inout}
mpl.rcParams['xtick.top'] = False # draw ticks on the top side
mpl.rcParams['ytick.right'] = False # draw ticks on the top side
#xtick.labeltop      : False   ## draw label on the top
mpl.rcParams['xtick.labelbottom'] = True    # draw label on the bottom

mpl.rcParams['xtick.major.bottom'] = True   # draw x axis bottom major ticks
#mpl.rcParams['xtick.major.top'] = True   # draw x axis top major ticks
mpl.rcParams['xtick.minor.bottom'] = False    ## draw x axis bottom minor ticks
#mpl.rcParams['xtick.minor.top'] = True    ## draw x axis top minor ticks

mpl.rcParams['xtick.minor.visible'] = True  # visibility of minor ticks on x-axis

#xtick.alignment     : center  ## alignment of xticks
#xtick.alignment     : center  ## alignment of xticks

# Legend
mpl.rcParams['legend.loc'] = 'best'
mpl.rcParams['legend.frameon'] = True # if True, draw the legend on a background patch
mpl.rcParams['legend.framealpha'] = 0.19 # 0.8 legend patch transparency
mpl.rcParams['legend.facecolor'] = 'inherit'  # inherit from axes.facecolor; or color spec
mpl.rcParams['legend.edgecolor'] = 'inherit' # background patch boundary color
mpl.rcParams['legend.fancybox'] = True     # if True, use a rounded box for the

#mpl.rcParams['legend.numpoints'] = 1 # the number of marker points in the legend line
#mpl.rcParams['legend.scatterpoints'] = 1 # number of scatter points
#mpl.rcParams['legend.markerscale'] = 1.0 # the relative size of legend markers vs. original
mpl.rcParams['legend.fontsize'] = 14 # 'medium' 'large'

## Dimensions as fraction of fontsize:
mpl.rcParams['legend.borderpad'] = 0.4  ## border whitespace espacio de los bordes con respecto al texto
mpl.rcParams['legend.labelspacing'] = 0.5  ## the vertical space between the legend entries
mpl.rcParams['legend.handlelength'] = 1.5  ## the length of the legend lines defauld 2
#mpl.rcParams['legend.handleheight'] = 0.7  ## the height of the legend handle
mpl.rcParams['legend.handletextpad'] = 0.8  ## the space between the legend line and legend text
#mpl.rcParams['legend.borderaxespad'] = 0.5  ## the border between the axes and legend edge
#mpl.rcParams['legend.columnspacing'] = 8.0  ## column separation
# Out:
# <ipython-input-2-a7fd5b3b4c70>:19: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   mpl.rcParams['mathtext.fallback_to_cm']= True # When True, use symbols from the Computer Modern
# <ipython-input-2-a7fd5b3b4c70>:19: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   mpl.rcParams['mathtext.fallback_to_cm']= True # When True, use symbols from the Computer Modern
# <ipython-input-2-a7fd5b3b4c70>:19: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   mpl.rcParams['mathtext.fallback_to_cm']= True # When True, use symbols from the Computer Modern
# ...

# %%
class OOMFormatter(mpl.ticker.ScalarFormatter):
    def __init__(self, order=0, fformat="%1.1f", offset=True, mathText=True):
        self.oom = order
        self.fformat = fformat
        mpl.ticker.ScalarFormatter.__init__(self,useOffset=offset,useMathText=mathText)
    
    def _set_orderOfMagnitude(self, nothing):
        self.orderOfMagnitude = self.oom
    
    def _set_format(self):
        self.format = self.fformat
        if self._useMathText:
            self.format = '$%s$' % mpl.ticker._mathdefault(self.format)

# %%
# Bs máxima compacticidad

r1 = np.loadtxt('radio_799.dat', usecols=(0,1))
r2 = np.loadtxt('radio_100.dat', usecols=(0,1))
r3 = np.loadtxt('radio_32.dat', usecols=(0,1))

sch = np.loadtxt('Schw.dat', usecols=(0,1))

# %%
fig, ax = plt.subplots(figsize=(10,7))

ax.plot(r1[:100,0], r1[:100,1], color='blue', label=r'$c_1=d_1=0,\;\;r_{out}=50 M/M_{\mathrm{Pl}}^{2}$')

ax.plot(r2[:100,0], r2[:100,1], color='red', label=r'$c_1=d_1=0,\;\;r_{out}=6.25 M/M_{\mathrm{Pl}}^{2}$')

ax.plot(r3[:100,0], r3[:100,1], color='orange', label=r'$c_1=d_1=0,\;\;r_{out}=2 M/M_{\mathrm{Pl}}^{2}$')

ax.plot(sch[:72,0], sch[:72,1], color='black', label=r'Schw. black hole, $r_{out}=50 M/M_{\mathrm{Pl}}^{2}$')


#ax.plot(np.log10(lum1111[:,0]), np.log10(lum1111[:,1]),'-', color='red',label=r'Model I with $\bar{\eta}=-2$',linewidth=1)


angle2=0
plt.figtext(.15, .63, r'$\mathrm{M} = 3\times 10^9\;\mathrm{M}_{\odot} $', {'color': 'black'},
            rotation=angle2, rotation_mode='anchor')

plt.figtext(.15, .59, r'$m = 2.8\times 10^{-20}\;\mathrm{eV} $', {'color': 'black'},
            rotation=angle2, rotation_mode='anchor')


ax.set_ylabel(r'$\mathrm{\nu}\,\mathrm{L(\nu)}\;\;[\mathrm{erg}\;s^{-1}]$')
ax.set_xlabel(r'$\mathrm{\nu}\;\mathrm{[Hz]}$')

ax.legend(loc='best',frameon=False)

#ax.set_xlim(12, 14.55)
#ax.set_ylim(34, 40)

ax.set_xscale('log')
ax.set_yscale('log')

# %%
# plot

r1_BS = np.loadtxt('radio_799.dat', usecols=(0,1))  # m=2.8286*10^-20
r2_H1 = np.loadtxt('H_L3_1_5_mostComp.dat', usecols=(0,1)) # m=3.27748*10^-20
r2_H2 = np.loadtxt('H_L3_1_mostComp.dat', usecols=(0,1)) # m=4.89266*10^-20

sch = np.loadtxt('Schw.dat', usecols=(0,1))

#test = np.loadtxt('test.dat', usecols=(0,1)) # m=4.89266*10^-20

# %%
fig, ax = plt.subplots(figsize=(10,7))

ax.plot(r1_BS[:,0], r1_BS[:,1], color='blue', label=r'$c_1=0, d_1=0,\;\;\Lambda_3 \gg \, M_{\mathrm{Pl}}^{1/3} m^{2/3}\;(\mathrm{EKG})$')

ax.plot(r2_H1[:,0], r2_H1[:,1], color='red', label=r'$c_1=1/2, d_1=0,\;\;\Lambda_3 = 1.5 \, M_{\mathrm{Pl}}^{1/3} m^{2/3}$')

ax.plot(r2_H2[:,0], r2_H2[:,1], color='orange', label=r'$c_1=1/2, d_1=0,\;\;\Lambda_3 = 1.0 \, M_{\mathrm{Pl}}^{1/3} m^{2/3}$')

ax.plot(sch[:,0], sch[:,1], color='black', label=r'Schw. black hole')


#ax.plot(np.log10(lum1111[:,0]), np.log10(lum1111[:,1]),'-', color='red',label=r'Model I with $\bar{\eta}=-2$',linewidth=1)


angle2=0
plt.figtext(.15, .63, r'$\mathrm{M} = 3\times 10^9\;\mathrm{M}_{\odot} $', {'color': 'black'},
            rotation=angle2, rotation_mode='anchor')



ax.set_ylabel(r'$\mathrm{\nu}\,\mathrm{L(\nu)}\;\;[\mathrm{erg}\;s^{-1}]$')
ax.set_xlabel(r'$\mathrm{\nu}\;\mathrm{[Hz]}$')

ax.legend(loc=(0.1, 0.05),frameon=False)

ax.set_xlim(1e10, 1.5e18)
ax.set_ylim(1e-10, 1e41)

ax.set_xscale('log')
ax.set_yscale('log')

# %%
sch = np.loadtxt('Schw.dat', usecols=(0,1))

test_1 = np.loadtxt('test_1.dat', usecols=(0,1)) # 4.89266*(10^-20eV)
test_1_5 = np.loadtxt('test_1_5.dat', usecols=(0,1)) # 3.27748*(10^-20eV)

# %%
fig, ax = plt.subplots(figsize=(10,7))

#ax.plot(r1_BS[:,0], r1_BS[:,1], color='blue', label=r'$c_1=0, d_1=0,\;\;\Lambda_3 \gg \, M_{\mathrm{Pl}}^{1/3} m^{2/3}\;(\mathrm{EKG})$')

ax.plot(test_1_5[:,0],test_1_5[:,1], color='red', label=r'$c_1=1/2, d_1=0,\;\;\Lambda_3 = 1.5 \, M_{\mathrm{Pl}}^{1/3} m^{2/3}$')

ax.plot(test_1[:,0], test_1[:,1], color='orange', ls=':',marker='o',label=r'$c_1=1/2, d_1=0,\;\;\Lambda_3 = 1.0 \, M_{\mathrm{Pl}}^{1/3} m^{2/3}$')

ax.plot(sch[:,0], sch[:,1], color='black', label=r'Schw. black hole')


#ax.plot(np.log10(lum1111[:,0]), np.log10(lum1111[:,1]),'-', color='red',label=r'Model I with $\bar{\eta}=-2$',linewidth=1)


angle2=0
plt.figtext(.15, .63, r'$\mathrm{M} = 3\times 10^9\;\mathrm{M}_{\odot} $', {'color': 'black'},
            rotation=angle2, rotation_mode='anchor')



ax.set_ylabel(r'$\mathrm{\nu}\,\mathrm{L(\nu)}\;\;[\mathrm{erg}\;s^{-1}]$')
ax.set_xlabel(r'$\mathrm{\nu}\;\mathrm{[Hz]}$')

ax.legend(loc=(0.1, 0.05),frameon=False)

ax.set_xlim(1e10, 1.0e15)
ax.set_ylim(1e-10, 1e40)

ax.set_xscale('log')
ax.set_yscale('log')

# %%
def fun(t, d, D, a):
    """
    t parámetro de entrada
    d -> delta, D -> D_0, a-> alpha parámtros de ajuste
    """
    dr_sq = 6*d**2*np.power(1-(np.exp(-D*t/d**2))**a, 1/a)
    
    return dr_sq

# %%
27.6395/3.14/8/3.30355
# Out:
# 0.3330655103991103

# %%
# 4.89266*(10^-20eV) # \bar M = 27.6696, R_95=3.31371
g_1 = np.loadtxt('g_profile_L3_1.dat', unpack=True) 
N_1 = np.loadtxt('N_profile_L3_1.dat', unpack=True) 


# 2.8286*(10^-20eV) # \bar M =  15.9325 R_95=6.04864
g_Bs = np.loadtxt('g_profile_BS.dat', unpack=True) 
N_Bs = np.loadtxt('N_profile_BS.dat', unpack=True) 

# 3.27748*(10^-20eV) # \bar M = 18.6018 R_95=4.54781
g_1_5 = np.loadtxt('g_profile_L3_1_5.dat', unpack=True) 
N_1_5 = np.loadtxt('N_profile_L3_1_5.dat', unpack=True)

# %%
rad1 = np.arange(2, 180 , 0.1)

Mass1 = 27.6395
Mass1_5 = 18.6018
MassBs = 15.9325

Rs1 = 2*Mass1/(8*np.pi)
Rs1_5 = 2*Mass1_5/(8*np.pi)
RsBs = 2*MassBs/(8*np.pi)


#  Detalles por la definción
NN = lambda M, r: np.power(1-2*M/(r*8*np.pi), 0.5)
gg = lambda M, r: np.power(1/(1-2*M/(r*8*np.pi)),0.5)

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 5.5), sharex=False, sharey=False) 

ax[0].plot(N_1[0], N_1[1], label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0, \;\;\Lambda_3 = 1.0 \, M_{\mathrm{Pl}}^{1/3} m^{2/3}$', 
           color = 'red')
ax[0].plot(rad1, NN(Mass1,rad1),':', color='black', label=r'Schw. black hole')


ax[0].plot(N_1_5[0], N_1_5[1], label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0, \;\;\Lambda_3 = 1.5 \, M_{\mathrm{Pl}}^{1/3} m^{2/3}$', 
           color = 'blue')
ax[0].plot(rad1, NN(Mass1_5,rad1),':', color='black')


ax[0].plot(N_Bs[0], N_Bs[1], label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0, \;\;\Lambda_3 \gg \, M_{\mathrm{Pl}}^{1/3} m^{2/3}\;(\mathrm{EKG})$', 
           color = 'orange')
ax[0].plot(rad1, NN(MassBs,rad1),':', color='black')


ax[0].axvline(x=6*Mass1, color='red', linestyle=':', alpha=0.5)
ax[0].axvline(x=6*Mass1_5, color='blue', linestyle=':', alpha=0.5)
ax[0].axvline(x=6*MassBs, color='orange', linestyle=':', alpha=0.5)


#ax[0].axvline(x=Rs1, color='#756f6b', linestyle=':', alpha=0.5)
#ax[0].axvline(x=8.06799, color='#756f6b', linestyle='-', alpha=0.5)

#angle2=90
#ax[0].text(Rs1-0.2, .881, r'$r_{\mathrm{schw}}= $'+r'${:3.2}$'.format(Rs1)+r' $m^{-1}$',
#            rotation=angle2, rotation_mode='anchor', c='#756f6b')

#ax[0].text(7.9, .757, r'$R_{95}=8.068 \, m^{-1}$', c = '#756f6b',
#            rotation=angle2, rotation_mode='anchor')




ax[0].set_xlim(N_1[0][0], 200)
ax[0].set_ylim(0.3, 1)

ax[0].set_xlabel(r'$r\,[m^{-1}]$')
ax[0].set_ylabel(r'$N$')

ax[0].legend(loc= 'best',frameon=False)



ax[1].plot(g_1[0], g_1[1], label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0, \;\;\Lambda_3 = 1.0 \, M_{\mathrm{Pl}}^{1/3} m^{2/3}$', 
           color = 'red')
ax[1].plot(rad1, gg(Mass1,rad1),':', color='black', label=r'Schw. black hole')

ax[1].plot(g_1_5[0], g_1_5[1], label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0, \;\;\Lambda_3 = 1.5 \, M_{\mathrm{Pl}}^{1/3} m^{2/3}$', 
           color = 'blue')
ax[1].plot(rad1, gg(Mass1_5, rad1),':', color='black')

ax[1].plot(g_Bs[0], g_Bs[1], label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0, \;\;\Lambda_3 \gg \, M_{\mathrm{Pl}}^{1/3} m^{2/3}\;(\mathrm{EKG})$', 
           color = 'orange')
ax[1].plot(rad1, gg(MassBs, rad1),':', color='black')

ax[1].axvline(x=6*Mass1, color='red', linestyle=':', alpha=0.5)
ax[1].axvline(x=6*Mass1_5, color='blue', linestyle=':', alpha=0.5)
ax[1].axvline(x=6*MassBs, color='orange', linestyle=':', alpha=0.5)


##

#ax[1].axvline(x=Rs1, color='#756f6b', linestyle=':', alpha=0.5)
#ax[1].axvline(x=8.06799, color='#756f6b', linestyle='-', alpha=0.5)

#angle2=90
#ax[1].text(Rs1-0.2, 1.125, r'$r_{\mathrm{schw}}= $'+r'${:3.2}$'.format(Rs1)+r' $m^{-1}$',
#            rotation=angle2, rotation_mode='anchor', c='#756f6b')

#ax[1].text(7.9, 0.997, r'$R_{95}=8.068 \, m^{-1}$', c = '#756f6b',
#            rotation=angle2, rotation_mode='anchor')



ax[1].set_xlabel(r'$r\,[m^{-1}]$')
ax[1].set_ylabel(r'$g$')

ax[1].set_xlim(N_1[0][0], 200)
ax[1].set_ylim(0.99, 1.8)


#ax[1].legend(loc='best', frameon=False);
# Out:
# <ipython-input-130-edc3426ba08f>:13: RuntimeWarning: invalid value encountered in power
#   NN = lambda M, r: np.power(1-2*M/(r*8*np.pi), 0.5)
# <ipython-input-130-edc3426ba08f>:14: RuntimeWarning: invalid value encountered in power
#   gg = lambda M, r: np.power(1/(1-2*M/(r*8*np.pi)),0.5)
# (0.99, 1.8)

# %%
rad1 = np.arange(2, 180 , 0.1)

Mass1 = 27.6696
Rs1 = 2*Mass1/(8*np.pi)


#  Detalles por la definción
NN = lambda M, r: np.power(1-2*M/(r*8*np.pi), 0.5)
gg = lambda M, r: np.power(1/(1-2*M/(r*8*np.pi)),0.5)

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 5.5), sharex=False, sharey=False) 

ax[0].plot(N_1[0], N_1[1], label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0, \\[0.15cm]\Lambda_3 = 1.0 \, M_{\mathrm{Pl}}^{1/3} m^{2/3}$', 
           color = 'red')
ax[0].plot(rad1, NN(Mass1,rad1),':', color='black', label=r'Schw. black hole')


ax[0].axvline(x=6*Mass1/(8*np.pi), color='black', linestyle=':', alpha=0.5)
ax[0].axvline(x=Rs1, color='#756f6b', linestyle=':', alpha=0.5)
ax[0].axvline(x=3.31371, color='#756f6b', linestyle='-', alpha=0.5)

angle2=90
#ax[0].text(Rs1-0.2, .881, r'$r_{\mathrm{schw}}= $'+r'${:3.2}$'.format(Rs1)+r' $m^{-1}$',
#            rotation=angle2, rotation_mode='anchor', c='#756f6b')

#ax[0].text(7.9, .757, r'$R_{95}=3.30355 \, m^{-1}$', c = '#756f6b',
#            rotation=angle2, rotation_mode='anchor')




ax[0].set_xlim(N_1[0][0], 15)
ax[0].set_ylim(0.3, 1)

ax[0].set_xlabel(r'$r\,[m^{-1}]$')
ax[0].set_ylabel(r'$N$')

ax[0].legend(loc= 'best',frameon=False)


ax[1].plot(g_1[0], g_1[1], label=r'$c_{4}^{(1)}=1/2, d_{4}^{(-1)}=0,\\\Lambda_3 = 1.0 \, M_{\mathrm{Pl}}^{1/3} m^{2/3}$', 
           color = 'red')
ax[1].plot(rad1, gg(Mass1,rad1),':', color='black', label=r'Schw. black hole')


ax[1].axvline(x=6*Mass1/(8*np.pi), color='black', linestyle=':', alpha=0.5)
ax[1].axvline(x=Rs1, color='#756f6b', linestyle=':', alpha=0.5)
ax[1].axvline(x=3.31371, color='#756f6b', linestyle='-', alpha=0.5)

#angle2=90
ax[1].text(Rs1-0.2, .92, r'$r_{\mathrm{schw}}= $'+r'${:3.2}$'.format(Rs1)+r' $m^{-1}$',
            rotation=angle2, rotation_mode='anchor', c='#756f6b')

ax[1].text(3.85, .92, r'$R_{95}=3.31 \, m^{-1}$', c = '#756f6b',
            rotation=angle2, rotation_mode='anchor')

ax[1].text(6*Mass1/(8*np.pi)-0.2, .92, r'ISCO', c = '#756f6b',
            rotation=angle2, rotation_mode='anchor')



ax[1].set_xlabel(r'$r\,[m^{-1}]$')
ax[1].set_ylabel(r'$N$')

ax[1].set_xlim(N_1[0][0], 15)
ax[1].set_ylim(0.9, 1.8)

#ax[1].set_xscale('log')
#ax[1].set_yscale('log')


ax[1].legend(loc='best', frameon=False);
# Out:
# <ipython-input-19-54b40d98e5f9>:8: RuntimeWarning: invalid value encountered in power
#   NN = lambda M, r: np.power(1-2*M/(r*8*np.pi), 0.5)
# <ipython-input-19-54b40d98e5f9>:9: RuntimeWarning: invalid value encountered in power
#   gg = lambda M, r: np.power(1/(1-2*M/(r*8*np.pi)),0.5)

# %%
rad1 = np.arange(1, 180 , 0.1)

MassBs = 15.9325
RsBs = 2*MassBs/(8*np.pi)


#  Detalles por la definción
NN = lambda M, r: np.power(1-2*M/(r*8*np.pi), 0.5)
gg = lambda M, r: np.power(1/(1-2*M/(r*8*np.pi)),0.5)

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 5.5), sharex=False, sharey=False) 

ax[0].plot(N_Bs[0], N_Bs[1], label=r'$c_{4}^{(1)}=1/2,d_{4}^{(-1)}=0,\\[0.15cm]\Lambda_3 \gg \, M_{\mathrm{Pl}}^{1/3} m^{2/3}\;(\mathrm{EKG})$', 
           color = 'orange')
ax[0].plot(rad1, NN(MassBs,rad1),':', color='black', label=r'Schw. black hole')

ax[0].axvline(x=6*MassBs/(8*np.pi), color='orange', linestyle=':', alpha=0.5)


ax[0].axvline(x=RsBs, color='#756f6b', linestyle=':', alpha=0.5)
ax[0].axvline(x=6.04864, color='#756f6b', linestyle='-', alpha=0.5)

#angle2=90
#ax[0].text(Rs1-0.2, .881, r'$r_{\mathrm{schw}}= $'+r'${:3.2}$'.format(Rs1)+r' $m^{-1}$',
#            rotation=angle2, rotation_mode='anchor', c='#756f6b')

#ax[0].text(7.9, .757, r'$R_{95}=3.30355 \, m^{-1}$', c = '#756f6b',
#            rotation=angle2, rotation_mode='anchor')




ax[0].set_xlim(N_1[0][0], 15)
ax[0].set_ylim(0.5, 1)

ax[0].set_xlabel(r'$r\,[m^{-1}]$')
ax[0].set_ylabel(r'$N$')

ax[0].legend(loc= 'center right',frameon=False)


ax[1].plot(g_Bs[0], g_Bs[1], label=r'$c_{4}^{(1)}=1/2, d_{4}^{(-1)}=0,\\\Lambda_3 \gg \, M_{\mathrm{Pl}}^{1/3} m^{2/3}\;(\mathrm{EKG})$', 
           color = 'orange')
ax[1].plot(rad1, gg(MassBs,rad1),':', color='black', label=r'Schw. black hole')

ax[1].axvline(x=6*MassBs/(8*np.pi), color='orange', linestyle=':', alpha=0.5)


ax[1].axvline(x=RsBs, color='#756f6b', linestyle=':', alpha=0.5)
ax[1].axvline(x=6.04864, color='#756f6b', linestyle='-', alpha=0.5)

#angle2=90
ax[1].text(RsBs-0.3, .95, r'$r_{\mathrm{schw}}= $'+r'${:3.2}$'.format(Rs1)+r' $m^{-1}$',
            rotation=angle2, rotation_mode='anchor', c='#756f6b')

ax[1].text(7, .95, r'$R_{95}=6.05 \, m^{-1}$', c = '#756f6b',
            rotation=angle2, rotation_mode='anchor')

ax[1].set_xlabel(r'$r\,[m^{-1}]$')
ax[1].set_ylabel(r'$N$')

ax[1].set_xlim(N_1[0][0], 15)
ax[1].set_ylim(0.95, 1.2)

#ax[1].set_xscale('log')
#ax[1].set_yscale('log')


#ax[1].legend(loc='center left', frameon=False);
# Out:
# <ipython-input-188-eaf78034653d>:8: RuntimeWarning: invalid value encountered in power
#   NN = lambda M, r: np.power(1-2*M/(r*8*np.pi), 0.5)
# <ipython-input-188-eaf78034653d>:9: RuntimeWarning: invalid value encountered in power
#   gg = lambda M, r: np.power(1/(1-2*M/(r*8*np.pi)),0.5)
# (0.95, 1.2)

# %%
rad1 = np.arange(2, 180 , 0.1)

Mass1_5 = 18.6018
Rs1_5 = 2*Mass1_5/(8*np.pi)


#  Detalles por la definción
NN = lambda M, r: np.power(1-2*M/(r*8*np.pi), 0.5)
gg = lambda M, r: np.power(1/(1-2*M/(r*8*np.pi)),0.5)

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 5.5), sharex=False, sharey=False) 

ax[0].plot(N_1[0], N_1[1], label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0, \\[0.15cm]\Lambda_3 = 1.5 \, M_{\mathrm{Pl}}^{1/3} m^{2/3}$', 
           color = 'blue')
ax[0].plot(rad1, NN(Mass1_5,rad1),':', color='black', label=r'Schw. black hole')

ax[0].axvline(x=6*Mass1_5, color='blue', linestyle=':', alpha=0.5)


ax[0].axvline(x=Rs1, color='#756f6b', linestyle=':', alpha=0.5)
ax[0].axvline(x=4.54781, color='#756f6b', linestyle='-', alpha=0.5)



ax[0].set_xlim(N_1[0][0], 200)
ax[0].set_ylim(0.3, 1)

ax[0].set_xlabel(r'$r\,[m^{-1}]$')
ax[0].set_ylabel(r'$N$')

ax[0].legend(loc= 'center left',frameon=False)


ax[1].plot(N_1[0], N_1[1], label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0, \;\;\Lambda_3 = 1.5 \, M_{\mathrm{Pl}}^{1/3} m^{2/3}$', 
           color = 'blue')
ax[1].plot(rad1, NN(Mass1,rad1),':', color='black', label=r'Schw. black hole')

ax[1].axvline(x=6*Mass1_5, color='blue', linestyle=':', alpha=0.5)


ax[1].axvline(x=Rs1, color='#756f6b', linestyle=':', alpha=0.5)
ax[1].axvline(x=4.54781, color='#756f6b', linestyle='-', alpha=0.5)

#angle2=90
ax[1].text(Rs1-0.3, .65, r'$r_{\mathrm{schw}}= $'+r'${:3.2}$'.format(Rs1)+r' $m^{-1}$',
            rotation=angle2, rotation_mode='anchor', c='#756f6b')

ax[1].text(7, .31, r'$R_{95}=4.55 \, m^{-1}$', c = '#756f6b',
            rotation=angle2, rotation_mode='anchor')

ax[1].set_xlabel(r'$r\,[m^{-1}]$')
ax[1].set_ylabel(r'$N$')

ax[1].set_xlim(N_1[0][0], 200)
ax[1].set_ylim(0.3, 1)

ax[1].set_xscale('log')
ax[1].set_yscale('log')


#ax[1].legend(loc='center left', frameon=False);
# Out:
# <ipython-input-162-d2d74a7aba8f>:8: RuntimeWarning: invalid value encountered in power
#   NN = lambda M, r: np.power(1-2*M/(r*8*np.pi), 0.5)

# %%
plt.plot(test_1[:,0], test_1[:,1], color='orange', ls=':',marker='o',label=r'$c_1=1/2, d_1=0,\;\;\Lambda_3 = 1.0 \, M_{\mathrm{Pl}}^{1/3} m^{2/3}$')

plt.xlim(1e10,4e13)
# Out:
# (10000000000.0, 40000000000000.0)

# %%
plt.plot(test_1[:,0], test_1[:,1], color='orange', ls=':',marker='o',label=r'$c_1=1/2, d_1=0,\;\;\Lambda_3 = 1.0 \, M_{\mathrm{Pl}}^{1/3} m^{2/3}$')

plt.xlim(1e10,4e13)
plt.xscale('log')
plt.yscale('log')

# %%
HS1 = np.loadtxt("HS1.dat", unpack=True)
HS2 = np.loadtxt("HS2.dat", unpack=True)
HS3 = np.loadtxt("HS3.dat", unpack=True)
HS4 = np.loadtxt("HS4.dat", unpack=True)
HS5 = np.loadtxt("HS5.dat", unpack=True)
HS8 = np.loadtxt("HS8.dat", unpack=True)


SC1 = np.loadtxt("S1.dat", unpack=True)
SC2 = np.loadtxt("S2.dat", unpack=True)
SC3 = np.loadtxt("S3.dat", unpack=True)
SC4 = np.loadtxt("S4.dat", unpack=True)
SC5 = np.loadtxt("S5.dat", unpack=True)
SC6 = np.loadtxt("S6.dat", unpack=True)
SC7 = np.loadtxt("S7.dat", unpack=True)
SC8 = np.loadtxt("S8.dat", unpack=True)

# %%
plt.plot(HS1[0], HS1[1], color='orange', ls='-',marker='',label=r'HS $r_out=3.1 r_s$')
#plt.plot(HS2[0], HS2[1], color='orange', ls='-',marker='',label=r'HS $r_out=4.1 r_s$')
#plt.plot(HS3[0], HS3[1], color='blue', ls='-',marker='',label=r'HS $r_out=5.1 r_s$')
#plt.plot(HS4[0], HS4[1], color='red', ls='-',marker='',label=r'HS $r_out=10.1 r_s$')
#plt.plot(HS5[0], HS5[1], color='grey', ls='-',marker='',label=r'HS $r_out=20.1 r_s$')
#plt.plot(HS8[0], HS8[1], color='black', ls='-',marker='',label=r'HS $r_out=50 r_s$')


plt.plot(SC1[0], SC1[1], color='black', ls='', marker='o', ms=4, label=r'BH $r_out=3.1 r_s$')
#plt.plot(SC2[0], SC2[1], color='black', ls='',marker='o', ms=4,label=r'BH $r_out=4.1 r_s$')
#plt.plot(SC3[0], SC3[1], color='black', ls='',marker='o', ms=4,label=r'BH $r_out=5.1 r_s$')
#plt.plot(SC4[0], SC4[1], color='black', ls='',marker='o',ms=4,label=r'BH $r_out=10.1 r_s$')
#plt.plot(SC5[0], SC5[1], color='black', ls='',marker='o',ms=4,label=r'BH $r_out=20.1 r_s$')
#plt.plot(SC6[0], SC6[1], color='black', ls=':',marker='o',label=r'BH $r_out=30.1 r_s$')
#plt.plot(SC7[0], SC7[1], color='black', ls=':',marker='o',label=r'BH $r_out=40.1 r_s$')
#plt.plot(SC8[0], SC8[1], color='black', ls='',marker='o',ms=4, label=r'BH $r_out=50 r_s$')





#plt.xscale('log')
#plt.yscale('log')



plt.legend()
plt.xlim(1e10,2e14)
#plt.ylim(1e1,2e20)#2e40
# Out:
# (10000000000.0, 200000000000000.0)
