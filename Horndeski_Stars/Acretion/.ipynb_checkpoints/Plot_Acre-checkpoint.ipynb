# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as font_manager
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
#from matplotlib.patches import Rectangle

from cycler import cycler

# %%
# estructura para latex
mpl.use("pgf")

# estilo de linea y grosor
mpl.rcParams['lines.linestyle'] = '-'
mpl.rcParams['lines.linewidth'] = 2.

# orden de los colores que usará
mpl.rcParams['axes.prop_cycle'] = cycler('color', ['#1f77b4', '#ff7f0e', '#2ca02c', 
                                                   '#d62728', '#9467bd', '#8c564b', '#e377c2', 
                                                   '#7f7f7f', '#bcbd22', '#17becf'])
#cycler(color=['r', 'g', 'b', 'y'])

# latex modo math
mpl.rcParams['mathtext.fontset'] = 'cm'  # Should be 'dejavusans' (default),
                                         # 'dejavuserif', 'cm' (Computer Modern), 'stix',
                                         # 'stixsans' or 'custom'
        
mpl.rcParams['mathtext.fallback_to_cm']= True # When True, use symbols from the Computer Modern
                                              # fonts when a symbol can not be found in one of
                                              # the custom math fonts.
    
# Texto
mpl.rcParams['font.family'] = 'serif' # serif, sans-serif, cursive, fantasy, monospace
cmfont = font_manager.FontProperties(fname=mpl.get_data_path() + '/fonts/ttf/cmr10.ttf')
mpl.rcParams['font.serif']=cmfont.get_name()
mpl.rcParams['font.size'] = 16 # tamaño de la letra

###
mpl.rcParams['pgf.texsystem'] = 'pdflatex'
mpl.rcParams['text.usetex'] = True
mpl.rcParams['pgf.rcfonts'] = False
mpl.rcParams['text.latex.preamble'] = [r'\usepackage{amssymb}'] # \usepackage{txfonts}


mpl.rcParams['pgf.preamble'] = ['\\usepackage{amssymb}']
###


#mpl.rcParams['axes.titlepad'] = 6.0     # pad between axes and title in points
mpl.rcParams['axes.labelpad'] = 3.0 #10.0     # space between label and axis
mpl.rcParams['axes.labelweight'] = 'normal'  # weight (grosor) of the x and y labels
mpl.rcParams['axes.labelcolor'] = 'black'
mpl.rcParams['axes.unicode_minus'] = False # use Unicode for the minus symbol
mpl.rcParams['axes.linewidth'] = 1     # edge linewidth, grosor del marco

#mpl.rcParams['axes.titlesize'] = 24
mpl.rcParams['axes.labelsize'] = 16
#mpl.rcParams['lines.markersize'] = 10


# display axis spines, muestra la linea de los marcos
mpl.rcParams['axes.spines.left'] = True
mpl.rcParams['axes.spines.bottom'] = True
mpl.rcParams['axes.spines.top'] = True
mpl.rcParams['axes.spines.right'] = True

# Figura
#mpl.rcParams['figure.dpi'] = 100 # figure dots per inch
mpl.rcParams['figure.figsize'] = [12, 9]# [4,3] # 
mpl.rcParams['figure.facecolor'] = 'white'     # figure facecolor
mpl.rcParams['figure.edgecolor'] = 'white'     # figure edgecolor
mpl.rcParams['savefig.dpi'] = 100

mpl.rcParams['xtick.labelsize'] = 15 #'large' # tamaño de los números de los ejes
mpl.rcParams['ytick.labelsize'] = 15 #'large'
mpl.rcParams['xtick.direction'] = 'out' # direction: {in, out, inout} señalamiento de los ejes
mpl.rcParams['ytick.direction'] = 'out' # direction: {in, out, inout}
mpl.rcParams['xtick.top'] = False # draw ticks on the top side
mpl.rcParams['ytick.right'] = False # draw ticks on the top side
#xtick.labeltop      : False   ## draw label on the top
mpl.rcParams['xtick.labelbottom'] = True    # draw label on the bottom

mpl.rcParams['xtick.major.bottom'] = True   # draw x axis bottom major ticks
#mpl.rcParams['xtick.major.top'] = True   # draw x axis top major ticks
mpl.rcParams['xtick.minor.bottom'] = False    ## draw x axis bottom minor ticks
#mpl.rcParams['xtick.minor.top'] = True    ## draw x axis top minor ticks

mpl.rcParams['xtick.minor.visible'] = True  # visibility of minor ticks on x-axis

#xtick.alignment     : center  ## alignment of xticks
#xtick.alignment     : center  ## alignment of xticks

# Legend
mpl.rcParams['legend.loc'] = 'best'
mpl.rcParams['legend.frameon'] = True # if True, draw the legend on a background patch
mpl.rcParams['legend.framealpha'] = 0.19 # 0.8 legend patch transparency
mpl.rcParams['legend.facecolor'] = 'inherit'  # inherit from axes.facecolor; or color spec
mpl.rcParams['legend.edgecolor'] = 'inherit' # background patch boundary color
mpl.rcParams['legend.fancybox'] = True     # if True, use a rounded box for the

#mpl.rcParams['legend.numpoints'] = 1 # the number of marker points in the legend line
#mpl.rcParams['legend.scatterpoints'] = 1 # number of scatter points
#mpl.rcParams['legend.markerscale'] = 1.0 # the relative size of legend markers vs. original
mpl.rcParams['legend.fontsize'] = 14 # 'medium' 'large'

## Dimensions as fraction of fontsize:
mpl.rcParams['legend.borderpad'] = 0.4  ## border whitespace espacio de los bordes con respecto al texto
mpl.rcParams['legend.labelspacing'] = 0.5  ## the vertical space between the legend entries
mpl.rcParams['legend.handlelength'] = 1.5  ## the length of the legend lines defauld 2
#mpl.rcParams['legend.handleheight'] = 0.7  ## the height of the legend handle
mpl.rcParams['legend.handletextpad'] = 0.8  ## the space between the legend line and legend text
#mpl.rcParams['legend.borderaxespad'] = 0.5  ## the border between the axes and legend edge
#mpl.rcParams['legend.columnspacing'] = 8.0  ## column separation
# Out:
# <ipython-input-2-7253cdea030d>:19: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   mpl.rcParams['mathtext.fallback_to_cm']= True # When True, use symbols from the Computer Modern
# <ipython-input-2-7253cdea030d>:19: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   mpl.rcParams['mathtext.fallback_to_cm']= True # When True, use symbols from the Computer Modern
# <ipython-input-2-7253cdea030d>:19: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   mpl.rcParams['mathtext.fallback_to_cm']= True # When True, use symbols from the Computer Modern
# ...

# %%
class OOMFormatter(mpl.ticker.ScalarFormatter):
    def __init__(self, order=0, fformat="%1.1f", offset=True, mathText=True):
        self.oom = order
        self.fformat = fformat
        mpl.ticker.ScalarFormatter.__init__(self,useOffset=offset,useMathText=mathText)
    
    def _set_orderOfMagnitude(self, nothing):
        self.orderOfMagnitude = self.oom
    
    def _set_format(self):
        self.format = self.fformat
        if self._useMathText:
            self.format = '$%s$' % mpl.ticker._mathdefault(self.format)

# %%
# más compactas
rsH = 2.19913
HF3 = np.loadtxt('F628rs_L3_1.dat', unpack=True)
HF32 = np.loadtxt('2F628rs_L3_1.dat', unpack=True)
HT3 = np.loadtxt('T628rs_L3_1.dat', unpack=True)
#mphi = 4.89141*10^-20 eV
#rout = 628rs=1381.76, rin=3.01 rs

rsBs = 1.27171
HTLInf = np.loadtxt('T799rs_L3_Inf.dat', unpack=True)
HFLInf = np.loadtxt('F1799rs_L3_Inf.dat', unpack=True)
HFLInf2 = np.loadtxt('2F1799rs_L3_Inf.dat', unpack=True)
#mphi = 2.8286*10^-20 eV
#rout = 799.04, rin=0

rsScH = 2.19913
SCHT = np.loadtxt('T1385rs_Sch.dat', unpack=True)
SCHF = np.loadtxt('F1385rs_Sch.dat', unpack=True)
SCHF2 = np.loadtxt('2F1385rs_Sch.dat', unpack=True)

# %% [markdown]
# ## esta

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 5.5), sharex=False, sharey=False) 

ax[0].plot(HTLInf[0]/rsBs, HTLInf[1], label =r'$c_{4}^{(1)}=1/2,\; d_{4}^{(-1)}=0$', color = '#566874')
ax[0].plot(HT3[0]/rsH, HT3[1], label =r'$c_{4}^{(1)}=1/2,\; d_{4}^{(-1)}=0$', color = '#4596cc')
ax[0].plot(SCHT[0]/rsScH, SCHT[1], color='black', ls=':', label=r'Schw. black hole')

#ax[0].axvspan(0, 3, color='#756f6b', alpha = 0.2)
ax[0].axvline(x=3, ymin=0, ymax=0.45, color='#756f6b', linestyle='-', alpha=0.5)
ax[0].axvline(x=3, ymin=0.58, ymax=1, color='#756f6b', linestyle='-', alpha=0.5)
ax[0].text(3.25, 730, r'ISCO',
        rotation=90, rotation_mode='anchor', c='black', fontsize = 14)

ax[0].set_ylabel(r'$T\,[K]$')
ax[0].set_xlabel(r'$r/r_s$')

###
ax[1].plot(HFLInf[0], HFLInf[1], label =r'$c_{4}^{(1)}=1/2,\; d_{4}^{(-1)}=0$', color = '#566874')
ax[1].plot(HF3[0], HF3[1], label =r'$c_{4}^{(1)}=1/2,\; d_{4}^{(-1)}=0$', color = '#4596cc')
ax[1].plot(SCHF[0], SCHF[1], color='black', ls=':', label=r'Schw. black hole')

ax[1].set_xlabel(r'$\nu [\mathrm{Hz}]$')
ax[1].set_ylabel(r'$\nu L(\nu) [\textrm{erg}\cdot\textrm{s}^{-1}]$')


#ax[1].set_xscale('log')
#ax[1].set_yscale('log')

ax[0].set_xlim(0,20)
ax[0].set_ylim(0,1600)

ax[1].set_xlim(1e10, 5e14)
ax[1].set_ylim(0, 2.3e40)

ax[0].legend(loc=(0.537,0.5),frameon=False, ncol=1,labelspacing=3)

ax[0].text(12.6, 1320, r'$\Lambda_3\gg \, M_{\mathrm{Pl}}^{1/3} m^{2/3} (\mathrm{EKG})$',
            rotation=0, rotation_mode='anchor', c='black', fontsize = 14)
ax[0].text(12.6, 1000, r'$\Lambda_3 = M_{\mathrm{Pl}}^{1/3} m^{2/3}$',
            rotation=0, rotation_mode='anchor', c='black', fontsize = 14)

ax[1].legend(loc=(0.537,0.5), frameon=False, ncol=1,labelspacing=3)

ax[1].text(3.15e14, 1.89e40, r'$\Lambda_3\gg \, M_{\mathrm{Pl}}^{1/3} m^{2/3} (\mathrm{EKG})$',
            rotation=0, rotation_mode='anchor', c='black', fontsize = 14)
ax[1].text(3.15e14, 1.43e40, r'$\Lambda_3 = M_{\mathrm{Pl}}^{1/3} m^{2/3}$',
            rotation=0, rotation_mode='anchor', c='black', fontsize = 14)
# Out:
# Text(315000000000000.0, 1.43e+40, '$\\Lambda_3 = M_{\\mathrm{Pl}}^{1/3} m^{2/3}$')

# %%
plt.savefig('acret.pgf', 
            #This is simple recomendation for publication plots
            dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

#plt.savefig('rho_profile.pgf')
plt.savefig("acret.png",dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 5.5), sharex=False, sharey=False) 

ax[0].plot(HTLInf[0]/rsBs, HTLInf[1], label =r'$c_1=1/2,\; d_1=0$', color = '#566874')
ax[0].plot(HT3[0]/rsH, HT3[1], label =r'$c_1=1/2,\; d_1=0$', color = '#4596cc')
ax[0].plot(SCHT[0]/rsScH, SCHT[1], color='black', ls=':', label=r'agujero negro de Schw.')

#ax[0].axvspan(0, 3, color='#756f6b', alpha = 0.2)
ax[0].axvline(x=3, ymin=0, ymax=0.45, color='#756f6b', linestyle='-', alpha=0.5)
ax[0].axvline(x=3, ymin=0.6, ymax=1, color='#756f6b', linestyle='-', alpha=0.5)
ax[0].text(3.25, 730, r'UOCE',
        rotation=90, rotation_mode='anchor', c='black', fontsize = 14)

ax[0].set_ylabel(r'$T\,[K]$')
ax[0].set_xlabel(r'$r/r_s$')

###
ax[1].plot(HFLInf[0], HFLInf[1], label =r'$c_1=1/2,\; d_1=0$', color = '#566874')
ax[1].plot(HF3[0], HF3[1], label =r'$c_1=1/2,\; d_1=0$', color = '#4596cc')
ax[1].plot(SCHF[0], SCHF[1], color='black', ls=':', label=r'agujero negro de Schw.')

ax[1].set_xlabel(r'$\nu [\mathrm{Hz}]$')
ax[1].set_ylabel(r'$\nu L(\nu) [\textrm{erg}\cdot\textrm{s}^{-1}]$')


#ax[1].set_xscale('log')
#ax[1].set_yscale('log')

ax[0].set_xlim(0,20)
ax[0].set_ylim(0,1600)

ax[1].set_xlim(1e10, 5e14)
ax[1].set_ylim(0, 2.3e40)

ax[0].legend(loc=(0.537,0.5),frameon=False, ncol=1,labelspacing=3)

ax[0].text(12.6, 1320, r'$\Lambda_3\gg \, M_{\mathrm{Pl}}^{1/3} m^{2/3} (\mathrm{EKG})$',
            rotation=0, rotation_mode='anchor', c='black', fontsize = 14)
ax[0].text(12.6, 1000, r'$\Lambda_3 = M_{\mathrm{Pl}}^{1/3} m^{2/3}$',
            rotation=0, rotation_mode='anchor', c='black', fontsize = 14)

ax[1].legend(loc=(0.537,0.5), frameon=False, ncol=1,labelspacing=3)

ax[1].text(3.15e14, 1.89e40, r'$\Lambda_3\gg \, M_{\mathrm{Pl}}^{1/3} m^{2/3} (\mathrm{EKG})$',
            rotation=0, rotation_mode='anchor', c='black', fontsize = 14)
ax[1].text(3.15e14, 1.43e40, r'$\Lambda_3 = M_{\mathrm{Pl}}^{1/3} m^{2/3}$',
            rotation=0, rotation_mode='anchor', c='black', fontsize = 14)
# Out:
# Text(315000000000000.0, 1.43e+40, '$\\Lambda_3 = M_{\\mathrm{Pl}}^{1/3} m^{2/3}$')

# %%
plt.savefig('acret_T.pgf', 
            #This is simple recomendation for publication plots
            dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

#plt.savefig('rho_profile.pgf')
plt.savefig("acret_T.png",dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 5.5), sharex=False, sharey=False) 

ax[0].plot(HTLInf[0]/rsBs, HTLInf[1], label =r'$c_{4}^{(1)}=1/2,\; d_{4}^{(-1)}=0$', color = '#566874')
ax[0].plot(HT3[0]/rsH, HT3[1], label =r'$c_{4}^{(1)}=1/2,\; d_{4}^{(-1)}=0$', color = '#4596cc')
ax[0].plot(SCHT[0]/rsScH, SCHT[1], color='black', ls=':', label=r'Schw. black hole')

ax[0].axvspan(0, 3, color='#756f6b', alpha = 0.2)
ax[0].axvline(x=3, ymin=0, ymax=0.45, color='#756f6b', linestyle='-', alpha=0.5)
ax[0].axvline(x=3, ymin=0.58, ymax=1, color='#756f6b', linestyle='-', alpha=0.5)
ax[0].text(3.25, 730, r'ISCO',
        rotation=90, rotation_mode='anchor', c='black', fontsize = 14)

ax[0].set_ylabel(r'$T\,[K]$')
ax[0].set_xlabel(r'$r/r_s$')

###
ax[1].plot(HFLInf2[0], HFLInf2[1], label =r'$c_{4}^{(1)}=1/2,\; d_{4}^{(-1)}=0$', color = '#566874')
ax[1].plot(HF32[0], HF32[1], label =r'$c_{4}^{(1)}=1/2,\; d_{4}^{(-1)}=0$', color = '#4596cc')
ax[1].plot(SCHF2[0], SCHF2[1], color='black', ls=':', label=r'Schw. black hole')

ax[1].set_xlabel(r'$\nu [\mathrm{Hz}]$')
ax[1].set_ylabel(r'$\nu L(\nu) [\textrm{erg}\cdot\textrm{s}^{-1}]$')


ax[1].set_xscale('log')
ax[1].set_yscale('log')

ax[0].set_xlim(0,20)
ax[0].set_ylim(0,1600)

ax[1].set_xlim(1e10, 1e16)
ax[1].set_ylim(1e-11, 3e43)

ax[0].legend(loc=(0.537,0.5),frameon=False, ncol=1,labelspacing=3)

ax[0].text(12.6, 1320, r'$\Lambda_3\gg \, M_{\mathrm{Pl}}^{1/3} m^{2/3} (\mathrm{EKG})$',
            rotation=0, rotation_mode='anchor', c='black', fontsize = 14)
ax[0].text(12.6, 1000, r'$\Lambda_3 = M_{\mathrm{Pl}}^{1/3} m^{2/3}$',
            rotation=0, rotation_mode='anchor', c='black', fontsize = 14)

ax[1].legend(loc='lower left', frameon=False, ncol=1,labelspacing=3)

ax[1].text(5.3e10, 1.0e8, r'$\Lambda_3\gg \, M_{\mathrm{Pl}}^{1/3} m^{2/3} (\mathrm{EKG})$',
            rotation=0, rotation_mode='anchor', c='black', fontsize = 14)
ax[1].text(5.3e10, 1.0e-3, r'$\Lambda_3 = M_{\mathrm{Pl}}^{1/3} m^{2/3}$',
            rotation=0, rotation_mode='anchor', c='black', fontsize = 14)
# Out:
# Text(53000000000.0, 0.001, '$\\Lambda_3 = M_{\\mathrm{Pl}}^{1/3} m^{2/3}$')

# %% [markdown]
# ## esta

# %%
rsBs = 1.27171
HTLInf = np.loadtxt('T_adm_L3_inf.dat', unpack=True)

rsH = 2.19913
HF3 = np.loadtxt('T_adm_L3_1.dat', unpack=True)


SCHT2 = np.loadtxt('Schw2_Ad.dat', unpack=True)
SCHT = np.loadtxt('Schw_Ad.dat', unpack=True)

# %%
# M = 27.6867
# R95 = 3.31263
M1 = 27.6867 # H
M2 = 15.90897267397468 # BS
Rs1 = 2*M1/(8*np.pi) # H
Rs2 = 2*M2/(8*np.pi) # BS

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 5.5), sharex=False, sharey=False) 

#ax[0].yaxis.set_major_formatter(OOMFormatter(-4, "%1.1f"))
ax[0].ticklabel_format(axis='y', style='sci', scilimits=(-4,-4))

ax[0].plot(HTLInf[0], HTLInf[1], label =r'$c_{4}^{(1)}=1/2,\; d_{4}^{(-1)}=0$', color = '#566874')
ax[0].plot(SCHT2[0], SCHT2[1], color='black', ls=':', label=r'Schw. black hole')

ax[0].axvline(x=3, ymin=0, ymax=0.67, color='#756f6b', linestyle='-', alpha=0.5)
ax[0].axvline(x=3, ymin=0.8, ymax=1, color='#756f6b', linestyle='-', alpha=0.5)
ax[0].text(3.25, 1.0e-04, r'ISCO',
            rotation=90, rotation_mode='anchor', c='black', fontsize = 14)

ax[0].set_ylabel(r'$T\, [\dot{M}_{0}/ (\sigma r_s^{2})]$')
ax[0].set_xlabel(r'$r/r_s$')

###
ax[1].ticklabel_format(axis='y', style='sci', scilimits=(-3,-3))
ax[1].plot(HF3[0], HF3[1], label =r'$c_{4}^{(1)}=1/2,\; d_{4}^{(-1)}=0$', color = '#4596cc')
ax[1].plot(SCHT[0], SCHT[1], color='black', ls=':', label=r'Schw. black hole')

#ax[1].axvspan(0, 3, color='#756f6b', alpha = 0.2)
ax[1].axvline(x=3, ymin=0, ymax=0.85, color='#756f6b', linestyle='-', alpha=0.5)
ax[1].axvline(x=3, ymin=0.985, ymax=1, color='#756f6b', linestyle='-', alpha=0.5)
ax[1].text(3.15, 6.0e-04, r'ISCO',
        rotation=90, rotation_mode='anchor', c='black', fontsize = 14)



ax[1].set_ylabel(r'$T\, [\dot{M}_{0}/ (\sigma r_s^{2})]$')
ax[1].set_xlabel(r'$r/r_s$')


#ax[1].set_xscale('log')
ax[0].set_yscale('log')
ax[1].set_yscale('log')

ax[0].set_xlim(0,25)
ax[0].set_ylim(1e-07,25e-4)

ax[1].set_xlim(0, 25)
ax[1].set_ylim(1e-07,25e-4)
#ax[1].set_ylim(1e-11, 3e43)

r95 =6.01466/Rs2
ax[0].axvline(x=r95, color='#756f6b', linestyle='-', alpha=0.5)
ax[0].text(5.7/Rs2, 1.1e-07, r'$R_{95}=$'+' ${:.2f} r_s$'.format(r95), c = 'black',
            rotation=90, rotation_mode='anchor')

r95 = 3.31263/Rs1
ax[1].axvline(x=r95, color='#756f6b', linestyle='-', alpha=0.4)
ax[1].text(1.25, 1.05e-07, r'$R_{95}=$'+' ${:.2f} r_s$'.format(r95), c = 'black',
            rotation=90, rotation_mode='anchor')

ax[0].legend(loc=(0.55, 0.66),frameon=False, ncol=1,labelspacing=3)

ax[0].text(16, 3.0e-04, r'$\Lambda_3\gg \, M_{\mathrm{Pl}}^{1/3} m^{2/3} (\mathrm{EKG})$',
            rotation=0, rotation_mode='anchor', c='black', fontsize = 14)
#ax[0].text(12.6, 1000, r'$\Lambda_3 = M_{\mathrm{Pl}}^{1/3} m^{2/3}$',
#            rotation=0, rotation_mode='anchor', c='black', fontsize = 14)

ax[1].legend(loc=(0.55, 0.66), frameon=False, ncol=1,labelspacing=3)

ax[1].text(16.1, 3.0e-04, r'$\Lambda_3 = M_{\mathrm{Pl}}^{1/3} m^{2/3}$',
            rotation=0, rotation_mode='anchor', c='black', fontsize = 14)
# Out:
# Text(16.1, 0.0003, '$\\Lambda_3 = M_{\\mathrm{Pl}}^{1/3} m^{2/3}$')

# %%
plt.savefig('acret2.pgf', 
            #This is simple recomendation for publication plots
            dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

#plt.savefig('rho_profile.pgf')
plt.savefig("acret2.png",dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

# %%
# M = 27.6867
# R95 = 3.31263
M1 = 27.6867 # H
M2 = 15.90897267397468 # BS
Rs1 = 2*M1/(8*np.pi) # H
Rs2 = 2*M2/(8*np.pi) # BS

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 5.5), sharex=False, sharey=False) 

#ax[0].yaxis.set_major_formatter(OOMFormatter(-4, "%1.1f"))
ax[0].ticklabel_format(axis='y', style='sci', scilimits=(-4,-4))

ax[0].plot(HTLInf[0], HTLInf[1], label =r'$c_1=1/2,\; d_1=0$', color = '#566874')
ax[0].plot(SCHT2[0], SCHT2[1], color='black', ls=':', label=r'agujero negro de Schw.')

ax[0].axvline(x=3, ymin=0, ymax=0.67, color='#756f6b', linestyle='-', alpha=0.5)
ax[0].axvline(x=3, ymin=0.82, ymax=1, color='#756f6b', linestyle='-', alpha=0.5)
ax[0].text(3.25, 1.0e-04, r'UOCE',
            rotation=90, rotation_mode='anchor', c='black', fontsize = 14)

ax[0].set_ylabel(r'$T\, [\dot{M}_{0}/ (\sigma r_s^{2})]$')
ax[0].set_xlabel(r'$r/r_s$')

###
ax[1].ticklabel_format(axis='y', style='sci', scilimits=(-3,-3))
ax[1].plot(HF3[0], HF3[1], label =r'$c_1=1/2,\; d_1=0$', color = '#4596cc')
ax[1].plot(SCHT[0], SCHT[1], color='black', ls=':', label=r'agujero negro de Schw.')

#ax[1].axvspan(0, 3, color='#756f6b', alpha = 0.2)
ax[1].axvline(x=3, ymin=0, ymax=0.82, color='#756f6b', linestyle='-', alpha=0.5)
ax[1].axvline(x=3, ymin=0.985, ymax=1, color='#756f6b', linestyle='-', alpha=0.5)
ax[1].text(3.2, 5.0e-04, r'UOCE',
        rotation=90, rotation_mode='anchor', c='black', fontsize = 14)



ax[1].set_ylabel(r'$T\, [\dot{M}_{0}/ (\sigma r_s^{2})]$')
ax[1].set_xlabel(r'$r/r_s$')


#ax[1].set_xscale('log')
ax[0].set_yscale('log')
ax[1].set_yscale('log')

ax[0].set_xlim(0,25)
ax[0].set_ylim(1e-07,25e-4)

ax[1].set_xlim(0, 25)
ax[1].set_ylim(1e-07,25e-4)
#ax[1].set_ylim(1e-11, 3e43)

r95 =6.01466/Rs2
ax[0].axvline(x=r95, color='#756f6b', linestyle='-', alpha=0.5)
ax[0].text(5.7/Rs2, 1.1e-07, r'$R_{95}=$'+' ${:.2f} r_s$'.format(r95), c = 'black',
            rotation=90, rotation_mode='anchor')

r95 = 3.31263/Rs1
ax[1].axvline(x=r95, color='#756f6b', linestyle='-', alpha=0.4)
ax[1].text(1.25, 1.05e-07, r'$R_{95}=$'+' ${:.2f} r_s$'.format(r95), c = 'black',
            rotation=90, rotation_mode='anchor')

ax[0].legend(loc=(0.55, 0.66),frameon=False, ncol=1,labelspacing=3)

ax[0].text(16, 3.0e-04, r'$\Lambda_3\gg \, M_{\mathrm{Pl}}^{1/3} m^{2/3} (\mathrm{EKG})$',
            rotation=0, rotation_mode='anchor', c='black', fontsize = 14)
#ax[0].text(12.6, 1000, r'$\Lambda_3 = M_{\mathrm{Pl}}^{1/3} m^{2/3}$',
#            rotation=0, rotation_mode='anchor', c='black', fontsize = 14)

ax[1].legend(loc=(0.55, 0.66), frameon=False, ncol=1,labelspacing=3)

ax[1].text(16.1, 3.0e-04, r'$\Lambda_3 = M_{\mathrm{Pl}}^{1/3} m^{2/3}$',
            rotation=0, rotation_mode='anchor', c='black', fontsize = 14)
# Out:
# Text(16.1, 0.0003, '$\\Lambda_3 = M_{\\mathrm{Pl}}^{1/3} m^{2/3}$')

# %%
plt.savefig('acret2_T.pgf', 
            #This is simple recomendation for publication plots
            dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

#plt.savefig('rho_profile.pgf')
plt.savefig("acret2_T.png",dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

# %%
plt.plot(HL3[0], HL3[1], label =r'$r_{out}=628 rs$', color = '#566874')
plt.plot(HL31[0], HL31[1], label =r'$r_{out}=500 rs$', color = 'red')
plt.plot(HL32[0], HL32[1], label =r'$r_{out}=100 rs$', color = 'black')
plt.plot(HL33[0], HL33[1], label =r'$r_{out}=10 rs$', color = 'orange')

plt.yscale('log')
plt.xscale('log')

plt.xlabel(r'$\nu [\mathrm{H_z}]$')
plt.ylabel(r'$\nu L(\nu) [\mathrm{erg} s^{-1}]$')

plt.ylim(1e-40,1e45)
plt.xlim(1e10,5e14)

plt.legend()
