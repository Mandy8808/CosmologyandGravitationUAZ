# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy.interpolate import interp1d, Rbf, InterpolatedUnivariateSpline

# %%
F1 = 25 #30 # Axes font size
F2 = 21 #18 # Legend font size
line = 3.0 # Line width


#rc = rcParams # Font structure is called rc now
#rc['text.usetex'] = True # Tex fonts
matplotlib.rcParams['font.family'] = 'serif'
matplotlib.rcParams['font.serif'].insert(0,'cm') # Default font is computer modern for latex
matplotlib.rcParams['font.size'] = F1
matplotlib.rcParams['xtick.labelsize'] = 'small'
matplotlib.rcParams['ytick.labelsize'] = 'small'
matplotlib.rcParams['legend.fontsize'] = F2


#params = {'text.usetex': False, 'mathtext.fontset': 'stixsans'} 
#plt.rcParams.update(params) 
#tipo de letra
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
#matplotlib.pyplot.title(r'ABC123 vs $\mathrm{ABC123}^{123}$')

# %%
class OOMFormatter(matplotlib.ticker.ScalarFormatter):
    def __init__(self, order=0, fformat="%1.1f", offset=True, mathText=True):
        self.oom = order
        self.fformat = fformat
        matplotlib.ticker.ScalarFormatter.__init__(self,useOffset=offset,useMathText=mathText)
    
    def _set_orderOfMagnitude(self, nothing):
        self.orderOfMagnitude = self.oom
    
    def _set_format(self):
        self.format = self.fformat
        if self._useMathText:
            self.format = '$%s$' % matplotlib.ticker._mathdefault(self.format)

# %% [markdown]
# figura de pegado

# %%
# Case Beyond Horndeski with X, 
# phi0=0.007
# eta=-0.3
datag = np.loadtxt('Funcg.dat', usecols=(0,1)) 
dataN = np.loadtxt('FuncN.dat', usecols=(0,1)) 
dataM = np.loadtxt('FuncM.dat', usecols=(0,1)) 

datag_M = np.loadtxt('FuncgM.dat', usecols=(0,1)) 
dataN_M = np.loadtxt('FuncNM.dat', usecols=(0,1))

# %%
#  Uso raiz, pq mi definición de NN y gg es al cuadrado
NN = lambda r: np.power(1-2*Mass/r,0.5)
gg = lambda r: np.power((1-2*Mass/r)**-1,0.5)

# %%
rad = np.arange(5., datag[-1,0], 0.1)
Mass = dataM[-1,1]

fig, ax = plt.subplots(figsize=(12,9))

matplotlib.rcParams['font.size'] = 20

#ax.yaxis.set_major_formatter(OOMFormatter(-4, "%1.1f"))
#ax.ticklabel_format(axis='y', style='sci', scilimits=(-4,-4))

ax.plot(datag[:,0],datag[:,1],'k--', label=r'$g$')
ax.plot(rad, gg(rad),'k:', label=r'$g_{\mathrm{schw}}$')
#ax.plot(rad, NN(rad),'b:', label='metric Schw. term N')

# These are in unitless percentages of the figure size. (0,0 is bottom left)
left, bottom, width, height = [0.53, 0.53, 0.35, 0.3]
ax1 = fig.add_axes([left, bottom, width, height])

ax1.plot(dataM[:,0],dataM[:,1],'k-')
#ax.plot(dataN[:,0],dataN[:,1],'b--', label='metric term N')

angle2=0
plt.figtext(.78, .79, '{0:.3f}'.format(Mass), {'color': 'black', 'fontsize': 20},
            rotation=angle2, rotation_mode='anchor')


ax1.set_xticks(np.arange(0, 20, 2.5))

x1, x2, y1, y2 = datag[0,0], datag[-1,0], dataphi[0,1], dataphi[-1,1]
ax.set_xlim(x1, x2) # apply the x-limits
#ax.set_ylim(0.5, 1.4)
#ax1.set_ylim(0.99, 1.03)
ax1.set_xlim(x1, x2) #(0, 20)

#ax.set_ylabel(r'$g$')#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax.set_xlabel(r'$\bar{r}$', fontsize=30)#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

matplotlib.rcParams['font.size'] = 25
ax1.set_ylabel(r'$\bar{M}$') #
#ax1.set_xlabel(r'$\bar{r}$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')
ax.set_title(r'$\bar{\eta}=-0.3$', loc='right', fontsize=25)
ax.set_title(r'$\bar{\sigma}_{0}=0.03$', loc='left', fontsize=25)

matplotlib.rcParams['legend.fontsize'] = 15
#ax.legend(('Numerical solution', 'Analytical fitting'),loc='upper right',frameon=False)
#ax1.legend(loc='upper right',frameon=False)
matplotlib.rcParams['legend.fontsize'] = 28


ax.legend(loc='upper left',frameon=False);

# %%
rad = np.arange(3, dataN[-1,0], 0.1)
Mass = dataM[-1,1]

fig, ax = plt.subplots(figsize=(12,9))

matplotlib.rcParams['font.size'] = 20

#ax.yaxis.set_major_formatter(OOMFormatter(-4, "%1.1f"))
#ax.ticklabel_format(axis='y', style='sci', scilimits=(-4,-4))

ax.plot(dataN_M[:,0], dataN_M[:,1],'k--', label=r'$N$')
ax.plot(rad, NN(rad),'k:', label=r'$N_{\mathrm{schw}}$')
#ax.plot(rad, NN(rad),'b:', label='metric Schw. term N')

# These are in unitless percentages of the figure size. (0,0 is bottom left)
left, bottom, width, height = [0.52, 0.25, 0.35, 0.35]
ax1 = fig.add_axes([left, bottom, width, height])


ax1.plot(dataN[:,0],dataN[:,1],'r-', label=r'$\hat{N}$')
ax1.plot(rad, NN(rad),'k:')
#ax.plot(dataN[:,0],dataN[:,1],'b--', label='metric term N')

ax1.set_xticks(np.arange(0, 20, 2.5))
#ax1.set_yticks(np.arange(0, 1.25, .05))

x1, x2, y1, y2 = datag[0,0], datag[-1,0], dataphi[0,1], dataphi[-1,1]
ax.set_xlim(x1, x2) # apply the x-limits
ax.set_ylim(0.7, .98)
ax1.set_ylim(0.7, 1.25)
ax1.set_xlim(x1, x2)

#ax.set_ylabel(r'$g$')#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax.set_xlabel(r'$\bar{r}$', fontsize=27)#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

matplotlib.rcParams['font.size'] = 20
#ax1.set_ylabel(r'$\bar{M}$') #
#ax1.set_xlabel(r'$\bar{r}$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')
ax.set_title(r'$\bar{\eta}=-0.3$', loc='right', fontsize=25)
ax.set_title(r'$\bar{\sigma}_{0}=0.03$', loc='left', fontsize=25)

matplotlib.rcParams['legend.fontsize'] = 20
#ax.legend(('Numerical solution', 'Analytical fitting'),loc='upper right',frameon=False)
ax1.legend(loc='lower right',frameon=False)
matplotlib.rcParams['legend.fontsize'] = 28
ax.legend(loc='upper left',frameon=False);

# %%
dataBHXm109 = np.loadtxt('BHXm109.dat', usecols=(0,1))
dataBHX109 = np.loadtxt('BHX109.dat', usecols=(0,1))

dataBHXMm109 = np.loadtxt('BHX_Mm109.dat', usecols=(0,1))
dataBHXM109 = np.loadtxt('BHX_M109.dat', usecols=(0,1))

#sigma=0.3

dataphiKG = np.loadtxt('FuncsigmaKG.dat', usecols=(0,1)) 
dataMKG = np.loadtxt('M_KG.dat', usecols=(0,1)) 

#beyond X Model I
#dataM = np.loadtxt('FuncM.dat', usecols=(0,1)) 
#dataphi = np.loadtxt('FuncsigmaM.dat', usecols=(0,1))

dataM_P = np.loadtxt('M_BHX_P.dat', usecols=(0,1)) 
dataphi_P = np.loadtxt('FuncsigmaBHX_P.dat', usecols=(0,1))

#beyond X^2 model II
dataBHM = np.loadtxt('XX_2_masa_Profile.dat', usecols=(0,1)) 
dataBHphi = np.loadtxt('XX_2_sigma_Profile.dat', usecols=(0,1)) 

dataBHP = np.loadtxt('XX_2_masa_Profile_Pos.dat', usecols=(0,1)) 
dataBHPphi = np.loadtxt('XX_2_sigma_Profile_Pos.dat', usecols=(0,1))

# %%
rad = np.arange(0,7.5, 0.1)
#IntM=InterpolatedUnivariateSpline(dataM_P [:,0], dataM_P [:,1])
#ext=np.array([[dataM_P[-1,0], dataM_P[-1,1]], [16, dataM_P[-1,1]]])

fig, ax = plt.subplots(figsize=(12,9))

matplotlib.rcParams['font.size'] = 20

#ax.yaxis.set_major_formatter(OOMFormatter(-4, "%1.1f"))
#ax.ticklabel_format(axis='y', style='sci', scilimits=(-4,-4))
# [marker][line][color]

ax.plot(dataBHXMm109[:,0], dataBHXMm109[:,1],'b:',label=r'$\mathrm{Model\; I\; with\;} \bar{\eta}=-0.109$')
ax.plot(dataBHXM109[:,0], dataBHXM109[:,1],'b--',label=r'$\mathrm{Model\; I\; with\;} \bar{\eta}=0.109$')

ax.plot(dataBHM [:,0], dataBHM [:,1],'r-',marker='.', markersize='7',label=r'$\mathrm{Model\;II\; with\;} \bar{\eta}=-0.3$')
ax.plot(dataBHP [:,0], dataBHP [:,1],'r-.',label=r'$\mathrm{Model\; II\; with\;} \bar{\eta}=0.3 $')

ax.plot(dataMKG [:,0], dataMKG [:,1],'-', color='darkgrey', label='Einstein-Klein Gordon') #,label='Case II'


#angle2=0
#plt.figtext(.7, .73, r'boson stars', {'color': '0', 'fontsize': 20},
#            rotation=angle2, rotation_mode='anchor')

angle2=0
plt.figtext(.15, .83, r'$\bar{\sigma}_{0}=0.03$', {'color': '0', 'fontsize': 25},
            rotation=angle2, rotation_mode='anchor')

#x1, x2, y1, y2 = datag[0,0], datag[-1,0], dataphi[0,1], dataphi[-1,1]
ax.set_xlim(0, 17.5) # apply the x-li4mits
#ax.set_ylim(0.5, 1.4)

ax.set_ylabel(r'$\bar{M}$', fontsize=30)#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax.set_xlabel(r'$\bar{r}$', fontsize=30)#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

matplotlib.rcParams['font.size'] = 25
#ax1.set_xlabel(r'$\bar{r}$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')
#ax.set_title(r'$\bar{\eta}=-0.3$', loc='right', fontsize=25)
#ax.set_title(r'$\bar{\sigma}_{0}=0.03$', loc='left', fontsize=25)

matplotlib.rcParams['legend.fontsize'] = 25
#ax.legend(('Numerical solution', 'Analytical fitting'),loc='upper right',frameon=False)
ax.legend(loc=(.5, .15) ,frameon=False)
#matplotlib.rcParams['legend.fontsize'] = 25
#ax.legend(loc=(.72, .6),frameon=False);

# %%
#ext=np.array([[dataphi_P[-1,0]+0.5, dataphi_P[-1,1]], [16, dataphi_P[-1,1]]])
#Intphi=InterpolatedUnivariateSpline(dataphi_P[:,0], dataphi_P[:,1])
rad = np.arange(0,8, 0.1)

fig, ax = plt.subplots(figsize=(12,9))

matplotlib.rcParams['font.size'] = 25

#ax.yaxis.set_major_formatter(OOMFormatter(-4, "%1.1f"))
#ax.ticklabel_format(axis='y', style='sci', scilimits=(-2,-2))

ax.plot(dataBHXm109[:,0], dataBHXm109[:,1],'b:',label=r'$\mathrm{Model\; I\; with\;} \bar{\eta}=-0.109$')
ax.plot(dataBHX109[:,0], dataBHX109[:,1],'b:',label=r'$\mathrm{Model\; I\; with\;} \bar{\eta}=0.109$')

ax.plot(dataBHphi[:,0], dataBHphi[:,1],'r-',marker='.', markersize='7', label=r'$\mathrm{Model\;II\; with\;} \bar{\eta}=-0.3$')
ax.plot(dataBHPphi[:,0], dataBHPphi[:,1],'r-.',label=r'$\mathrm{Model\; II\; with\;} \bar{\eta}=0.3$')

ax.plot(dataphiKG[:,0], dataphiKG[:,1],'-',color='darkgrey', label='Einstein-Klein Gordon')

#angle2=-62
#plt.figtext(.26, .642, r'boson stars', {'color': '0', 'fontsize': 20},
#            rotation=angle2, rotation_mode='anchor')


#x1, x2, y1, y2 = datag[0,0], datag[-1,0], dataphi[0,1], dataphi[-1,1]
#ax.set_xlim(0, 40) # apply the x-limits
#ax.set_ylim(-4, -1.4)
ax.set_xlim(0, 17.5) # apply the x-limits



ax.set_ylabel(r'$\bar{\sigma}$', fontsize=30)#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax.set_xlabel(r'$\bar{r}$', fontsize=30)#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

matplotlib.rcParams['font.size'] = 25
#ax1.set_xlabel(r'$\bar{r}$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')
#ax.set_title(r'$\bar{\eta}=-0.3$', loc='right', fontsize=25)
#ax.set_title(r'$\bar{\sigma}_{0}=0.007$', loc='left', fontsize=25)

matplotlib.rcParams['legend.fontsize'] = 25
ax.legend(loc='upper right',frameon=False)
#ax.legend(loc=0,frameon=False)
#matplotlib.rcParams['legend.fontsize'] = 25
#ax.legend(loc=(.72, .8),frameon=False);

# %%
dataBHXgm109 = np.loadtxt('BHXgm109.dat', usecols=(0,1))
dataBHgX109 = np.loadtxt('BHXg109.dat', usecols=(0,1))

dataBHXXgm03 = np.loadtxt('BHXXgm03.dat', usecols=(0,1))
dataBHgXX03 = np.loadtxt('BHXXg03.dat', usecols=(0,1))

datagKG = np.loadtxt('KGg.dat', usecols=(0,1))

# %%
#ext=np.array([[dataphi_P[-1,0]+0.5, dataphi_P[-1,1]], [16, dataphi_P[-1,1]]])
#Intphi=InterpolatedUnivariateSpline(dataphi_P[:,0], dataphi_P[:,1])
rad = np.arange(0,8, 0.1)

fig, ax = plt.subplots(figsize=(12,9))

matplotlib.rcParams['font.size'] = 25

#ax.yaxis.set_major_formatter(OOMFormatter(-4, "%1.1f"))
#ax.ticklabel_format(axis='y', style='sci', scilimits=(-2,-2))

ax.plot(dataBHXgm109[:,0], dataBHXgm109[:,1],'b:',label=r'$\mathrm{Model\; I\; with\;} \bar{\eta}=-0.109$')
ax.plot(dataBHgX109[:,0], dataBHgX109[:,1],'b:',label=r'$\mathrm{Model\; I\; with\;} \bar{\eta}=0.109$')

ax.plot(dataBHXXgm03[:,0], dataBHXXgm03[:,1],'r-',marker='.', markersize='7', label=r'$\mathrm{Model\;II\; with\;} \bar{\eta}=-0.3$')
ax.plot(dataBHgXX03[:,0], dataBHgXX03[:,1],'r-.',label=r'$\mathrm{Model\; II\; with\;} \bar{\eta}=0.3$')

ax.plot(datagKG[:,0], datagKG[:,1],'-',color='darkgrey', label='Einstein-Klein Gordon')

#angle2=-62
#plt.figtext(.26, .642, r'boson stars', {'color': '0', 'fontsize': 20},
#            rotation=angle2, rotation_mode='anchor')


#x1, x2, y1, y2 = datag[0,0], datag[-1,0], dataphi[0,1], dataphi[-1,1]
#ax.set_xlim(0, 40) # apply the x-limits
#ax.set_ylim(-4, -1.4)
ax.set_xlim(0, 17.5) # apply the x-limits



ax.set_ylabel(r'$g$', fontsize=30)#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax.set_xlabel(r'$\bar{r}$', fontsize=30)#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

matplotlib.rcParams['font.size'] = 25
#ax1.set_xlabel(r'$\bar{r}$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')
#ax.set_title(r'$\bar{\eta}=-0.3$', loc='right', fontsize=25)
#ax.set_title(r'$\bar{\sigma}_{0}=0.007$', loc='left', fontsize=25)

matplotlib.rcParams['legend.fontsize'] = 25
ax.legend(loc='lower center',frameon=False)
#ax.legend(loc=0,frameon=False)
#matplotlib.rcParams['legend.fontsize'] = 25
#ax.legend(loc=(.72, .8),frameon=False);

# %% [markdown]
# dataphi[0,1]

# %%
dataV = np.loadtxt('Vanis.dat', usecols=(0,1))

# %%
fig, ax = plt.subplots(figsize=(12,9))

matplotlib.rcParams['font.size'] = 20

#ax.yaxis.set_major_formatter(OOMFormatter(-4, "%1.1f"))
#ax.ticklabel_format(axis='y', style='sci', scilimits=(-4,-4))

ax.yaxis.set_major_formatter(OOMFormatter(-4, "%1.1f"))
ax.ticklabel_format(axis='y', style='sci', scilimits=(-6,-6)) # da el exponente
ax.plot(dataV[:,0],dataV[:,1],'k--', label=r'$h(\bar{r})$') #=(\bar{\sigma}´)^{2}N^{2}-g^{2}\bar{\sigma}^{2}\bar{\omega}
ax.plot(dataV[:,0],dataV[:,1],'rx', label='Viable region')

#ax.set_ylabel(r'$g$')#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax.set_xlabel(r'$\bar{r}$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

matplotlib.rcParams['legend.fontsize'] = 25
#ax.legend(('Numerical solution', 'Analytical fitting'),loc='upper right',frameon=False)
ax.set_title(r'$\bar{\eta}=-0.3$', loc='right', fontsize=20)
ax.legend(loc=(.6, .1),frameon=False)

# %%
dataV = np.loadtxt('VanisX_1.dat', usecols=(0,1)) 
dataV2 = np.loadtxt('VanisX_2.dat', usecols=(0,1)) 

inter1 = np.array([[8.9595],[0.000884161]]) # R_95, V[] caso I con 0.03
viabl1 = np.array([[12.55],[4.7*10**-5]])

inter2 = np.array([[13.181],[0.000256172]]) # R_95, V[] caso II con 0.015
viabl2 = np.array([[16.22],[4.7*10**-5]])

dataP = np.loadtxt('D_3em02.dat', usecols=(0,1)) 

V=InterpolatedUnivariateSpline(dataV[:,0], np.log10(dataV[:,1]))

# %%
fig, ax = plt.subplots(figsize=(12,9))

rad=np.arange(0,30, 0.01)

matplotlib.rcParams['font.size'] = 20

#ax.yaxis.set_major_formatter(OOMFormatter(-4, "%1.1f"))
#ax.ticklabel_format(axis='y', style='sci', scilimits=(-3,-3)) # da el exponente

#ax.plot(dataV[:,0], np.log10(dataV[:,1]),'k--', label=r'$\bar{M}=0.681$')
ax.plot(rad, V(rad),'k:', label=r'$\bar{M}=0.681$')
ax.plot([8.9595],np.log10([0.000884161]),'ro')
#ax.plot([12.55],np.log10([4.7*10**-5]),'kv')

ax.plot(dataV2[:,0], np.log10(dataV2[:,1]),'b--', label=r'$\bar{M}=0.523$')
ax.plot([13.181],np.log10([0.000256172]),'ro')
#ax.plot([16.22],np.log10([4.7*10**-5]),'kv')


ax.plot(dataP[:,0], np.log10(dataP[:,1]),'g-', label=r'$\bar{M}=0.477$')
ax.plot([9.13209],np.log10([0.000497858]),'ro')


plt.axhline(y=np.log10(0.000022), color='red', ls='-')
angle2=0
plt.figtext(.13, .465, r'Terrestrial experiments (CODATA 2018)', {'color': 'red', 'fontsize': 20},
            rotation=angle2, rotation_mode='anchor')


ax.axhspan(np.log10(0.02), np.log10(0.01), facecolor='0.75', alpha=0.5)
plt.figtext(0.13, 0.69, r'BBN, CMB, SNI or GW', {'color': '0', 'fontsize': 15},
            rotation=angle2, rotation_mode='anchor')



angle3=-25
plt.figtext(.647, .605, r'$\bar{\sigma}_{0}=0.03$', {'color': '0', 'fontsize': 20},
            rotation=angle3, rotation_mode='anchor')

angle3=-20
plt.figtext(.75, .62, r'$\bar{\sigma}_{0}=0.015$', {'color': 'blue', 'fontsize': 20},
            rotation=angle3, rotation_mode='anchor')


angle3=-21
plt.figtext(.54, .60, r'$\bar{\sigma}_{0}=0.03 \; \mathrm{with}\;\bar{\eta}=0.3$', {'color': 'green', 'fontsize': 20},
            rotation=angle3, rotation_mode='anchor')


ax.set_ylabel(r'$\log_{10}\,\left|1-\mathrm{G}^\mathrm{{I}}_{\mathrm{eff}}/\mathrm{G}\right| $',fontsize=27)#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax.set_xlabel(r'$\bar{r}$',fontsize=27)#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

matplotlib.rcParams['legend.fontsize'] = 25
ax.set_title(r'$\bar{\eta}=-0.3$', loc='right', fontsize=25)
ax.set_title(r'Model I', loc='left', fontsize=25)
ax.legend(loc='lower left',frameon=False) #(.65, .74)


#angle2=90
#plt.figtext(.77, .46, r'$G=6.67430\times10^{-11}$', {'color': '0.5', 'fontsize': 25},
#            rotation=angle2, rotation_mode='anchor')

ax.set_xlim(0, 15)
ax.set_ylim(-9, 0)
# Out:
# (-9, 0)

# %%
fig, ax = plt.subplots(figsize=(12,9))

rad=np.arange(0,30, 0.01)

matplotlib.rcParams['font.size'] = 20

#ax.yaxis.set_major_formatter(OOMFormatter(-4, "%1.1f"))
#ax.ticklabel_format(axis='y', style='sci', scilimits=(-3,-3)) # da el exponente

#ax.plot(dataV[:,0], np.log10(dataV[:,1]),'k--', label=r'$\bar{M}=0.681$')
ax.plot(rad, V(rad),'k:', label=r'$\bar{M}=0.681$')
ax.plot([8.9595],np.log10([0.000884161]),'ro')
#ax.plot([12.55],np.log10([4.7*10**-5]),'kv')

ax.plot(dataV2[:,0], np.log10(dataV2[:,1]),'b--', label=r'$\bar{M}=0.523$')
ax.plot([13.181],np.log10([0.000256172]),'ro')
#ax.plot([16.22],np.log10([4.7*10**-5]),'kv')


leg22, = ax.plot(dataP[:,0], np.log10(dataP[:,1]),'g-')#, label=r'$\bar{M}=0.477$')
ax.plot([9.13209],np.log10([0.000497858]),'ro')


plt.axhline(y=np.log10(0.000022), color='red', ls='-')
angle2=0
plt.figtext(.13, .465, r'Terrestrial experiments (CODATA 2018)', {'color': 'red', 'fontsize': 20},
            rotation=angle2, rotation_mode='anchor')


ax.axhspan(np.log10(0.02), np.log10(0.01), facecolor='0.75', alpha=0.5)
plt.figtext(0.13, 0.69, r'BBN, CMB, SNI or GW', {'color': '0', 'fontsize': 15},
            rotation=angle2, rotation_mode='anchor')



angle3=-25
plt.figtext(.647, .605, r'$\bar{\sigma}_{0}=0.03$', {'color': '0', 'fontsize': 20},
            rotation=angle3, rotation_mode='anchor')

angle3=-20
plt.figtext(.75, .62, r'$\bar{\sigma}_{0}=0.015$', {'color': 'blue', 'fontsize': 20},
            rotation=angle3, rotation_mode='anchor')


angle3=-25
plt.figtext(.54, .605, r'$\bar{\sigma}_{0}=0.03$', {'color': 'green', 'fontsize': 20},
            rotation=angle3, rotation_mode='anchor')


ax.set_ylabel(r'$\log_{10}\,\left|1-\mathrm{G}^\mathrm{{I}}_{\mathrm{eff}}/\mathrm{G}\right| $',fontsize=27)#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax.set_xlabel(r'$\bar{r}$',fontsize=27)#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

matplotlib.rcParams['legend.fontsize'] = 25
#ax.set_title(r'$\bar{\eta}=-0.3$', loc='right', fontsize=25)
ax.set_title(r'Model I', loc='left', fontsize=25)
#ax.legend(loc='lower left',frameon=False) #(.65, .74)

#matplotlib.rcParams['legend.fontsize'] = 28

leg2 = ax.legend(loc = 'lower left', frameon=False, title = r'$\bar{\eta}=-0.3$', fontsize=25,
                title_fontsize='25')

ax.legend([leg22], [r'$\bar{M}=0.477$'], loc=(.4,.11), frameon=False, title = r'$\bar{\eta}=0.3$', 
                    labelspacing=0.5, title_fontsize='25')


ax.add_artist(leg2)


ax.set_xlim(0, 15)
ax.set_ylim(-9, 0)
# Out:
# (-9, 0)

# %%
fig, ax = plt.subplots(figsize=(12,9))

rad=np.arange(0,30, 0.01)

matplotlib.rcParams['font.size'] = 20

#ax.yaxis.set_major_formatter(OOMFormatter(-4, "%1.1f"))
#ax.ticklabel_format(axis='y', style='sci', scilimits=(-3,-3)) # da el exponente

#ax.plot(dataV[:,0], np.log10(dataV[:,1]),'k--', label=r'$\bar{M}=0.679$')
ax.plot(rad, V(rad),'k--', label=r'$\bar{M}=0.681$')
ax.plot(dataV2[:,0], np.log10(dataV2[:,1]),'b--', label=r'$\bar{M}=0.523$')
#ax.plot([24.925],[-10.1756],'ko', label='Viable region')

ax.axhspan(-14, np.log10(4.7e-05), facecolor='0.75', alpha=0.5)
angle2=0
plt.figtext(.2, .655, r'Relative standard uncertainty', {'color': '0.5', 'fontsize': 20},
            rotation=angle2, rotation_mode='anchor')


angle3=-30
plt.figtext(.56, .65, r'$\bar{\sigma}_{0}=0.03$', {'color': '0', 'fontsize': 20},
            rotation=angle3, rotation_mode='anchor')

angle3=-23
plt.figtext(.70, .65, r'$\bar{\sigma}_{0}=0.015$', {'color': 'blue', 'fontsize': 20},
            rotation=angle3, rotation_mode='anchor')

ax.set_ylabel(r'$\log_{10}\,\left|1-\mathrm{G}^{I}_{\mathrm{N}}/\mathrm{G}\right| $')#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax.set_xlabel(r'$\bar{r}$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

matplotlib.rcParams['legend.fontsize'] = 25
ax.set_title(r'$\bar{\eta}=-0.3$', loc='right', fontsize=25)
ax.set_title(r'Case I', loc='left', fontsize=25)
ax.legend(loc=(.6, .8),frameon=False)


#angle2=90
#plt.figtext(.77, .46, r'$G=6.67430\times10^{-11}$', {'color': '0.5', 'fontsize': 25},
#            rotation=angle2, rotation_mode='anchor')

ax.set_xlim(0, 26)
ax.set_ylim(-14, -0.8)
# Out:
# (-14, -0.8)

# %% [markdown]
# The Fig~\ref{figV1} left, represent two solutions where for $\bar{r}>12.55$ (black dashed line) and $\bar{r}>16.22$ (red dashed line), is satisfied that $G_{N}\approx \text{G}$. For other hand, in the Fig~\ref{figV1} right, the solution with central density $\bar{\sigma}_{0}=0.015$ is inside of the viable region for all radius value. This is different for $\bar{\sigma}_{0}=0.03$, for this case it happens when $\bar{r}=3.76$.

# %%
dataV = np.loadtxt('VanisXX_1.dat', usecols=(0,1)) 
dataV2 = np.loadtxt('VanisXX_2.dat', usecols=(0,1)) 

inter1 = np.array([[9.058677580711635],[1.45622*10**-8]]) # R_95, V[] caso II con 0.03
viabl1 = np.array([[3.76],[4.7*10**-5]])

inter2 = np.array([[12.8792],[2.0506*10**-9]]) # R_95, V[] caso II con 0.015

# %%
fig, ax = plt.subplots(figsize=(12,9))

matplotlib.rcParams['font.size'] = 20

#ax.yaxis.set_major_formatter(OOMFormatter(-4, "%1.1f"))
#ax.ticklabel_format(axis='y', style='sci', scilimits=(-3,-3)) # da el exponente
ax.plot(dataV2[:,0], np.log10(dataV2[:,1]),'k:', label=r'$\bar{M}=0.61$')
ax.plot([8.45868],[-7.83677],'ro')
#ax.plot([3.76],np.log10([4.7*10**-5]),'kv')

ax.plot(dataV[:,0], np.log10(dataV[:,1]),'b--', label=r'$\bar{M}=0.49$')
ax.plot([12.8792],np.log10([2.0506*10**-9]),'ro')

#ax.axhspan(-14, np.log10(4.7e-05), facecolor='0.75', alpha=0.5)
angle2=0
#plt.figtext(.55, .655, r'Relative standard uncertainty', {'color': '0.5', 'fontsize': 23},
#            rotation=angle2, rotation_mode='anchor')


plt.axhline(y=np.log10(0.000022), color='red', ls='-')
angle2=0
plt.figtext(.5, .465, r'Terrestrial experiments (CODATA 2018)', {'color': 'red', 'fontsize': 20},
            rotation=angle2, rotation_mode='anchor')


ax.axhspan(np.log10(0.02), np.log10(0.01), facecolor='0.75', alpha=0.5)
plt.figtext(0.71, 0.69, r'BBN, CMB, SNI or GW', {'color': '0', 'fontsize': 15},
            rotation=angle2, rotation_mode='anchor')


angle3=-45
plt.figtext(.43, .35, r'$\bar{\sigma}_{0}=0.03$', {'color': '0', 'fontsize': 20},
            rotation=angle3, rotation_mode='anchor')

angle3=-27 # 0.490389 masa
plt.figtext(.55, .34, r'$\bar{\sigma}_{0}=0.015$', {'color': 'blue', 'fontsize': 20},
            rotation=angle3, rotation_mode='anchor')

ax.set_ylabel(r'$\log_{10}\,\left|1-\mathrm{G}^{\mathrm{II}}_{\mathrm{eff}}/G\right| $', fontsize=27)#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax.set_xlabel(r'$\bar{r}$', fontsize=27)#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

matplotlib.rcParams['legend.fontsize'] = 25
#ax.set_title(r'$\bar{\eta}=-0.3$', loc='right', fontsize=25)
ax.set_title(r'Model II', loc='left', fontsize=25)
ax.legend(loc='lower left',frameon=False, title=r'$\bar{\eta}=-0.3$', title_fontsize='25')


#angle2=90
#plt.figtext(.77, .46, r'$G=6.67430\times10^{-11}$', {'color': '0.5', 'fontsize': 25},
#            rotation=angle2, rotation_mode='anchor')

ax.set_xlim(0, 15)
#ax.set_ylim(-14, -0.8)
ax.set_ylim(-9, 0)
#ax.set_ylim(-7.2, -0.8)
# Out:
# (-9, 0)

# %%
# E-KG
dataBS = np.loadtxt('Func_wM_0.dat', usecols=(0,1)) 

# Horndeski
dataH_M03 = np.loadtxt('Func_wM_M03_H.dat', usecols=(0,1)) 
dataH_03 = np.loadtxt('Func_wM_03_H.dat', usecols=(0,1)) 

# beyond X
dataBH_M03_X = np.loadtxt('Func_wM_M03_BH_X.dat', usecols=(0,1)) 
dataBH_03_X = np.loadtxt('Dat_wvsM95_eta03_X.dat', usecols=(0,1)) 

# beyond X^2
dataBH_M03_X2 = np.loadtxt('Dat_wvsM95_etam03.dat', usecols=(0,1)) 
dataBH_03_X2 = np.loadtxt('Dat_wvsM95_eta03.dat', usecols=(0,1))

# %%
#rad = np.arange(8, datag[-1,0], 0.1)
#Mass = dataM[-1,1]

fig, ax = plt.subplots(figsize=(12,9))

matplotlib.rcParams['font.size'] = 20

#ax.yaxis.set_major_formatter(OOMFormatter(-4, "%1.1f"))
#ax.ticklabel_format(axis='y', style='sci', scilimits=(-4,-4))


line, = ax.plot(dataBH_M03_X[:,0],dataBH_M03_X[:,1],':',color='blue', 
        label=r'$\mathrm{Model \; I\; with}\;\bar{\eta}=-0.3$')
line.set_dashes([10, 3, 2, 5, 6, 1]) # 5 points on, 2 off, 3 on, 1 off

ax.plot(dataH_M03[:,0],dataH_M03[:,1], '--', color='green', dashes=(5, 5),
        label=r'$\mathrm{Horndeski \; with\;}\; \bar{\eta}=-0.3$')

ax.plot(dataBH_M03_X2[:,0],dataBH_M03_X2[:,1],':',color='red', 
        label=r'$\mathrm{Model \; II \; with\;}\;\bar{\eta}=-0.3$')

ax.plot(dataBS[:,0],dataBS[:,1],'-', color='darkgrey')#, label=r'Mini Boson Star'

angle2=25 #25 .52, .60
plt.figtext(.52, .60, r'boson stars', {'color': '0.5', 'fontsize': 22},
            rotation=angle2, rotation_mode='anchor')

ax.plot(dataBH_03_X2[:,0], dataBH_03_X2[:,1],'-.',color='red',  
        label=r'$\mathrm{Model \;II\; with}\;\bar{\eta}=0.3$')

line, = ax.plot(dataH_03[:,0],dataH_03[:,1],'-.', color='green',
        label=r'$\mathrm{Horndeski \; with\;}\; \bar{\eta}=0.3$')
line.set_dashes([8, 4, 2, 4, 2, 4]) 

ax.plot(dataBH_03_X[:,0],dataBH_03_X[:,1],'--',color='blue', 
        label=r'$\mathrm{Model \; I\; with}\;\bar{\eta}=0.3$')



#x1, x2, y1, y2 = datag[0,0], datag[-1,0], dataphi[0,1], dataphi[-1,1]
#ax.set_xlim(x1, x2) # apply the x-limits
ax.set_xlim(0.55, 1.0)
#ax.set_ylim(0.1, 1.)
ax.set_ylim(0.15, .8)

#ax.set_ylabel(r'$g$')#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax.set_xlabel(r'$\bar{r}$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

matplotlib.rcParams['font.size'] = 20
ax.set_ylabel(r'$M_{95}$', fontsize=30) #
ax.set_xlabel(r'$\bar{\omega}^{new}$', fontsize=30)#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

#ax.set_title(r'$\bar{\eta}=\pm 0.3$', loc='right', fontsize=25)

matplotlib.rcParams['legend.fontsize'] = 15
#ax.legend(('Numerical solution', 'Analytical fitting'),loc='upper right',frameon=False)
#ax1.legend(loc='lower right',frameon=False)
matplotlib.rcParams['legend.fontsize'] = 23
ax.legend(loc=(.005, .03),frameon=False);


#ax.plot(0.908925,0.562397,'o', color='darkgrey')
#ax.plot(0.8967355379880991, 0.6472954746573958,'o', color='blue')

#ax.plot(0.9091962116376728, 0.5604212624159505,'o', color='red')
#ax.plot(0.9080424976269752, 0.5699054566272543,'x', color='red')

# %%
# E-KG
dataBS = np.loadtxt('Func_rM_0.dat', usecols=(0,1)) 
maxBS = np.array([[6.00924 ,0.601351]]) 

# Horndeski
dataH_M03 = np.loadtxt('Func_rM_MH.dat', usecols=(0,1)) 
dataH_03 = np.loadtxt('Func_rM_H.dat', usecols=(0,1)) 

maxH_M03 = np.array([[4.56024, 0.699697]]) 
maxH_03 = np.array([[7.11511, 0.536516]])

# beyond X
dataBH_M03_X = np.loadtxt('Func_rM_MBHX.dat', usecols=(0,1)) 
maxBH_M03_X = np.array([[5.00505, 0.761092]])

dataBH_03_X = np.loadtxt('Dat_mvsr_eta03_X.dat', usecols=(0,1))
maxBH_03_X = np.array([[9.13209, 0.477482]])


# beyond X^2
dataBH_M03_X2 = np.loadtxt('Dat_mvsr_etam03.dat', usecols=(0,1)) 
dataBH_03_X2 = np.loadtxt('Dat_mvsr_eta03.dat', usecols=(0,1))  

maxBH_M03_X2 = np.array([[6.14582, 0.612864]]) 
#maxBH_M03_X2 = np.array([[6.07614, 0.609814]]) 
maxBH_03_X2 = np.array([[6.02618, 0.600102]])

# %%
print(0.699697/4.56024)
print(0.761092/5.00505)
# Out:
# 0.1534342490746101
# 0.15206481453731732

# %%
#rad = np.arange(8, datag[-1,0], 0.1)
#Mass = dataM[-1,1]

fig, ax = plt.subplots(figsize=(12,9))

matplotlib.rcParams['font.size'] = 20

#ax.yaxis.set_major_formatter(OOMFormatter(-4, "%1.1f"))
#ax.ticklabel_format(axis='y', style='sci', scilimits=(-4,-4))  r'$\mathrm{Model\; I\; with\;} \bar{\eta}=-0.3$

line, = ax.plot(dataBH_M03_X[:,0],dataBH_M03_X[:,1],':',color='blue',
        label=r'$\mathrm{Model \; I\; with}\;\bar{\eta}=-0.3$')
line.set_dashes([10, 3, 2, 5, 6, 1])

ax.plot(maxBH_M03_X[:,0],maxBH_M03_X[:,1],'o', color='blue')

ax.plot(dataH_M03[:,0],dataH_M03[:,1],'--', color='green', dashes=(5, 5),
        label=r'$\mathrm{Horndeski \; with\;}\; \bar{\eta}=-0.3$')
ax.plot(maxH_M03[:,0],maxH_M03[:,1],'o', color='green')

ax.plot(dataBH_M03_X2[:,0],dataBH_M03_X2[:,1],':',color='red', 
        label=r'$\mathrm{Model\; II\; with}\;\bar{\eta}=-0.3$')
ax.plot(maxBH_M03_X2[:,0]-0.38,maxBH_M03_X2[:,1]-0.0042,'o', color='red')

ax.plot(dataBS[:,0],dataBS[:,1],'-', color='darkgrey')#, label=r'Mini Boson Star'
ax.plot(maxBS[:,0],maxBS[:,1],'o', color='darkgrey')

angle2=80
plt.figtext(.175, .43, r'boson stars', {'color': '0.5', 'fontsize': 22},
            rotation=angle2, rotation_mode='anchor')

ax.plot(dataBH_03_X2[:,0], dataBH_03_X2[:,1],'-.',color='red', 
        label=r'$\mathrm{Model \;II\; with}\;\bar{\eta}=0.3$')
ax.plot(maxBH_03_X2[:,0],maxBH_03_X2[:,1],'o', color='red')

f, = ax.plot(dataH_03[:,0],dataH_03[:,1],'-.', color='green',
        label=r'$\mathrm{Horndeski \; with\;}\; \bar{\eta}=0.3$')
line.set_dashes([8, 4, 2, 4, 2, 4])
ax.plot(maxH_03 [:,0], maxH_03 [:,1],'o', color='green')

ax.plot(dataBH_03_X[:,0],dataBH_03_X[:,1],'--',color='blue', 
        label=r'$\mathrm{Model \; I\; with}\;\bar{\eta}=0.3$')
ax.plot(maxBH_03_X [:,0],maxBH_03_X [:,1],'o', color='blue')




#x1, x2, y1, y2 = datag[0,0], datag[-1,0], dataphi[0,1], dataphi[-1,1]
#ax.set_xlim(x1, x2) # apply the x-limits
ax.set_xlim(0., 38)
ax.set_ylim(0.15, .8)

#ax.set_ylabel(r'$g$')#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax.set_xlabel(r'$\bar{r}$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

matplotlib.rcParams['font.size'] = 20
ax.set_ylabel(r'$M_{95}$', fontsize=30) #
ax.set_xlabel(r'$R_{95}$', fontsize=30)#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

#ax.set_title(r'$\bar{\eta}=\pm 0.3$', loc='right', fontsize=25)

matplotlib.rcParams['legend.fontsize'] = 15
#ax.legend(('Numerical solution', 'Analytical fitting'),loc='upper right',frameon=False)
#ax1.legend(loc='lower right',frameon=False)
matplotlib.rcParams['legend.fontsize'] = 23
ax.legend(loc=(.48, .5),frameon=False);

# %%
#rad = np.arange(8, datag[-1,0], 0.1)
#Mass = dataM[-1,1]

fig, ax = plt.subplots(figsize=(12,9))

matplotlib.rcParams['font.size'] = 20

#ax.yaxis.set_major_formatter(OOMFormatter(-4, "%1.1f"))
#ax.ticklabel_format(axis='y', style='sci', scilimits=(-4,-4))

#ax.plot(dataH_M03[:,0],dataH_M03[:,1],':', color='green', label='$\mathrm{Case \; I \; with\;} F_{4}=0$')
#ax.plot(maxH_M03[:,0],maxH_M03[:,1],'o', color='green')

#ax.plot(dataBH_M03_X[:,0],dataBH_M03_X[:,1],':',color='blue', label='Case I')
#ax.plot(maxBH_M03_X [:,0],maxBH_M03_X [:,1],'o', color='blue')

ax.plot(dataBH_M03_X2[:,0],dataBH_M03_X2[:,1],'*',color='red', label='Case II')
ax.plot(maxBH_M03_X2[:,0],maxBH_M03_X2[:,1],'o', color='red')

ax.plot(dataBS[:,0],dataBS[:,1],'-', color='darkgrey')#, label=r'Mini Boson Star'
ax.plot(maxBS[:,0],maxBS[:,1],'o', color='darkgrey')

angle2=80
plt.figtext(.18, .43, r'boson stars', {'color': '0.5', 'fontsize': 18},
            rotation=angle2, rotation_mode='anchor')

ax.plot(dataBH_03_X2[:,0], dataBH_03_X2[:,1],'x',color='red', label='Case II')
ax.plot(maxBH_03_X2[:,0],maxBH_03_X2[:,1],'o', color='red')

#ax.plot(dataH_03[:,0],dataH_03[:,1],'-', color='green', label='$\mathrm{Case \; I \; with\;} F_{4}=0$')
#ax.plot(maxH_03 [:,0], maxH_03 [:,1],'o', color='green')

#x1, x2, y1, y2 = datag[0,0], datag[-1,0], dataphi[0,1], dataphi[-1,1]
#ax.set_xlim(x1, x2) # apply the x-limits
ax.set_xlim(5, 10)
ax.set_ylim(0.55, .64)

#ax.set_ylabel(r'$g$')#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax.set_xlabel(r'$\bar{r}$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

matplotlib.rcParams['font.size'] = 20
ax.set_ylabel(r'$\bar{M}$') #
ax.set_xlabel(r'$\bar{R}$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

ax.set_title(r'$\bar{\eta}=\pm 0.3$', loc='right', fontsize=25)

matplotlib.rcParams['legend.fontsize'] = 15
#ax.legend(('Numerical solution', 'Analytical fitting'),loc='upper right',frameon=False)
#ax1.legend(loc='lower right',frameon=False)
matplotlib.rcParams['legend.fontsize'] = 22
#ax.legend(loc=(.62, .63),frameon=False);

# %%
dataBH_M03_X

# %%
V=InterpolatedUnivariateSpline(dataBH_M03_X [:,0], dataBH_M03_X[:,1])

rad=np.arange(0,30, 0.01)

plt.plot(dataBH_M03_X[:,0],dataBH_M03_X[:,1],':',color='blue', label='Case I')

# %% [markdown]
# Compacticidades

# %%
#Compacticidad GR
C_GR = np.array([[0, 0.601351/6.00924]])

# Compacticidad BY with X
C_005 = np.loadtxt('Comp_BH_X.dat', usecols=(0,1)) 

# Compacticidad H with X
C_1 = np.loadtxt('Comp_H_X.dat', usecols=(0,1)) 

inter = np.array([[-0.3, 0.153]])

# %%
#radio = np.linspace(0, 11, 400)

#blackhold = lambda r: 0.5


fig, ax = plt.subplots(figsize=(12,9))

matplotlib.rcParams['font.size'] = 20

# Draw a default hline at y=1 that spans the xrange
plt.axhline(y=0.158, color='red', ls='-')
plt.axhline(y=4/9, color='blue', ls='-')
plt.axhline(y=1/2, color='green', ls='-')
plt.axhline(y=C_GR[:,1], color='darkgrey', ls='-')

# intercepto
ax.plot(inter[:,0], inter[:,1],'ko')
plt.text(-0.5, 0.13, '(-0.3, 0.153)', {'color': 'k', 'fontsize': 15})

# GR
#ax.plot(C_GR[:,0], C_GR[:,1],'*', color='darkgrey',ms=12)

#BY X
ax.plot(C_005[:,0], C_005[:,1],':', color='blue', label='Model I')

#H X
ax.plot(C_1[:,0], C_1[:,1], '--', color='green', label='$\mathrm{Model\; I\; with}\; F_{4}=0\; (\mathrm{Horndeski})$')

# textos

plt.text(-1.8, C_GR[:,1]+0.005, 'boson star', {'color': 'darkgrey', 'fontsize': 20})
plt.text(-1.8, 0.158+0.005, 'self-interacting boson star', {'color': 'r', 'fontsize': 20})
plt.text(-1.8, 4/9+0.005, 'fluid star', {'color': 'b', 'fontsize': 20})
plt.text(-1.8, 0.505, 'black hole', {'color': 'g', 'fontsize': 20})



#lineas
#plt.text(-8., 0.22, r'$\bar{\alpha} = 0.05$', {'color': 'orange', 'fontsize': 20})
#plt.text(-8., 0.18, r'$\bar{\alpha} = 0$', {'color': 'black', 'fontsize': 20})
#plt.text(-8., 0.11, r'$\bar{\alpha} = 1$', {'color': 'orange', 'fontsize': 20})


x1, x2, y1, y2 = -2, 0.01, 0, 0.55
ax.set_xlim(x1, x2) # apply the x-limits
ax.set_ylim(y1, y2)

ax.set_ylabel(r'$C^{\mathrm{max}}$', fontsize=25)#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax.set_xlabel(r'$\bar{\eta}$',  fontsize=25)#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

#matplotlib.rcParams['legend.fontsize'] = 23
#ax.legend((r'Free Fermions', r'Intercating Fermions'),loc='upper right',frameon=False)

ax2 = ax.twinx()
ax2.set_ylim(y1, y2)
#ax2.set_ylim(0, ax.get_ylim)

matplotlib.rcParams['legend.fontsize'] = 23
ax.legend(loc=(.02, .01),frameon=False);

# %%
C_GR[:,1]
# Out:
# array([0.10007106])
