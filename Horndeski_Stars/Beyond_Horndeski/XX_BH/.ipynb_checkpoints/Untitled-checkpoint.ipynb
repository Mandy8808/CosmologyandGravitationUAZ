# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as font_manager
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
#from matplotlib.patches import Rectangle

from cycler import cycler

# %%
# estructura para latex
# mpl.use("pgf")

# estilo de linea y grosor
mpl.rcParams['lines.linestyle'] = '-'
mpl.rcParams['lines.linewidth'] = 2.

# orden de los colores que usará
mpl.rcParams['axes.prop_cycle'] = cycler('color', ['#1f77b4', '#ff7f0e', '#2ca02c', 
                                                   '#d62728', '#9467bd', '#8c564b', '#e377c2', 
                                                   '#7f7f7f', '#bcbd22', '#17becf'])
#cycler(color=['r', 'g', 'b', 'y'])

# latex modo math
mpl.rcParams['mathtext.fontset'] = 'cm'  # Should be 'dejavusans' (default),
                                         # 'dejavuserif', 'cm' (Computer Modern), 'stix',
                                         # 'stixsans' or 'custom'
        
mpl.rcParams['mathtext.fallback_to_cm']= True # When True, use symbols from the Computer Modern
                                              # fonts when a symbol can not be found in one of
                                              # the custom math fonts.
    
# Texto
mpl.rcParams['font.family'] = 'serif' # serif, sans-serif, cursive, fantasy, monospace
cmfont = font_manager.FontProperties(fname=mpl.get_data_path() + '/fonts/ttf/cmr10.ttf')
mpl.rcParams['font.serif']=cmfont.get_name()
mpl.rcParams['font.size'] = 16 # tamaño de la letra

###
# mpl.rcParams['pgf.texsystem'] = 'pdflatex'
mpl.rcParams['text.usetex'] = True
mpl.rcParams['pgf.rcfonts'] = False
mpl.rcParams['text.latex.preamble'] = [r'\usepackage{amssymb}'] # \usepackage{txfonts}


mpl.rcParams['pgf.preamble'] = ['\\usepackage{amssymb}']
###


#mpl.rcParams['axes.titlepad'] = 6.0     # pad between axes and title in points
mpl.rcParams['axes.labelpad'] = 3.0 #10.0     # space between label and axis
mpl.rcParams['axes.labelweight'] = 'normal'  # weight (grosor) of the x and y labels
mpl.rcParams['axes.labelcolor'] = 'black'
mpl.rcParams['axes.unicode_minus'] = False # use Unicode for the minus symbol
mpl.rcParams['axes.linewidth'] = 1     # edge linewidth, grosor del marco

#mpl.rcParams['axes.titlesize'] = 24
mpl.rcParams['axes.labelsize'] = 16
#mpl.rcParams['lines.markersize'] = 10


# display axis spines, muestra la linea de los marcos
mpl.rcParams['axes.spines.left'] = False
mpl.rcParams['axes.spines.bottom'] = False
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.right'] = False

# Figura
#mpl.rcParams['figure.dpi'] = 100 # figure dots per inch
mpl.rcParams['figure.figsize'] = [12, 9]# [4,3] # 
mpl.rcParams['figure.facecolor'] = 'white'     # figure facecolor
mpl.rcParams['figure.edgecolor'] = 'white'     # figure edgecolor
mpl.rcParams['savefig.dpi'] = 100

mpl.rcParams['xtick.labelsize'] = 15 #'large' # tamaño de los números de los ejes
mpl.rcParams['ytick.labelsize'] = 15 #'large'
mpl.rcParams['xtick.direction'] = 'out' # direction: {in, out, inout} señalamiento de los ejes
mpl.rcParams['ytick.direction'] = 'out' # direction: {in, out, inout}
mpl.rcParams['xtick.top'] = False # draw ticks on the top side
mpl.rcParams['ytick.right'] = False # draw ticks on the top side
mpl.rcParams['ytick.left'] = False # draw ticks on the top side
mpl.rcParams['xtick.labelbottom'] = False    # draw label on the bottom

mpl.rcParams['xtick.major.bottom'] = False   # draw x axis bottom major ticks
#mpl.rcParams['xtick.major.top'] = True   # draw x axis top major ticks
mpl.rcParams['xtick.minor.bottom'] = False    ## draw x axis bottom minor ticks
#mpl.rcParams['xtick.minor.top'] = True    ## draw x axis top minor ticks

mpl.rcParams['xtick.minor.visible'] = False  # visibility of minor ticks on x-axis

#xtick.alignment     : center  ## alignment of xticks
#xtick.alignment     : center  ## alignment of xticks

# Legend
mpl.rcParams['legend.loc'] = 'best'
mpl.rcParams['legend.frameon'] = True # if True, draw the legend on a background patch
mpl.rcParams['legend.framealpha'] = 0.19 # 0.8 legend patch transparency
mpl.rcParams['legend.facecolor'] = 'inherit'  # inherit from axes.facecolor; or color spec
mpl.rcParams['legend.edgecolor'] = 'inherit' # background patch boundary color
mpl.rcParams['legend.fancybox'] = True     # if True, use a rounded box for the

#mpl.rcParams['legend.numpoints'] = 1 # the number of marker points in the legend line
#mpl.rcParams['legend.scatterpoints'] = 1 # number of scatter points
#mpl.rcParams['legend.markerscale'] = 1.0 # the relative size of legend markers vs. original
mpl.rcParams['legend.fontsize'] = 15 # 'medium' 'large'

## Dimensions as fraction of fontsize:
mpl.rcParams['legend.borderpad'] = 0.4  ## border whitespace espacio de los bordes con respecto al texto
mpl.rcParams['legend.labelspacing'] = 0.5  ## the vertical space between the legend entries
mpl.rcParams['legend.handlelength'] = 1.5  ## the length of the legend lines defauld 2
#mpl.rcParams['legend.handleheight'] = 0.7  ## the height of the legend handle
mpl.rcParams['legend.handletextpad'] = 0.8  ## the space between the legend line and legend text
#mpl.rcParams['legend.borderaxespad'] = 0.5  ## the border between the axes and legend edge
#mpl.rcParams['legend.columnspacing'] = 8.0  ## column separation
# Out:
# <ipython-input-2-ceb16b56b561>:19: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   mpl.rcParams['mathtext.fallback_to_cm']= True # When True, use symbols from the Computer Modern
# <ipython-input-2-ceb16b56b561>:19: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   mpl.rcParams['mathtext.fallback_to_cm']= True # When True, use symbols from the Computer Modern
# <ipython-input-2-ceb16b56b561>:19: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   mpl.rcParams['mathtext.fallback_to_cm']= True # When True, use symbols from the Computer Modern
# ...

# %%
import matplotlib.patches as patches
from matplotlib.patches import FancyBboxPatch

fig, ax = plt.subplots(figsize=(9,5)) #, nrows=2, ncols=2

# changing the background color
ax.set_facecolor('#adc6df')
ax.set_yticklabels([])
#ax.set_xticklabels([])

# Create a Rectangle patch
#GLPV
left, bottom, width, height = (.01, .01, .85, .97)
rect0 = plt.Rectangle((left, bottom), width, height, facecolor="none", alpha=0.09, 
                     edgecolor='#0a0909', hatch='.', lw=.1)

#Horndeski
left, bottom, width, height = (.02, .04, .655, .9)
rect = plt.Rectangle((left, bottom), width, height, facecolor="#9ad89a", alpha=0.3)

# WBG
left, bottom, width, height = (.45, .1, .36, .35)
rect1 = plt.Rectangle((left, bottom), width, height, facecolor="#7676ca", alpha=0.3)

# covariant
left, bottom, width, height = (.47, .22, .18, .2)
rect2 = plt.Rectangle((left, bottom), width, height, facecolor="#ca76a0", alpha=0.3)

# Brans–Dicke
left, bottom, width, height = (.03, .6, .35, .3)
rect3 = plt.Rectangle((left, bottom), width, height, facecolor="#b04444", alpha=0.5)

# Quintessence
left, bottom, width, height = (.18, .32, .25, .25)
rect4 = plt.Rectangle((left, bottom), width, height, facecolor='#918186',
                      alpha=0.7) # angle=30

# Add the patch to the Axes color='none'
ax.add_patch(rect0)
ax.add_patch(rect)
ax.add_patch(rect1)
ax.add_patch(rect2)
ax.add_patch(rect3)
ax.add_patch(rect4)


ax.text(0.87, 0.9, r'DHOST', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=0.9)
ax.text(0.7, 0.9, r'GLPV', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=0.9)
ax.text(0.7, 0.83, r'(beyond', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=0.9)
ax.text(0.7, 0.73, r'Horndeski)', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=0.9)
ax.text(0.45, 0.9, r'Horndeski', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=0.9)
ax.text(0.72, 0.2, r'WBG', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=0.9)
ax.text(0.48, 0.4, r'covariant', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=0.8)
ax.text(0.48, 0.32, r'Galileon', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=0.8)

ax.text(0.22, 0.48, r'Quintessence', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=0.8)
ax.text(0.12, 0.78, r'Brans–Dicke', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=.8)
# Out:
# Text(0.12, 0.78, 'Brans–Dicke')

# %%
import matplotlib.patches as patches
from matplotlib.patches import FancyBboxPatch

fig, ax = plt.subplots(figsize=(8,5)) #, nrows=2, ncols=2

# changing the background color
ax.set_facecolor('#adc6df')
ax.set_yticklabels([])
#ax.set_xticklabels([])

# changing the border color
ax.spines['bottom'].set_color('#1478db')
ax.spines['top'].set_color('#1478db') 
ax.spines['right'].set_color('#1478db')
ax.spines['left'].set_color('#1478db')


# Create a Rectangle patch
#GLPV
left, bottom, width, height = (.22, .225, .47, .54)
rect0 = FancyBboxPatch((left, bottom), 
                             width, height,
                             boxstyle="round, pad=0.2",
                             fc="#3ef705",
                             alpha=0.17,
                             ls='-',
                             mutation_aspect=.9,
                             ec='green', 
                             lw=1.5,
                             zorder=4) #(0., .5, 0.)

#Horndeski
left, bottom, width, height = (.23, .26, .26, .47)
#rect = plt.Rectangle((left, bottom), width, height, facecolor="#9ad89a", alpha=0.3)

rect = FancyBboxPatch((left, bottom), 
                             width, height,
                             boxstyle="round,pad=0.2",
                             #mutation_aspect=.8,
                             fc="#fa0505",
                             alpha=0.2, 
                             ls='-',
                             ec='red', 
                             lw=1.5, 
                             zorder=4)
    
# WBG
left, bottom, width, height = (.53, .33, .13, .12)
rect1 = FancyBboxPatch((left, bottom), 
                             width, height,
                             boxstyle="roundtooth, pad=0.18, tooth_size=0.015",
                             fc="#a005fa",
                             alpha=0.2, 
                             ls='-',
                             ec='#a005fa', 
                             lw=1.5,
                             zorder=4)
# covariant
left, bottom, width, height = (.56, .56, -.08, -.15)
rect2 =  FancyBboxPatch((left, bottom), 
                             width, height,
                             boxstyle="round4, pad=0.2, rounding_size=0.01",
                             fc="black",
                             alpha=0.3,
                             ls='-',
                             ec='#363138', 
                             lw=1.5,
                             hatch='\\',
                             zorder=4)

# EKG
left, bottom, width, height = (.565, .375, -.24, -.21)
rect22 =  FancyBboxPatch((left, bottom), 
                             width, height,
                             boxstyle="round4, pad=0.2, rounding_size=0.005",
                             fc="#f3f0f5",
                             alpha=0.3,
                             ls='-',
                             ec='#363138', 
                             lw=1.5,
                             hatch='/',
                             zorder=4)

# Brans–Dicke
left, bottom, width, height = (.3, .6, 0.025, -.09)
rect3 =  FancyBboxPatch((left, bottom), 
                             width, height,
                             boxstyle="round4, pad=0.2, rounding_size=0.01",
                             fc="#191a18",
                             alpha=0.3,
                             ls='-',
                             ec='#191a18', 
                             lw=2.5,
                             #hatch='|',
                             zorder=4)
# Quintessence
left, bottom, width, height = (.3, .3, 0.025, -.09)
rect4 =  FancyBboxPatch((left, bottom), 
                             width, height,
                             boxstyle="round4, pad=0.2, rounding_size=0.01",
                             fc="#0509f5",
                             alpha=0.3,
                             ls='-',
                             ec='#0509f5', 
                             lw=2.5,
                             #hatch='x',
                             zorder=4)

# Add the patch to the Axes color='none'
ax.add_patch(rect0)
ax.add_patch(rect)
ax.add_patch(rect1)
ax.add_patch(rect2)
ax.add_patch(rect22)
ax.add_patch(rect3)
ax.add_patch(rect4)


ax.text(0.86, 0.94, r'DHOST', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.7, 0.9, r'GLPV', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.7, 0.83, r'(beyond', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.7, 0.73, r'Horndeski)', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.45, 0.8, r'Horndeski', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.72, 0.25, r'WBG', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.53, 0.56, r'covariant', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.53, 0.48, r'galileon', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.4, 0.3, r'EKG', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)

ax.text(0.12, 0.28, r'Quintessence', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.12, 0.58, r'Brans–Dicke', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
# Out:
# Text(0.12, 0.58, 'Brans–Dicke')

# %%
import matplotlib.patches as patches
from matplotlib.patches import FancyBboxPatch

fig, ax = plt.subplots(figsize=(8,5)) #, nrows=2, ncols=2

# changing the background color
#ax.set_facecolor('#adc6df')
ax.set_yticklabels([])
#ax.set_xticklabels([])

# changing the border color
#ax.spines['bottom'].set_color('#1478db')
#ax.spines['top'].set_color('#1478db') 
#ax.spines['right'].set_color('#1478db')
#ax.spines['left'].set_color('#1478db')


# Create a Rectangle patch
#DHOST
left, bottom, width, height = (.22, .225, .375, .48) #0.4
rect0 = FancyBboxPatch((left, bottom), 
                             width, height,
                             boxstyle="round, pad=0.2, rounding_size=0.03",
                             ec='blue', 
                             lw=2,
                             fc="darkblue",
                             alpha=0.05,
                             ls='-',
                             mutation_aspect=.9,
                             zorder=4) #(0., .5, 0.)

#GLPV
left, bottom, width, height = (.24, .28, .185, .37)
rect = FancyBboxPatch((left, bottom), 
                             width, height,
                             boxstyle="round, pad=0.2, rounding_size=0.03",
                             #mutation_aspect=.8,
                             fc="brown",
                             alpha=0.1, 
                             ls='-',
                             ec='darkred', 
                             lw=1.5, 
                             zorder=4)

#Horndeski
left, bottom, width, height = (.26, .28+0.04, -.05, .28)
#rect = plt.Rectangle((left, bottom), width, height, facecolor="#9ad89a", alpha=0.3)

rect01 = FancyBboxPatch((left, bottom), 
                             width, height,
                             boxstyle="round, pad=0.2, rounding_size=0.03",
                             #mutation_aspect=.8,
                             fc="green",
                             alpha=0.15, 
                             ls='-',
                             ec='darkgreen', 
                             lw=1.5, 
                             zorder=4)
    
# WBG
left, bottom, width, height = (.3, .347, .055, .05)# .39
rect1 = FancyBboxPatch((left, bottom), 
                             width, height,
                             boxstyle="roundtooth, pad=0.18, tooth_size=0.015",
                             fc="blue",
                             alpha=0.2, 
                             ls='-',
                             ec='darkblue', 
                             lw=1.5,
                             zorder=4)
# covariant
left, bottom, width, height = (.342, .54, -.17, -.19)
rect2 =  FancyBboxPatch((left, bottom), 
                             width, height,
                             boxstyle="round, pad=0.2, rounding_size=0.03",
                             fc="black",
                             alpha=0.3,
                             ls='-',
                             ec='#363138', 
                             lw=1.5,
                             #hatch='\\',
                             zorder=4)

# EKG
left, bottom, width, height = (.342, .39, -.28, -.037)
rect22 =  FancyBboxPatch((left, bottom), 
                             width, height,
                             boxstyle="round, pad=0.2, rounding_size=0.03",
                             fc="#f3f0f5",
                             alpha=0.4,
                             ls='-',
                             ec='#363138', 
                             lw=0.05,
                             #hatch='/',
                             zorder=4)

# Add the patch to the Axes color='none'
ax.add_patch(rect0)
ax.add_patch(rect)
ax.add_patch(rect01)
ax.add_patch(rect1)
ax.add_patch(rect22)
ax.add_patch(rect2)
#ax.add_patch(rect3)
#ax.add_patch(rect4)


ax.text(0.65, 0.85, r'DHOST', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.445, 0.83, r'GLPV', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.445, 0.76, r'(beyond', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.445, 0.68, r'Horndeski)', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.24, 0.775, r'Horndeski', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.42, 0.25, r'WBG', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.16, 0.51, r'covariant', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.16, 0.43, r'galileon', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.16, 0.295, r'EKG', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)

#ax.text(0.12, 0.28, r'Quintessence', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
#ax.text(0.12, 0.58, r'Brans–Dicke', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
# Out:
# Text(0.16, 0.295, 'EKG')

# %%
import matplotlib.patches as patches
from matplotlib.patches import FancyBboxPatch

fig, ax = plt.subplots(figsize=(6.8,4.8)) #, nrows=2, ncols=2

# changing the background color
#ax.set_facecolor('#adc6df')
ax.set_yticklabels([])
#ax.set_xticklabels([])

# changing the border color
ax.spines['bottom'].set_color('#1478db')
ax.spines['top'].set_color('#1478db') 
ax.spines['right'].set_color('#1478db')
ax.spines['left'].set_color('#1478db')


# Create a Rectangle patch
#DHOST                        (.22, .225, .375, .48)
left, bottom, width, height = (.22, .225, .57, .55) #0.4
rect0 = FancyBboxPatch((left, bottom), 
                             width, height,
                             boxstyle="round, pad=0.2, rounding_size=0.03",
                             ec='blue', 
                             lw=2,
                             fc="darkblue",
                             alpha=0.05,
                             ls='-',
                             mutation_aspect=.9,
                             zorder=4) #(0., .5, 0.)

#GLPV
left, bottom, width, height = (.24, .28, .355, .44)
rect = FancyBboxPatch((left, bottom), 
                             width, height,
                             boxstyle="round, pad=0.2, rounding_size=0.03",
                             #mutation_aspect=.8,
                             fc="brown",
                             alpha=0.1, 
                             ls='-',
                             ec='darkred', 
                             lw=1.5, 
                             zorder=4)

#Horndeski
left, bottom, width, height = (.26, .28+0.04, 0.085, .35)
#rect = plt.Rectangle((left, bottom), width, height, facecolor="#9ad89a", alpha=0.3)

rect01 = FancyBboxPatch((left, bottom), 
                             width, height,
                             boxstyle="round, pad=0.2, rounding_size=0.03",
                             #mutation_aspect=.8,
                             fc="green",
                             alpha=0.15, 
                             ls='-',
                             ec='darkgreen', 
                             lw=1.5, 
                             zorder=4)
    
# WBG
left, bottom, width, height = (.3, .347, .205, .10)# .39
rect1 = FancyBboxPatch((left, bottom), 
                             width, height,
                             boxstyle="roundtooth, pad=0.18, tooth_size=0.015",
                             fc="blue",
                             alpha=0.2, 
                             ls='-',
                             ec='darkblue', 
                             lw=1.5,
                             zorder=4)
# covariant
left, bottom, width, height = (.342, .54, -.08, -.14)
rect2 =  FancyBboxPatch((left, bottom), 
                             width, height,
                             boxstyle="round, pad=0.2, rounding_size=0.03",
                             fc="black",
                             alpha=0.15,
                             ls='-',
                             ec='#363138', 
                             lw=1.5,
                             #hatch='\\',
                             zorder=4)

# EKG
left, bottom, width, height = (.34, .39, -.27, .0143)
rect22 =  FancyBboxPatch((left, bottom), 
                             width, height,
                             boxstyle="round, pad=0.2, rounding_size=0.03",
                             fc="#f3f0f5",
                             alpha=0.25,
                             ls='-',
                             ec='#363138', 
                             lw=0.05,
                             #hatch='/',
                             zorder=4)


# Add the patch to the Axes color='none'
ax.add_patch(rect0)
ax.add_patch(rect)
ax.add_patch(rect01)
ax.add_patch(rect1)
ax.add_patch(rect22)
ax.add_patch(rect2)
#ax.add_patch(rect3)
#ax.add_patch(rect4)


ax.text(0.79, 0.92, r'DHOST', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.56, 0.89, r'GLPV', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.56, 0.82, r'(beyond', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.56, 0.74, r'Horndeski)', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.33, 0.85, r'Horndeski', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.545, 0.25, r'WBG', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.285, 0.58, r'covariant', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.285, 0.51, r'galileons', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.17, 0.295, r'EKG', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)

#ax.text(0.12, 0.28, r'Quintessence', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.187, 0.54, r'GR', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)

ax.text(0.17, 0.295, r'EKG', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)
ax.text(0.187, 0.54, r'GR', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=1)




# GR
left, bottom, width, height = (.21, .46, 0, 0)
circ =  FancyBboxPatch((left, bottom), 
                             width, height,
                             boxstyle="circle, pad=0.01",
                             fc="k",
                             alpha=1,
                             ls='-',
                             ec='k',
                             #lw=0.05,
                             #hatch='/',
                             #zorder=4
                      )
#ax.add_patch(circ)

ax.plot([0.205], [0.46], r'k', marker = 'o', ms=4, alpha=0.6)

# %%
plt.savefig('FigRegion.pgf', 
            #This is simple recomendation for publication plots
            dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

#plt.savefig('rho_profile.pgf')
plt.savefig("FigRegion.png",dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

# %%
#from matplotlib.patches import Ellipse
import matplotlib.patches as patches

fig, ax = plt.subplots(figsize=(9,5)) #, nrows=2, ncols=2

# changing the background color
ax.set_facecolor('#adc6df')
ax.set_yticklabels([])
#ax.set_xticklabels([])

# Create a Rectangle patch
#GLPV
left, bottom, width, height = (.01, .01, .85, .97)
rect0 = plt.Rectangle((left, bottom), width, height, facecolor="none", alpha=0.09, 
                     edgecolor='#0a0909', hatch='.', lw=.1)

#Horndeski
left, bottom, width, height = (.02, .04, .655, .9)
rect = plt.Rectangle((left, bottom), width, height, facecolor="#9ad89a", alpha=0.3)

# WBG
left, bottom, width, height = (.6, .2, .38, .35)
rect1 = Ellipse((left, bottom), width, height, facecolor="#7676ca", alpha=0.3)

# covariant
left, bottom, width, height = (.52, .23, .18, .2)
rect2 = Ellipse((left, bottom), width, height, facecolor="#ca76a0", alpha=0.3)

# Brans–Dicke
left, bottom, width, height = (.21, .75, .35, .3)
rect3 = Ellipse((left, bottom), width, height, facecolor="#b04444", alpha=0.5)

# Quintessence
left, bottom, width, height = (.31, .45, .25, .25)
rect4 = Ellipse((left, bottom), width, height, facecolor='#918186',
                      alpha=0.7) # angle=30

# Add the patch to the Axes color='none'
ax.add_patch(rect0)
ax.add_patch(rect)
ax.add_patch(rect1)
ax.add_patch(rect2)
ax.add_patch(rect3)
ax.add_patch(rect4)


ax.text(0.87, 0.9, r'DHOST', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=0.9)
ax.text(0.7, 0.9, r'GLPV', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=0.9)
ax.text(0.7, 0.83, r'(beyond', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=0.9)
ax.text(0.7, 0.73, r'Horndeski)', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=0.9)
ax.text(0.45, 0.9, r'Horndeski', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=0.9)
ax.text(0.68, 0.2, r'WBG', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=0.9)
ax.text(0.45, 0.3, r'covariant', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=0.9)
ax.text(0.45, 0.23, r'Galileon', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=0.9)

ax.text(0.22, 0.48, r'Quintessence', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=0.9)
ax.text(0.12, 0.78, r'Brans–Dicke', transform=ax.transAxes, fontsize=18, verticalalignment='top', alpha=.9)
# Out:
# Text(0.12, 0.78, 'Brans–Dicke')
