# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as font_manager
#from mpl_toolkits.axes_grid1.inset_locator import inset_axes
#from matplotlib.patches import Rectangle

from cycler import cycler

# %%
# estructura para latex
#mpl.use("pgf")

# estilo de linea y grosor
mpl.rcParams['lines.linestyle'] = '-'
mpl.rcParams['lines.linewidth'] = 2.

# orden de los colores que usará
mpl.rcParams['axes.prop_cycle'] = cycler('color', ['#1f77b4', '#ff7f0e', '#2ca02c', 
                                                   '#d62728', '#9467bd', '#8c564b', '#e377c2', 
                                                   '#7f7f7f', '#bcbd22', '#17becf'])
#cycler(color=['r', 'g', 'b', 'y'])

# latex modo math
mpl.rcParams['mathtext.fontset'] = 'cm'  # Should be 'dejavusans' (default),
                                         # 'dejavuserif', 'cm' (Computer Modern), 'stix',
                                         # 'stixsans' or 'custom'
        
mpl.rcParams['mathtext.fallback_to_cm']= True # When True, use symbols from the Computer Modern
                                              # fonts when a symbol can not be found in one of
                                              # the custom math fonts.
    
# Texto
mpl.rcParams['font.family'] = 'serif' # serif, sans-serif, cursive, fantasy, monospace
cmfont = font_manager.FontProperties(fname=mpl.get_data_path() + '/fonts/ttf/cmr10.ttf')
mpl.rcParams['font.serif']=cmfont.get_name()
mpl.rcParams['font.size'] = 16 # tamaño de la letra

###
#mpl.rcParams['pgf.texsystem'] = 'pdflatex'
mpl.rcParams['text.usetex'] = True
mpl.rcParams['pgf.rcfonts'] = False
mpl.rcParams['text.latex.preamble'] = [r'\usepackage{amssymb}'] # \usepackage{txfonts}


mpl.rcParams['pgf.preamble'] = ['\\usepackage{amssymb}']
###


#mpl.rcParams['axes.titlepad'] = 6.0     # pad between axes and title in points
mpl.rcParams['axes.labelpad'] = 3.0 #10.0     # space between label and axis
mpl.rcParams['axes.labelweight'] = 'normal'  # weight (grosor) of the x and y labels
mpl.rcParams['axes.labelcolor'] = 'black'
mpl.rcParams['axes.unicode_minus'] = False # use Unicode for the minus symbol
mpl.rcParams['axes.linewidth'] = 1     # edge linewidth, grosor del marco

#mpl.rcParams['axes.titlesize'] = 24
mpl.rcParams['axes.labelsize'] = 16
#mpl.rcParams['lines.markersize'] = 10


# display axis spines, muestra la linea de los marcos
mpl.rcParams['axes.spines.left'] = True
mpl.rcParams['axes.spines.bottom'] = True
mpl.rcParams['axes.spines.top'] = True
mpl.rcParams['axes.spines.right'] = True

# Figura
#mpl.rcParams['figure.dpi'] = 100 # figure dots per inch
mpl.rcParams['figure.figsize'] = [12, 9]# [4,3] # 
mpl.rcParams['figure.facecolor'] = 'white'     # figure facecolor
mpl.rcParams['figure.edgecolor'] = 'white'     # figure edgecolor
mpl.rcParams['savefig.dpi'] = 100

mpl.rcParams['xtick.labelsize'] = 15 #'large' # tamaño de los números de los ejes
mpl.rcParams['ytick.labelsize'] = 15 #'large'
mpl.rcParams['xtick.direction'] = 'out' # direction: {in, out, inout} señalamiento de los ejes
mpl.rcParams['ytick.direction'] = 'out' # direction: {in, out, inout}
mpl.rcParams['xtick.top'] = False # draw ticks on the top side
mpl.rcParams['ytick.right'] = False # draw ticks on the top side
#xtick.labeltop      : False   ## draw label on the top
mpl.rcParams['xtick.labelbottom'] = True    # draw label on the bottom

mpl.rcParams['xtick.major.bottom'] = True   # draw x axis bottom major ticks
#mpl.rcParams['xtick.major.top'] = True   # draw x axis top major ticks
mpl.rcParams['xtick.minor.bottom'] = False    ## draw x axis bottom minor ticks
#mpl.rcParams['xtick.minor.top'] = True    ## draw x axis top minor ticks

mpl.rcParams['xtick.minor.visible'] = True  # visibility of minor ticks on x-axis

#xtick.alignment     : center  ## alignment of xticks
#xtick.alignment     : center  ## alignment of xticks

# Legend
mpl.rcParams['legend.loc'] = 'best'
mpl.rcParams['legend.frameon'] = True # if True, draw the legend on a background patch
mpl.rcParams['legend.framealpha'] = 0.19 # 0.8 legend patch transparency
mpl.rcParams['legend.facecolor'] = 'inherit'  # inherit from axes.facecolor; or color spec
mpl.rcParams['legend.edgecolor'] = 'inherit' # background patch boundary color
mpl.rcParams['legend.fancybox'] = True     # if True, use a rounded box for the

#mpl.rcParams['legend.numpoints'] = 1 # the number of marker points in the legend line
#mpl.rcParams['legend.scatterpoints'] = 1 # number of scatter points
#mpl.rcParams['legend.markerscale'] = 1.0 # the relative size of legend markers vs. original
mpl.rcParams['legend.fontsize'] = 15 # 'medium' 'large'

## Dimensions as fraction of fontsize:
mpl.rcParams['legend.borderpad'] = 0.4  ## border whitespace espacio de los bordes con respecto al texto
mpl.rcParams['legend.labelspacing'] = 0.5  ## the vertical space between the legend entries
mpl.rcParams['legend.handlelength'] = 1.5  ## the length of the legend lines defauld 2
#mpl.rcParams['legend.handleheight'] = 0.7  ## the height of the legend handle
mpl.rcParams['legend.handletextpad'] = 0.8  ## the space between the legend line and legend text
#mpl.rcParams['legend.borderaxespad'] = 0.5  ## the border between the axes and legend edge
#mpl.rcParams['legend.columnspacing'] = 8.0  ## column separation
# Out:
# <ipython-input-2-4339b6c11e74>:19: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   mpl.rcParams['mathtext.fallback_to_cm']= True # When True, use symbols from the Computer Modern
# <ipython-input-2-4339b6c11e74>:19: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   mpl.rcParams['mathtext.fallback_to_cm']= True # When True, use symbols from the Computer Modern
# <ipython-input-2-4339b6c11e74>:19: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   mpl.rcParams['mathtext.fallback_to_cm']= True # When True, use symbols from the Computer Modern
# ...

# %%
# Fig izquierda
# E-KG
maxBS = np.array([[6.00924 ,0.601351]]) 
dataBS1 = np.loadtxt('Func_wM_0.dat', usecols=(0,1)) 

# Horndeski
dataH1_M03 = np.loadtxt('Func_wM_M03_H.dat', usecols=(0,1)) 
dataH1_03 = np.loadtxt('Func_wM_03_H.dat', usecols=(0,1)) 

# beyond X
dataBH1_M03_X = np.loadtxt('2Func_wM_M03_BH_X.dat', usecols=(0,1)) 
dataBH1_03_X = np.loadtxt('Dat_wvsM95_eta03_X.dat', usecols=(0,1))

# %%
# Fig derecha
# E-KG
dataBS = np.loadtxt('Func_rM_0.dat', usecols=(0,1)) 

# Horndeski
dataH_M03 = np.loadtxt('Func_rM_MH.dat', usecols=(0,1)) 
dataH_03 = np.loadtxt('Func_rM_H.dat', usecols=(0,1)) 

# beyond X
dataBH_M03_X = np.loadtxt('2Dat_mvsr_etaM03_X.dat', usecols=(0,1)) 
dataBH_03_X = np.loadtxt('2Dat_mvsr_eta03_X.dat', usecols=(0,1))

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 5.5))

ax[0].plot(dataBS1[0:30,0], 8*np.pi*dataBS1[0:30, 1], label = r'$c_{4}^{(1)}=d_{4}^{(-1)}=0$', 
           color = '#566874') # (BS) [0:35,0]
ax[0].plot(dataBS1[29:35,0], 8*np.pi*dataBS1[29:35, 1], ls=':',
           color = '#566874') # (BS)
ax[0].plot(dataBS1[29,0], 8*np.pi*dataBS1[29,1],'o', color = '#566874' )


ax[0].plot(dataH1_M03[:35,0], 8*np.pi*dataH1_M03[:35,1], label = r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0$', 
           color = '#5079b9')
ax[0].plot(dataH1_M03[34:,0], 8*np.pi*dataH1_M03[34:,1],ls=':',
           color = '#5079b9')
ax[0].plot(dataH1_M03[34,0], 8*np.pi*dataH1_M03[34,1],'o', color= '#5079b9')


ax[0].plot(dataH1_03[0:23,0], 8*np.pi*dataH1_03[0:23,1], label = r'$c_{4}^{(1)}=-1/2, \;d_{4}^{(-1)}=0$', 
           color = '#419ede')# [0:32,0]
ax[0].plot(dataH1_03[22:32,0], 8*np.pi*dataH1_03[22:32,1], ls=':',
           color = '#419ede')
ax[0].plot(dataH1_03[22,0], 8*np.pi*dataH1_03[22,1],'o', color = '#419ede')


ax[0].plot(dataBH1_M03_X[:26,0], 8*np.pi*dataBH1_M03_X[:26,1], label = r'$c_{4}^{(1)}=1/2,\; d_{4}^{(-1)}=1$', 
           color = '#b45c1f')
ax[0].plot(dataBH1_M03_X[25:,0], 8*np.pi*dataBH1_M03_X[25:,1], ls=':',
           color = '#b45c1f')
ax[0].plot(dataBH1_M03_X[25,0], 8*np.pi*dataBH1_M03_X[25,1],'o', color = '#b45c1f')


ax[0].plot(dataBH1_03_X[13:,0], 8*np.pi*dataBH1_03_X[13:,1], label = r'$c_{4}^{(1)}=-1/2,\; d_{4}^{(-1)}=-1$', 
           color = '#de8241')
ax[0].plot(dataBH1_03_X[:13,0], 8*np.pi*dataBH1_03_X[:13,1], ls=':',
           color = '#de8241')
ax[0].plot(dataBH1_03_X[13,0], 8*np.pi*dataBH1_03_X[13,1],'o', color = '#de8241')

ax[0].set_xlim(0.73, 1.00)
ax[0].set_ylim(2.5, 19.7)

ax[0].set_ylabel(r'$M_{95}\; [M_{\mathrm{Pl}}^{2}\; m^{-1}]$') #, fontsize=25
ax[0].set_xlabel(r'$\omega\;[m]$')

ax[0].legend(loc='best', frameon=False)


ax[0].axvspan(0.2, dataBH1_M03_X[25,0], ymin=0, ymax=0.97, facecolor='#b45c1f', alpha=0.08)
ax[0].axvspan(0.2, dataH1_M03[34,0], ymin=0, ymax=0.87, facecolor='#5079b9', alpha=0.2)
ax[0].axvspan(0.2, dataBS1[29,0], ymin=0, ymax=0.74, facecolor='#566874', alpha=0.1)
ax[0].axvspan(0.2, dataH1_03[22,0], ymin=0, ymax=0.64, facecolor='#419ede', alpha=0.1)
ax[0].axvspan(0.2, dataBH1_03_X[13,0], ymin=0, ymax=0.55, facecolor='#de8241', alpha=0.1)
ax[0].axvspan(0.991, 1, ymin=0, ymax=1, facecolor='blue', alpha=0.1)

######

ax[1].plot(dataBS[0:30,0], 8*np.pi*dataBS[0:30,1], label = r'$c_{4}^{(1)}=d_{4}^{(-1)}=0$', color = '#566874')
ax[1].plot(dataBS[29:35,0], 8*np.pi*dataBS[29:35,1],ls=':', color = '#566874')
ax[1].plot(dataBS[29,0], 8*np.pi*dataBS[29,1],'o', color = '#566874' )

ax[1].plot(dataH_M03[:35,0], 8*np.pi*dataH_M03[:35,1], label = r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0$', color = '#5079b9')
ax[1].plot(dataH_M03[34:,0], 8*np.pi*dataH_M03[34:,1], ls=':',color = '#5079b9')
ax[1].plot(dataH_M03[34,0], 8*np.pi*dataH_M03[34,1],'o', color= '#5079b9')

ax[1].plot(dataH_03[:23,0], 8*np.pi*dataH_03[0:23,1], label = r'$c_{4}^{(1)}=-1/2, \;d_{4}^{(-1)}=0$', color = '#419ede')
ax[1].plot(dataH_03[22:32,0], 8*np.pi*dataH_03[22:32,1], ls=':', color = '#419ede')
ax[1].plot(dataH_03[22,0], 8*np.pi*dataH_03[22,1],'o', color = '#419ede')

ax[1].plot(dataBH_M03_X[3:,0], 8*np.pi*dataBH_M03_X[3:,1],label = r'$c_{4}^{(1)}=1/2,\; d_{4}^{(-1)}=1$', color = '#b45c1f')
ax[1].plot(dataBH_M03_X[:4,0], 8*np.pi*dataBH_M03_X[:4,1],ls=':', color = '#b45c1f')
ax[1].plot(dataBH_M03_X[3,0], 8*np.pi*dataBH_M03_X[3,1],'o', color = '#b45c1f') 

ax[1].plot(dataBH_03_X[5:,0], 8*np.pi*dataBH_03_X[5:,1], label = r'$c_{4}^{(1)}=-1/2,\; d_{4}^{(-1)}=-1$', color = '#de8241')
ax[1].plot(dataBH_03_X[:6,0], 8*np.pi*dataBH_03_X[:6,1], ls=':', color = '#de8241')
ax[1].plot(dataBH_03_X[5,0], 8*np.pi*dataBH_03_X[5,1],'o', color = '#de8241')

#ax[1].set_xlim(3., 30)
ax[1].set_ylim(2.5, 19.7)
ax[1].set_xlim(3., 38)
#ax[1].set_ylim(8, 19.7)



ax[1].set_ylabel(r'$M_{95}\; [M_{\mathrm{Pl}}^{2}\; m^{-1}]$') # , fontsize = 25
ax[1].set_xlabel(r'$R_{95}\;[m^{-1}]$')# , fontsize = 25

ax[1].legend(loc=(.45,.51),frameon=False); #frameon=False

ax[1].axvspan(1, 5.2, ymin=0, ymax=0.97, facecolor='#b45c1f', alpha=0.08)
ax[1].axvspan(1, 4.7, ymin=0, ymax=0.87, facecolor='#5079b9', alpha=0.2)
ax[1].axvspan(1, 6.2, ymin=0, ymax=0.74, facecolor='#566874', alpha=0.1)
ax[1].axvspan(1, 7.2, ymin=0, ymax=0.64, facecolor='#419ede', alpha=0.1)
ax[1].axvspan(1, 9.5, ymin=0, ymax=0.55, facecolor='#de8241', alpha=0.1)
ax[1].axvspan(36.5, 39, ymin=0, ymax=1, facecolor='blue', alpha=0.1)


angle2=90
plt.figtext(.475, .35, r'$\sim\mathrm{SP}$ system', {'color': '0', 'fontsize': 15},
            rotation=angle2, rotation_mode='anchor')

angle2=90
plt.figtext(.897, .35, r'$\sim\mathrm{SP}$ system', {'color': '0', 'fontsize': 15},
            rotation=angle2, rotation_mode='anchor')
# Out:
# Text(0.897, 0.35, '$\\sim\\mathrm{SP}$ system')

# %%
ax[1].plot(dataBS[0:30,0], 8*np.pi*dataBS[0:30,1], label = r'$c_{4}^{(1)}=d_{4}^{(-1)}=0$', color = '#566874')
ax[1].plot(dataBS[29:35,0], 8*np.pi*dataBS[29:35,1],ls=':', color = '#566874')

ax[1].plot(dataH_M03[:35,0], 8*np.pi*dataH_M03[:35,1], label = r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0$', color = '#5079b9')
ax[1].plot(dataH_M03[34:,0], 8*np.pi*dataH_M03[34:,1], ls=':',color = '#5079b9')

ax[1].plot(dataH_03[:23,0], 8*np.pi*dataH_03[0:23,1], label = r'$c_{4}^{(1)}=-1/2, \;d_{4}^{(-1)}=0$', color = '#419ede')
ax[1].plot(dataH_03[22:32,0], 8*np.pi*dataH_03[22:32,1], ls=':', color = '#419ede')

ax[1].plot(dataBH_M03_X[3:,0], 8*np.pi*dataBH_M03_X[3:,1],label = r'$c_{4}^{(1)}=1/2,\; d_{4}^{(-1)}=1$', color = '#b45c1f')
ax[1].plot(dataBH_M03_X[:4,0], 8*np.pi*dataBH_M03_X[:4,1],ls=':', color = '#b45c1f')

ax[1].plot(dataBH_03_X[5:,0], 8*np.pi*dataBH_03_X[5:,1], label = r'$c_{4}^{(1)}=-1/2,\; d_{4}^{(-1)}=-1$', color = '#de8241')
ax[1].plot(dataBH_03_X[:6,0], 8*np.pi*dataBH_03_X[:6,1], ls=':', color = '#de8241')

# %%
plt.plot(dataBH_M03_X[3:,0], 8*np.pi*dataBH_M03_X[3:,1], '-', color = '#b45c1f')
plt.plot(dataBH_03_X[5:,0], 8*np.pi*dataBH_03_X[5:,1], '-',color = '#de8241')
plt.xlim(4,35);

# %%
plt.plot(dataBH1_M03_X[:26,0], 8*np.pi*dataBH1_M03_X[:26,1], '-' , color = '#b45c1f')
plt.plot(dataBH1_03_X[13:,0], 8*np.pi*dataBH1_03_X[13:,1], '-', color = '#de8241')
