# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as font_manager
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
#from matplotlib.patches import Rectangle

from cycler import cycler

# %%
# estructura para latex
mpl.use("pgf")

# estilo de linea y grosor
mpl.rcParams['lines.linestyle'] = '-'
mpl.rcParams['lines.linewidth'] = 2.

# orden de los colores que usará
mpl.rcParams['axes.prop_cycle'] = cycler('color', ['#1f77b4', '#ff7f0e', '#2ca02c', 
                                                   '#d62728', '#9467bd', '#8c564b', '#e377c2', 
                                                   '#7f7f7f', '#bcbd22', '#17becf'])
#cycler(color=['r', 'g', 'b', 'y'])

# latex modo math
mpl.rcParams['mathtext.fontset'] = 'cm'  # Should be 'dejavusans' (default),
                                         # 'dejavuserif', 'cm' (Computer Modern), 'stix',
                                         # 'stixsans' or 'custom'
        
mpl.rcParams['mathtext.fallback_to_cm']= True # When True, use symbols from the Computer Modern
                                              # fonts when a symbol can not be found in one of
                                              # the custom math fonts.
    
# Texto
mpl.rcParams['font.family'] = 'serif' # serif, sans-serif, cursive, fantasy, monospace
cmfont = font_manager.FontProperties(fname=mpl.get_data_path() + '/fonts/ttf/cmr10.ttf')
mpl.rcParams['font.serif']=cmfont.get_name()
mpl.rcParams['font.size'] = 16 # tamaño de la letra

###
mpl.rcParams['pgf.texsystem'] = 'pdflatex'
mpl.rcParams['text.usetex'] = True
mpl.rcParams['pgf.rcfonts'] = False
mpl.rcParams['text.latex.preamble'] = [r'\usepackage{amssymb}'] # \usepackage{txfonts}


mpl.rcParams['pgf.preamble'] = ['\\usepackage{amssymb}']
###


#mpl.rcParams['axes.titlepad'] = 6.0     # pad between axes and title in points
mpl.rcParams['axes.labelpad'] = 3.0 #10.0     # space between label and axis
mpl.rcParams['axes.labelweight'] = 'normal'  # weight (grosor) of the x and y labels
mpl.rcParams['axes.labelcolor'] = 'black'
mpl.rcParams['axes.unicode_minus'] = False # use Unicode for the minus symbol
mpl.rcParams['axes.linewidth'] = 1     # edge linewidth, grosor del marco

#mpl.rcParams['axes.titlesize'] = 24
mpl.rcParams['axes.labelsize'] = 16
#mpl.rcParams['lines.markersize'] = 10


# display axis spines, muestra la linea de los marcos
mpl.rcParams['axes.spines.left'] = True
mpl.rcParams['axes.spines.bottom'] = True
mpl.rcParams['axes.spines.top'] = True
mpl.rcParams['axes.spines.right'] = True

# Figura
#mpl.rcParams['figure.dpi'] = 100 # figure dots per inch
mpl.rcParams['figure.figsize'] = [12, 9]# [4,3] # 
mpl.rcParams['figure.facecolor'] = 'white'     # figure facecolor
mpl.rcParams['figure.edgecolor'] = 'white'     # figure edgecolor
mpl.rcParams['savefig.dpi'] = 100

mpl.rcParams['xtick.labelsize'] = 15 #'large' # tamaño de los números de los ejes
mpl.rcParams['ytick.labelsize'] = 15 #'large'
mpl.rcParams['xtick.direction'] = 'out' # direction: {in, out, inout} señalamiento de los ejes
mpl.rcParams['ytick.direction'] = 'out' # direction: {in, out, inout}
mpl.rcParams['xtick.top'] = False # draw ticks on the top side
mpl.rcParams['ytick.right'] = False # draw ticks on the top side
#xtick.labeltop      : False   ## draw label on the top
mpl.rcParams['xtick.labelbottom'] = True    # draw label on the bottom

mpl.rcParams['xtick.major.bottom'] = True   # draw x axis bottom major ticks
#mpl.rcParams['xtick.major.top'] = True   # draw x axis top major ticks
mpl.rcParams['xtick.minor.bottom'] = False    ## draw x axis bottom minor ticks
#mpl.rcParams['xtick.minor.top'] = True    ## draw x axis top minor ticks

mpl.rcParams['xtick.minor.visible'] = True  # visibility of minor ticks on x-axis

#xtick.alignment     : center  ## alignment of xticks
#xtick.alignment     : center  ## alignment of xticks

# Legend
mpl.rcParams['legend.loc'] = 'best'
mpl.rcParams['legend.frameon'] = True # if True, draw the legend on a background patch
mpl.rcParams['legend.framealpha'] = 0.19 # 0.8 legend patch transparency
mpl.rcParams['legend.facecolor'] = 'inherit'  # inherit from axes.facecolor; or color spec
mpl.rcParams['legend.edgecolor'] = 'inherit' # background patch boundary color
mpl.rcParams['legend.fancybox'] = True     # if True, use a rounded box for the

#mpl.rcParams['legend.numpoints'] = 1 # the number of marker points in the legend line
#mpl.rcParams['legend.scatterpoints'] = 1 # number of scatter points
#mpl.rcParams['legend.markerscale'] = 1.0 # the relative size of legend markers vs. original
mpl.rcParams['legend.fontsize'] = 14 # 'medium' 'large'

## Dimensions as fraction of fontsize:
mpl.rcParams['legend.borderpad'] = 0.4  ## border whitespace espacio de los bordes con respecto al texto
mpl.rcParams['legend.labelspacing'] = 0.5  ## the vertical space between the legend entries
mpl.rcParams['legend.handlelength'] = 1.5  ## the length of the legend lines defauld 2
#mpl.rcParams['legend.handleheight'] = 0.7  ## the height of the legend handle
mpl.rcParams['legend.handletextpad'] = 0.8  ## the space between the legend line and legend text
#mpl.rcParams['legend.borderaxespad'] = 0.5  ## the border between the axes and legend edge
#mpl.rcParams['legend.columnspacing'] = 8.0  ## column separation
# Out:
# <ipython-input-6-7253cdea030d>:19: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   mpl.rcParams['mathtext.fallback_to_cm']= True # When True, use symbols from the Computer Modern
# <ipython-input-6-7253cdea030d>:19: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   mpl.rcParams['mathtext.fallback_to_cm']= True # When True, use symbols from the Computer Modern
# <ipython-input-6-7253cdea030d>:19: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   mpl.rcParams['mathtext.fallback_to_cm']= True # When True, use symbols from the Computer Modern
# ...

# %%
class OOMFormatter(mpl.ticker.ScalarFormatter):
    def __init__(self, order=0, fformat="%1.1f", offset=True, mathText=True):
        self.oom = order
        self.fformat = fformat
        mpl.ticker.ScalarFormatter.__init__(self,useOffset=offset,useMathText=mathText)
    
    def _set_orderOfMagnitude(self, nothing):
        self.orderOfMagnitude = self.oom
    
    def _set_format(self):
        self.format = self.fformat
        if self._useMathText:
            self.format = '$%s$' % mpl.ticker._mathdefault(self.format)

# %%
#sigma=0.3 # phi0=0.035

#beyond

dataBHX_m03A035 = np.loadtxt('X_m03A035.dat', usecols=(0,1))
dataBHX_03A035 = np.loadtxt('X_03A035.dat', usecols=(0,1))

dataBHMm03A035 = np.loadtxt('BHX_Mm03A035.dat', usecols=(0,1))
dataBHM03A035 = np.loadtxt('BHX_M03A035.dat', usecols=(0,1))

dataBHm03A035 = np.loadtxt('BHXm03A035.dat', usecols=(0,1)) 
dataBH03A035 = np.loadtxt('BHX03A035.dat', usecols=(0,1))

# horndeski
dataHX_m03A035 = np.loadtxt('HX_m03A035.dat', usecols=(0,1))
dataHX_03A035 = np.loadtxt('HX_03A035.dat', usecols=(0,1))

dataHMm03A035 = np.loadtxt('HX_Mm03A035.dat', usecols=(0,1))
dataHM03A035 = np.loadtxt('HX_M03A035_P.dat', usecols=(0,1))

dataHm03A035 = np.loadtxt('HXm03A035.dat', usecols=(0,1)) 
dataH03A035 = np.loadtxt('HX03A035.dat', usecols=(0,1))

# KG

dataXKG = np.loadtxt('KG_XA035.dat', usecols=(0,1)) 

dataphiKG = np.loadtxt('KGA035.dat', usecols=(0,1)) 
dataMKG = np.loadtxt('KGMA035.dat', usecols=(0,1))

# %%
#sigma=0.3 # phi0=0.035

#beyond

dataBoxBHX_m03A035 = np.loadtxt('BHmBox.dat', usecols=(0,1))
dataBoxBHX_03A035 = np.loadtxt('BHBox.dat', usecols=(0,1))

# horndeski
dataBoxHX_m03A035 = np.loadtxt('HmBox.dat', usecols=(0,1))
dataBoxHX_03A035 = np.loadtxt('HBox.dat', usecols=(0,1))

# KG
dataBoxXKG = np.loadtxt('BSBox.dat', usecols=(0,1))

# %%
# X/Lambda^2
rad = np.arange(0,7.5, 0.1)
#mpl.rcParams['text.latex.preamble'] = [r'\usepackage{amssymb}'] # \usepackage{txfonts}

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 5.5))

ax[0].plot(dataBHX_03A035[:,0], 8*np.pi*dataBHX_03A035[:,1]*0.3, 
           label=r'$c_{4}^{(1)}=-1/2,\; d_{4}^{(-1)}=-1$', color = '#de8241') #(bHS)

ax[0].plot(dataHX_03A035[:,0], 8*np.pi*dataHX_03A035[:,1]*0.3, 
           label=r'$c_{4}^{(1)}=-1/2, \;d_{4}^{(-1)}=0$', color = '#419ede') # (HS)

ax[0].plot(dataXKG[:,0], 8*np.pi*dataXKG[:,1]*0.3, 
           label='$c_{4}^{(1)}=d_{4}^{(-1)}=0\;(\mathrm{EKG})$', color = '#566874') # (BS)

ax[0].plot(dataHX_m03A035[:,0], 8*np.pi*dataHX_m03A035[:,1]*0.3, 
           label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0$', color = '#5079b9') # (HS)

ax[0].plot(dataBHX_m03A035[:,0], 8*np.pi*dataBHX_m03A035[:,1]*0.3, 
           label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=1$', color = '#b45c1f') # (bHS)

ax[0].set_xlim(0, 10) # apply the x-li4mits

ax[0].set_ylabel(r'$X\;[\Lambda_{2}^{4}]$')#
ax[0].set_xlabel(r'$r\;[m^{-1}]$')#

ax[0].legend(frameon=False)

# box
ax[1].plot(dataBoxBHX_m03A035[:,0], np.sqrt(8*np.pi)*dataBoxBHX_m03A035[:,1]*0.3,
           label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=1$', color = '#b45c1f') # (bHS)

ax[1].plot(dataBoxHX_m03A035[:,0], np.sqrt(8*np.pi)*dataBoxHX_m03A035[:,1]*0.3, 
           label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0$', color = '#5079b9') # (HS)

ax[1].plot(dataBoxXKG[:,0], np.sqrt(8*np.pi)*dataBoxXKG[:,1]*0.3, 
           label='$c_{4}^{(1)}=d_{4}^{(-1)}=0\;(\mathrm{EKG})$', color = '#566874') # (BS)

ax[1].plot(dataBoxHX_03A035[:,0], np.sqrt(8*np.pi)*dataBoxHX_03A035[:,1]*0.3, 
           label=r'$c_{4}^{(1)}=-1/2, \;d_{4}^{(-1)}=0$', color = '#419ede') # (HS)

ax[1].plot(dataBoxBHX_03A035[:,0], np.sqrt(8*np.pi)*dataBoxBHX_03A035[:,1]*0.3,
           label=r'$c_{4}^{(1)}=-1/2,\; d_{4}^{(-1)}=-1$', color = '#de8241') # (bHS)

ax[1].set_xlim(0, 10) # apply the x-li4mits
##ax.set_ylim(0.5, 1.4)

ax[1].set_ylabel(r'$|\Box \phi|\;[\Lambda_{3}^{3}]$')#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax[1].set_xlabel(r'$r\;[m^{-1}]$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

ax[1].legend(frameon=False)

# %%
plt.savefig('X.pgf', 
            #This is simple recomendation for publication plots
            dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

#plt.savefig('rho_profile.pgf')
plt.savefig("X.png",dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

# %%
from scipy.interpolate import interp1d, Rbf, InterpolatedUnivariateSpline

IntKG=InterpolatedUnivariateSpline(dataphiKG[:, 0], np.sqrt(8*np.pi)*dataphiKG[:,1])

IntHm03A035=InterpolatedUnivariateSpline(dataHm03A035[:, 0], np.sqrt(8*np.pi)*dataHm03A035[:,1])
IntH03A035=InterpolatedUnivariateSpline(dataH03A035[:, 0], np.sqrt(8*np.pi)*dataH03A035[:,1])

IntBHm03A035=InterpolatedUnivariateSpline(dataBHm03A035[:, 0], np.sqrt(8*np.pi)*dataBHm03A035[:,1])
IntBH03A035=InterpolatedUnivariateSpline(dataBH03A035[:, 0], np.sqrt(8*np.pi)*dataBH03A035[:,1])

# %%
# phi
rad = np.arange(0, 10, 0.1)

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 5.5))

ax[0].plot(dataBHm03A035[:,0], np.sqrt(8*np.pi)*dataBHm03A035[:,1], 
           label=r'$c_{4}^{(1)}=1/2,\;d_{4}^{(-1)}=1$', color = '#b45c1f') # (bHS)

ax[0].plot(dataHm03A035[:,0], np.sqrt(8*np.pi)*dataHm03A035[:,1], 
           label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0$', color = '#5079b9') # (HS)

ax[0].plot(dataphiKG[:,0], np.sqrt(8*np.pi)*dataphiKG[:,1], label='$c_{4}^{(1)}=d_{4}^{(-1)}=0\;(\mathrm{EKG})$', 
           color = '#566874') # (BS)

ax[0].plot(dataH03A035[:,0], np.sqrt(8*np.pi)*dataH03A035[:,1], 
           label=r'$c_{4}^{(1)}=-1/2, \;d_{4}^{(-1)}=0$', color = '#419ede') # (HS)

ax[0].plot(dataBH03A035[:,0], np.sqrt(8*np.pi)*dataBH03A035[:,1],
           label=r'$c_{4}^{(1)}=-1/2,\;d_{4}^{(-1)}=-1$', color = '#de8241') # (bHS)

left, bottom, width, height = [0.18, 0.18, 0.12, 0.16]
ax1 = fig.add_axes([left, bottom, width, height])

#ax1.yaxis.set_major_formatter(OOMFormatter(-2, "%1.1f"))
ax1.ticklabel_format(axis='y', style='sci', scilimits=(-2,-2))

ax1.plot(rad, (IntKG(rad)-IntHm03A035(rad))/IntKG(rad), color = '#5079b9')
ax1.plot(rad, (IntKG(rad)-IntH03A035(rad))/IntKG(rad), color = '#419ede')

ax1.plot(rad, (IntKG(rad)-IntBHm03A035(rad))/IntKG(rad), color = '#b45c1f')
ax1.plot(rad, (IntKG(rad)-IntBH03A035(rad))/IntKG(rad), color = '#de8241')

ax1.set_yticks(np.arange(-0.15, 0.156, 0.1))
ax1.set_ylim(-0.15, .15)
ax1.set_xlim(0, 10)

ax1.set_ylabel(r'$1-\sigma_{\;\mathrm{i}}/\sigma_{\;\mathrm{BS}}$')
#(r'$1-\frac{\sigma_{\;\mathrm{i}}}{\sigma_{\;\mathrm{BS}}}$')

ax[0].set_xlim(0, 10) # apply the x-li4mits
#ax.set_ylim(0.5, 1.4)

ax[0].set_ylabel(r'$\sigma\;\,[M_{\mathrm{Pl}}]$')#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax[0].set_xlabel(r'$r\;[m^{-1}]$')#, fontsize=17

ax[0].legend(loc='upper right', frameon=False)
#ax.legend(loc=(.72, .6),frameon=False);

ax[1].plot(dataBHMm03A035[:,0], 8*np.pi*dataBHMm03A035[:,1], 
           label=r'$c_{4}^{(1)}=1/2,\; d_{4}^{(-1)}=1$', color = '#b45c1f') # (bHS)

ax[1].plot(dataHMm03A035[:,0], 8*np.pi*dataHMm03A035[:,1], 
           label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0$', color = '#5079b9') #(HS)

ax[1].plot(dataMKG[:,0], 8*np.pi*dataMKG[:,1], label='$c_{4}^{(1)}=d_{4}^{(-1)}=0\;(\mathrm{EKG})$', 
           color = '#566874') # (BS)

ax[1].plot(dataHM03A035[:,0], 8*np.pi*dataHM03A035[:,1], 
           label=r'$c_{4}^{(1)}=-1/2, \;d_{4}^{(-1)}=0$', color = '#419ede') #(HS)

ax[1].plot(dataBHM03A035[:,0], 8*np.pi*dataBHM03A035[:,1],
           label=r'$c_{4}^{(1)}=-1/2,\; d_{4}^{(-1)}=-1$', color = '#de8241') #(bHS)


ax[1].set_xlim(0, 10) # apply the x-li4mits
#ax.set_ylim(0.5, 1.4)

ax[1].set_ylabel(r'$M\;\,[M_{\mathrm{Pl}}^{2}\; m^{-1}]$')# , fontsize=17
ax[1].set_xlabel(r'$r\;[m^{-1}]$')# , fontsize=17

#matplotlib.rcParams['legend.fontsize'] = 25
#ax.legend(('Numerical solution', 'Analytical fitting'),loc='upper right',frameon=False)
ax[1].legend(loc='lower right',frameon=False) # loc=(0.41, 0.001)

# %%
plt.savefig('rho_profile.pgf', 
            #This is simple recomendation for publication plots
            dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

#plt.savefig('rho_profile.pgf')
plt.savefig("rho_profile.png",dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

# %%
# E-KG
dataBS1 = np.loadtxt('Func_wM_0.dat', usecols=(0,1)) 

# Horndeski
dataH1_M03 = np.loadtxt('Func_wM_M03_H.dat', usecols=(0,1)) 
dataH1_03 = np.loadtxt('Func_wM_03_H.dat', usecols=(0,1)) 

# beyond X
#dataBH1_M03_X = np.loadtxt('Func_wM_M03_BH_X.dat', usecols=(0,1)) 
dataBH1_M03_X = np.loadtxt('2Func_wM_M03_BH_X.dat', usecols=(0,1)) 
dataBH1_03_X = np.loadtxt('Dat_wvsM95_eta03_X.dat', usecols=(0,1))

# %%
fig, ax = plt.subplots(figsize=(12,9))

ax.plot(dataBS1[:,0], 8*np.pi*dataBS1[:, 1], label = '$c_{4}^{(1)}=d_{4}^{(-1)}=0$', color = '#566874')
ax.plot(dataH1_M03[:,0], 8*np.pi*dataH1_M03[:,1], label = r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0$', color = '#5079b9')
ax.plot(dataH1_03[:,0], 8*np.pi*dataH1_03[:,1], label = r'$c_{4}^{(1)}=-1/2, \;d_{4}^{(-1)}=0$', color = '#419ede')
ax.plot(dataBH1_M03_X[:,0], 8*np.pi*dataBH1_M03_X[:,1], label = r'$c_{4}^{(1)}=1/2,\; d_{4}^{(-1)}=1$', color = '#b45c1f')
ax.plot(dataBH1_03_X[:,0], 8*np.pi*dataBH1_03_X[:,1], label = r'$c_{4}^{(1)}=-1/2,\; d_{4}^{(-1)}=-1$', color = '#de8241')

ax.set_xlim(0.72, 1.005)
ax.set_ylim(2.5, 19.7)

ax.set_ylabel(r'$M_{95}\; [M_{\mathrm{Pl}}^{2}\; m^{-1}]$') #, fontsize=25
ax.set_xlabel(r'$\omega^{new}\;[m]$')

ax.legend(frameon=False);

# %%
# E-KG
dataBS = np.loadtxt('Func_rM_0.dat', usecols=(0,1)) 
maxBS = np.array([[6.00924 ,0.601351]]) 

# Horndeski
dataH_M03 = np.loadtxt('Func_rM_MH.dat', usecols=(0,1)) 
dataH_03 = np.loadtxt('Func_rM_H.dat', usecols=(0,1)) 

maxH_M03 = np.array([[4.56024, 0.699697]]) 
maxH_03 = np.array([[7.11511, 0.536516]])

# beyond X
#dataBH_M03_X = np.loadtxt('Func_rM_MBHX.dat', usecols=(0,1)) 
dataBH_M03_X = np.loadtxt('2Dat_mvsr_etaM03_X.dat', usecols=(0,1)) 
maxBH_M03_X = np.array([[5.14747, 0.761286]])

dataBH_03_X = np.loadtxt('2Dat_mvsr_eta03_X.dat', usecols=(0,1))
maxBH_03_X = np.array([[9.43157, 0.477007]])

maxBH_M03_X2 = np.array([[6.14582, 0.612864]]) 
#maxBH_M03_X2 = np.array([[6.07614, 0.609814]]) 
maxBH_03_X2 = np.array([[6.02618, 0.600102]])

# %%
plt.plot(dataBH_M03_X[:,0],  8*np.pi*dataBH_M03_X[:,1])
plt.plot(dataBH_03_X[:,0],  8*np.pi*dataBH_03_X[:,1])

# %%
fig, ax = plt.subplots(figsize=(12,9))


ax.plot(dataBS[:,0], 8*np.pi*dataBS[:,1], label = '$c_{4}^{(1)}=d_{4}^{(-1)}=0$', color = '#566874')
ax.plot(maxBS[:,0], 8*np.pi*maxBS[:,1],'o', color = '#566874' )

ax.plot(dataH_M03[:,0], 8*np.pi*dataH_M03[:,1], label = r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0$', color = '#5079b9')
ax.plot(maxH_M03[:,0], 8*np.pi*maxH_M03[:,1],'o', color= '#5079b9')

ax.plot(dataH_03[:,0], 8*np.pi*dataH_03[:,1], label = r'$c_{4}^{(1)}=-1/2, \;d_{4}^{(-1)}=0$', color = '#419ede')
ax.plot(maxH_03 [:,0], 8*np.pi*maxH_03 [:,1],'o', color = '#419ede')

ax.plot(dataBH_M03_X[:,0], 8*np.pi*dataBH_M03_X[:,1], label = r'$c_{4}^{(1)}=1/2,\; d_{4}^{(-1)}=1$', color = '#b45c1f')
ax.plot(maxBH_M03_X[:,0], 8*np.pi*maxBH_M03_X[:,1],'o', color = '#b45c1f') 

ax.plot(dataBH_03_X[:,0], 8*np.pi*dataBH_03_X[:,1], label = r'$c_{4}^{(1)}=-1/2,\; d_{4}^{(-1)}=-1$', color = '#de8241')
ax.plot(maxBH_03_X [:,0], 8*np.pi*maxBH_03_X [:,1],'o', color = '#de8241')

ax.set_xlim(0., 30)
ax.set_ylim(2.5, 19.7)

ax.set_ylabel(r'$M_{95}\; [M_{\mathrm{Pl}}^{2}\; m^{-1}]$') # , fontsize = 25
ax.set_xlabel(r'$R_{95}\;[m^{-1}]$')# , fontsize = 25

ax.legend(frameon=False); #frameon=False

# %%
len(dataH_03)
# Out:
# 35

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 5.5))

ax[0].plot(dataBS1[0:35,0], 8*np.pi*dataBS1[0:35, 1], label = r'$c_{4}^{(1)}=d_{4}^{(-1)}=0$', 
           color = '#566874') # (BS)
ax[0].plot(dataH1_M03[:,0], 8*np.pi*dataH1_M03[:,1], label = r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0$', 
           color = '#5079b9')
ax[0].plot(dataH1_03[0:32,0], 8*np.pi*dataH1_03[0:32,1], label = r'$c_{4}^{(1)}=-1/2, \;d_{4}^{(-1)}=0$', 
           color = '#419ede')
ax[0].plot(dataBH1_M03_X[:,0], 8*np.pi*dataBH1_M03_X[:,1], label = r'$c_{4}^{(1)}=1/2,\; d_{4}^{(-1)}=1$', 
           color = '#b45c1f')
ax[0].plot(dataBH1_03_X[:,0], 8*np.pi*dataBH1_03_X[:,1], label = r'$c_{4}^{(1)}=-1/2,\; d_{4}^{(-1)}=-1$', 
           color = '#de8241')

ax[0].set_xlim(0.73, 1.00)
ax[0].set_ylim(2.5, 19.7)

ax[0].set_ylabel(r'$M_{95}\; [M_{\mathrm{Pl}}^{2}\; m^{-1}]$') #, fontsize=25
ax[0].set_xlabel(r'$\omega\;[m]$')

ax[0].legend(loc='best', frameon=False)

ax[1].plot(dataBS[0:35,0], 8*np.pi*dataBS[0:35,1], label = r'$c_{4}^{(1)}=d_{4}^{(-1)}=0$', color = '#566874')
ax[1].plot(maxBS[:,0], 8*np.pi*maxBS[:,1],'o', color = '#566874' )

ax[1].plot(dataH_M03[:,0], 8*np.pi*dataH_M03[:,1], label = r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0$', 
           color = '#5079b9')
ax[1].plot(maxH_M03[:,0], 8*np.pi*maxH_M03[:,1],'o', color= '#5079b9')

ax[1].plot(dataH_03[0:32,0], 8*np.pi*dataH_03[0:32,1], label = r'$c_{4}^{(1)}=-1/2, \;d_{4}^{(-1)}=0$', 
           color = '#419ede')
ax[1].plot(maxH_03 [:,0], 8*np.pi*maxH_03 [:,1],'o', color = '#419ede')

ax[1].plot(dataBH_M03_X[:,0], 8*np.pi*dataBH_M03_X[:,1],label = r'$c_{4}^{(1)}=1/2,\; d_{4}^{(-1)}=1$', 
           color = '#b45c1f')
ax[1].plot(maxBH_M03_X[:,0], 8*np.pi*maxBH_M03_X[:,1],'o', color = '#b45c1f') 

ax[1].plot(dataBH_03_X[:,0], 8*np.pi*dataBH_03_X[:,1], label = r'$c_{4}^{(1)}=-1/2,\; d_{4}^{(-1)}=-1$', 
           color = '#de8241')
ax[1].plot(maxBH_03_X [:,0], 8*np.pi*maxBH_03_X [:,1],'o', color = '#de8241')

ax[1].set_xlim(3., 30)
ax[1].set_ylim(2.5, 19.7)

ax[1].set_ylabel(r'$M_{95}\; [M_{\mathrm{Pl}}^{2}\; m^{-1}]$') # , fontsize = 25
ax[1].set_xlabel(r'$R_{95}\;[m^{-1}]$')# , fontsize = 25

ax[1].legend(frameon=False); #frameon=False

# %%
plt.savefig('w_M.pgf', 
            #This is simple recomendation for publication plots
            dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

#plt.savefig('rho_profile.pgf')
plt.savefig("w_M.png",dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
           )

# %%
# Case Beyond Horndeski with X, 
# eta = -0.3

#####
# phi0 = 0.03
# masa95 = 0.681363760338376
# radio95 = 8.9595

lens1 = np.loadtxt('Lensing_beyond_X_003.dat', usecols=(0,1)) 
dif1 = np.loadtxt('Dif_Lensing_beyond_X_003.dat', usecols=(0,1)) 

####
# phi0 = 0.015
# masa95 = 0.522599
# radio95 = 13.181

lens2 = np.loadtxt('Lensing_beyond_X_0015.dat', usecols=(0,1)) 
dif2 = np.loadtxt('Dif_Lensing_beyond_X_0015.dat', usecols=(0,1)) 

#  Soluciones analíticas
lens = lambda r: np.pi*(np.power(1/(1-(8*Masa)/(np.pi*r)),0.5)-1)

# %%
fig, ax = plt.subplots(2, sharex=True, sharey=False,
                       gridspec_kw=dict(height_ratios=[3,1]))#gridspec_kw={'hspace': 0}figsize=(12,9), 

rad=np.arange(lens1[0,0], lens1[-1,0], 0.01) # radios barras
Masa=0.681363760338376
ax[0].plot(rad, lens(rad), label='Black Hole', color = 'black')
ax[0].plot(lens1[:,0], lens1[:,1], label = r'bHS ($c_{1}=c_{2}=-1$)', color = '#b45c1f')

#linea vertical
ax[0].axvline(x=8.9595, color='lightcoral', linestyle=':')
ax[1].axvline(x=8.9595, color='lightcoral', linestyle=':')

angle2=90
plt.figtext(.215, .738, r'$\mathrm{R}_{95}=8.96$', {'color': 'lightcoral', 'fontsize': 20},
            rotation=angle2, rotation_mode='anchor')

ax[0].axvline(x=13.5325, color='dimgrey', linestyle=':')
ax[1].axvline(x=13.5325, color='dimgrey', linestyle=':')

angle2=90
plt.figtext(.3725, .645, r'$G_{\mathrm{eff}}=G+\sigma_{_{\mathrm{CODATA}}}$', {'color': 'dimgrey', 'fontsize': 20},
            rotation=angle2, rotation_mode='anchor')


ax[1].plot(dif1[:,0], dif1[:,1], color = 'red')

x1, x2, y1, y2 =lens1[0,0], 30, lens1[0,1], 0.5 #
ax[0].set_xlim(x1, x2) # apply the x-limits
#ax.set_ylim(y1, y2)

ax[0].set_ylabel(r'$\Delta\phi^{\;(1)}$', fontsize=25)#, rotation=0, fontsize=20, labelpad=25)#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')

ax[1].set_ylabel(r'$1-\frac{\Delta\phi^{\;(1)}}{\Delta\phi^{\;\mathrm{BH}}}$', fontsize=25)
ax[1].set_xlabel(r'$r_{0}\;[m^{-1}]$', fontsize=25)#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

ax[1].set_yticks(np.arange(0, 0.11, 0.05))

ax[0].legend(loc='upper right',frameon=False)

#ax[0].set_title(r'$\bar{\eta}=-0.3$', loc='right', fontsize=25)
#ax[0].set_title(r'$\bar{\mathrm{M}}= 0.68$', loc='left', fontsize=25)

plt.subplots_adjust(wspace=0, hspace=0)

# %%
fig, ax = plt.subplots(2, sharex=True, sharey=False,
                       gridspec_kw=dict(height_ratios=[3,1]))#gridspec_kw={'hspace': 0}figsize=(12,9), 

rad=np.arange(lens1[0,0], lens1[-1,0], 0.01) # radios barras
Masa=0.681363760338376
ax[0].plot(rad, lens(rad), label='Black Hole', color = 'black')
ax[0].plot(lens1[:,0], lens1[:,1], label = r'$c_{4}^{(1)}=1/2,\; d_{4}^{(-1)}=1$', color = '#b45c1f') # (bHS)

#linea vertical
ax[0].axvline(x=8.9595, color='lightcoral', linestyle=':')
ax[1].axvline(x=8.9595, color='lightcoral', linestyle=':')

angle2=90
plt.figtext(.261, .738, r'$\mathrm{R}_{95}=8.96$', {'color': 'lightcoral'},
            rotation=angle2, rotation_mode='anchor')#, 'fontsize': 20

ax[0].axvline(x=13.5325, color='dimgrey', linestyle=':')
ax[1].axvline(x=13.5325, color='dimgrey', linestyle=':')

angle2=90
plt.figtext(.58, .645, r'$G_{\mathrm{eff}}=G+\sigma_{_{\mathrm{CODATA}}}$', {'color': 'dimgrey'},
            rotation=angle2, rotation_mode='anchor')#, 'fontsize': 20


ax[1].plot(dif1[:,0], dif1[:,1], color = 'red')

x1, x2, y1, y2 =lens1[0,0], 18, lens1[0,1], 0.5 #
ax[0].set_xlim(x1, x2) # apply the x-limits
#ax.set_ylim(y1, y2)

ax[0].set_ylabel(r'$\Delta\phi^{\;(1)}$')#,, fontsize=25 rotation=0, fontsize=20, labelpad=25)#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')

ax[1].set_ylabel(r'$1-\frac{\Delta\phi^{\;(1)}}{\Delta\phi^{\;\mathrm{BH}}}$')#, fontsize=25
ax[1].set_xlabel(r'$r_{0}\;[m^{-1}]$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$'), fontsize=25

ax[1].set_yticks(np.arange(0, 0.11, 0.05))

ax[0].legend(loc='upper right',frameon=False)

#ax[0].set_title(r'$\bar{\eta}=-0.3$', loc='right', fontsize=25)
#ax[0].set_title(r'$\bar{\mathrm{M}}= 0.68$', loc='left', fontsize=25)

plt.subplots_adjust(wspace=0, hspace=0)

# %%
plt.savefig('Fig1_Len.pgf', 
            #This is simple recomendation for publication plots
            dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

#plt.savefig('rho_profile.pgf')
plt.savefig("Fig1_Len.png",dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

# %%
from scipy.interpolate import interp1d, Rbf, InterpolatedUnivariateSpline

dataV = np.loadtxt('VanisX_1.dat', usecols=(0,1)) 
dataV2 = np.loadtxt('VanisX_2.dat', usecols=(0,1)) 

inter1 = np.array([[8.9595],[0.000884161]]) # R_95, V[] caso I con 0.03
viabl1 = np.array([[12.55],[4.7*10**-5]])

inter2 = np.array([[13.181],[0.000256172]]) # R_95, V[] caso II con 0.015
viabl2 = np.array([[16.22],[4.7*10**-5]])

dataP = np.loadtxt('D_3em02.dat', usecols=(0,1)) 

V=InterpolatedUnivariateSpline(dataV[:,0], np.log10(dataV[:,1]))

# %%
fig, ax = plt.subplots(figsize=(12,9))

rad=np.arange(0,30, 0.01)

ax.plot(rad, V(rad), label = r'$M=0.681\; [M_{\mathrm{Pl}}^{2}\; m^{-1}]$', color = '#897b30')
ax.plot([8.9595],np.log10([0.000884161]),'ro')

ax.plot(dataV2[:,0], np.log10(dataV2[:,1]), label=r'$M =0.523 \; [M_{\mathrm{Pl}}^{2}\; m^{-1}]$', 
        color='#419dde')
ax.plot([13.181],np.log10([0.000256172]),'ro')


leg22, = ax.plot(dataP[:,0], np.log10(dataP[:,1]), color='#30897b')#, label=r'$\bar{M}=0.477$')
ax.plot([9.13209],np.log10([0.000497858]),'ro')


plt.axhline(y=np.log10(0.000022), color='red', ls='-')
angle2=0
plt.figtext(.13, .463, r'Terrestrial experiments (CODATA 2018)', {'color': 'red', 'fontsize': 20},
            rotation=angle2, rotation_mode='anchor')


ax.axhspan(np.log10(0.02), np.log10(0.01), facecolor='0.75', alpha=0.5)
plt.figtext(0.13, 0.69, r'BBN, CMB, SNI or GW', {'color': '0', 'fontsize': 15},
            rotation=angle2, rotation_mode='anchor')


angle3=-25
plt.figtext(.647, .605, r'$\sigma_{0}=0.15\,M_{\mathrm{Pl}}$', {'color': '0', 'fontsize': 20},
            rotation=angle3, rotation_mode='anchor')

angle3=-20
plt.figtext(.75, .62, r'$\sigma_{0}=0.08\,M_{\mathrm{Pl}}$', {'color': 'blue', 'fontsize': 20},
            rotation=angle3, rotation_mode='anchor')


angle3=-25
plt.figtext(.54, .605, r'$\sigma_{0}=0.15\,M_{\mathrm{Pl}}$', {'color': 'green', 'fontsize': 20},
            rotation=angle3, rotation_mode='anchor')


ax.set_ylabel(r'$\log_{10}\,\left|1-\mathrm{G}^\mathrm{{I}}_{\mathrm{eff}}/\mathrm{G}\right| $',fontsize=27)#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax.set_xlabel(r'$r\;[m^{-1}]$',fontsize=27)#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

leg2 = ax.legend(loc = 'lower left', frameon=False, title = r'bHS ($c_{1}=c_{2}=-1$)', fontsize=25,
                title_fontsize='25')

ax.legend([leg22], [r'$M=0.477\; [M_{\mathrm{Pl}}^{2}\; m^{-1}]$'], loc=(.5,.13), frameon=False, 
          title = r'bHS ($c_{1}=c_{2}=1$)', labelspacing=0.5, title_fontsize='25')


ax.add_artist(leg2)


ax.set_xlim(0, 15)
ax.set_ylim(-9, 0)
# Out:
# (-9, 0)

# %% [markdown]
# esta

# %%
fig, ax = plt.subplots(figsize=(12,9))

rad=np.arange(0,30, 0.01)

ax.plot(rad, V(rad), label = r'$M=0.681\; [M_{\mathrm{Pl}}^{2}\; m^{-1}]$', color = '#897b30')
ax.plot([8.9595], np.log10([0.000884161]),'ro')

ax.plot(dataV2[:,0], np.log10(dataV2[:,1]), label=r'$M =0.523 \; [M_{\mathrm{Pl}}^{2}\; m^{-1}]$', 
        color='#419dde')
ax.plot([13.181],np.log10([0.000256172]),'ro')


leg22, = ax.plot(dataP[:,0], np.log10(dataP[:,1]), color='#30897b')#, label=r'$\bar{M}=0.477$')
ax.plot([9.13209], np.log10([0.000497858]),'ro')


plt.axhline(y=np.log10(0.000022), color='red', ls='-')
angle2=0
plt.figtext(.13, .315, r'Terrestrial experiments (CODATA 2018)', {'color': 'red'},
            rotation=angle2, rotation_mode='anchor')


ax.axhspan(np.log10(0.02), np.log10(0.01), facecolor='0.75', alpha=0.5)
plt.figtext(0.13, 0.625, r'BBN, CMB, SNI or GW', {'color': '0'},
            rotation=angle2, rotation_mode='anchor')


angle3=-30
plt.figtext(.63, .5, r'$\sigma_{0}=0.15\,M_{\mathrm{Pl}}$', {'color': '#897b30'},
            rotation=angle3, rotation_mode='anchor')

angle3=-20
plt.figtext(.65, .55, r'$\sigma_{0}=0.08\,M_{\mathrm{Pl}}$', {'color': 'blue'},
            rotation=angle3, rotation_mode='anchor')


angle3=-30
plt.figtext(.61, .45, r'$\sigma_{0}=0.15\,M_{\mathrm{Pl}}$', {'color': 'green'},
            rotation=angle3, rotation_mode='anchor')


ax.set_ylabel(r'$\log_{10}\,\left|1-\mathrm{G}^\mathrm{{I}}_{\mathrm{eff}}/\mathrm{G}\right| $')#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax.set_xlabel(r'$r\;[m^{-1}]$')

leg2 = ax.legend(loc = 'lower left', frameon=False, title = r'$c_{4}^{(1)}=1/2,\;d_{4}^{(-1)}=1$'
                 , title_fontsize='17') # fontsize=25,  (bHS)

ax.legend([leg22], [r'$M=0.477\; [M_{\mathrm{Pl}}^{2}\; m^{-1}]$'], loc=(.35,.07), frameon=False, 
          title = r'$c_{4}^{(1)}=-1/2,\;d_{4}^{(-1)}=-1$', labelspacing=0.5, title_fontsize='17') # (bHS)


ax.add_artist(leg2)


ax.set_xlim(0, 15)
ax.set_ylim(-6.5, 0)
# Out:
# (-6.5, 0)

# %%
plt.savefig('Van1_v2.pgf', 
            #This is simple recomendation for publication plots
            dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

#plt.savefig('rho_profile.pgf')
plt.savefig("Van1_v2.png",dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

# %%
#Compacticidad GR
C_GR = np.array([[0, 0.601351/6.00924]])

# Compacticidad BY with X
C_005 = np.loadtxt('Comp_BH_X.dat', usecols=(0,1)) 

# Compacticidad H with X
C_1 = np.loadtxt('Comp_H_X.dat', usecols=(0,1)) 

inter = np.array([[-0.3, 0.153]])

# %%
C_005 =np.array([[-2.  , -1.99, -1.98, -1.97, -1.96, -1.95, -1.94, -1.93, -1.92,
        -1.91, -1.9 , -1.89, -1.88, -1.87, -1.86, -1.85, -1.84, -1.83,
        -1.82, -1.81, -1.8 , -1.79, -1.78, -1.77, -1.76, -1.75, -1.74,
        -1.73, -1.72, -1.71, -1.7 , -1.69, -1.68, -1.67, -1.66, -1.65,
        -1.64, -1.63, -1.62, -1.61, -1.6 , -1.59, -1.58, -1.57, -1.56,
        -1.55, -1.54, -1.53, -1.52, -1.51, -1.5 , -1.49, -1.48, -1.47,
        -1.46, -1.45, -1.44, -1.43, -1.42, -1.41, -1.4 , -1.39, -1.38,
        -1.37, -1.36, -1.35, -1.34, -1.33, -1.32, -1.31, -1.3 , -1.29,
        -1.28, -1.27, -1.26, -1.25, -1.24, -1.23, -1.22, -1.21, -1.2 ,
        -1.19, -1.18, -1.17, -1.16, -1.15, -1.14, -1.13, -1.12, -1.11,
        -1.1 , -1.09, -1.08, -1.07, -1.06, -1.05, -1.04, -1.03, -1.02,
        -1.01, -1.  , -0.99, -0.98, -0.97, -0.96, -0.95, -0.94, -0.93,
        -0.92, -0.91, -0.9 , -0.89, -0.88, -0.87, -0.86, -0.85, -0.84,
        -0.83, -0.82, -0.81, -0.8 , -0.79, -0.78, -0.77, -0.76, -0.75,
        -0.74, -0.73, -0.72, -0.71, -0.7 , -0.69, -0.68, -0.67, -0.66,
        -0.65, -0.64, -0.63, -0.62, -0.61, -0.6 , -0.59, -0.58, -0.57,
        -0.56, -0.55, -0.54, -0.53, -0.52, -0.51, -0.5 , -0.49, -0.48,
        -0.47, -0.46, -0.45, -0.44, -0.43, -0.42, -0.41, -0.4 , -0.39,
        -0.38, -0.37, -0.36, -0.35, -0.34, -0.33, -0.32, -0.31, -0.3 ,
        -0.29, -0.28, -0.27, -0.26, -0.25, -0.24, -0.23, -0.22, -0.21,
        -0.2 , -0.19, -0.18, -0.17, -0.16, -0.15, -0.14, -0.13, -0.12,
        -0.11, -0.1 , -0.09,  -0.08,-0.07, -0.06, -0.03, -0.02, -0.01],
        [0.26424411, 0.26424057, 0.26424398,0.26424078, 0.26423407,
        0.26423379, 0.26422466, 0.26422296, 0.26421253, 0.26420809, 
        0.26419788, 0.26418901, 0.26418088, 0.26416553, 0.26416172, 
        0.2641406, 0.26413745, 0.2641177 , 0.2641046 , 0.26409321, 
        0.26406731, 0.26406677, 0.2640402 , 0.26402379, 0.26401206, 
        0.26397547, 0.26398307, 0.26395343, 0.26392332, 0.26392162, 
        0.26389293, 0.26386245, 0.26386205, 0.26383207, 0.26380197, 
        0.26379658, 0.26377234, 0.26374336, 0.26372501, 0.26364717,
        0.26356285, 0.26347189, 0.26337408, 0.26326924, 0.26315718,
        0.26303772, 0.26291066, 0.26277583, 0.26263302, 0.26248207,
        0.26232277, 0.26215494, 0.26197839, 0.26179294, 0.26159839,
        0.26139457, 0.26118127, 0.26095833, 0.26072554, 0.26048272,
        0.26022968, 0.25996624, 0.2596922 , 0.25940739, 0.2591116 ,
        0.25880467, 0.25848639, 0.25815658, 0.25781505, 0.25746161,
        0.25709609, 0.25671828, 0.25632801, 0.25592508, 0.25550931,
        0.25508051, 0.25463849, 0.25418307, 0.25371405, 0.25323125,
        0.25273449, 0.25222357, 0.25169831, 0.25115852, 0.25060401,
        0.25003459, 0.24945008, 0.2488503 , 0.24823504, 0.24760413,
        0.24695738, 0.24629459, 0.24561559, 0.24492018, 0.24420818,
        0.2434794 , 0.24273366, 0.24197075, 0.24119051, 0.24039273,
        0.23957724, 0.23874384, 0.23789235, 0.23702258, 0.23613434,
        0.23522744, 0.23430171, 0.23335694, 0.23239295, 0.23140956,
        0.23040658, 0.22938381, 0.22834108, 0.22727819, 0.22619496,
        0.2250912 , 0.22396672, 0.22282134, 0.22165486, 0.2204671 ,
        0.21925788, 0.218027  , 0.21677428, 0.21549952, 0.21420255,
        0.21288317, 0.2115412 , 0.21017645, 0.20878873, 0.20737801,
        0.20594599, 0.20449551, 0.20302943, 0.20155059, 0.20006186,
        0.19856609, 0.19706614, 0.19556485, 0.19406509, 0.19256971,
        0.19108156, 0.1896035 , 0.18813839, 0.18668907, 0.18525841,
        0.18384925, 0.18246446, 0.18110689, 0.17977939, 0.17848482,
        0.17722603, 0.17600443, 0.17481561, 0.17365372, 0.1725129 ,
        0.17138729, 0.17027104, 0.1691583 , 0.16804321, 0.16691992,
        0.16578256, 0.16462529, 0.16344224, 0.16222756, 0.16097541,
        0.15967991, 0.15833522, 0.15693548, 0.15547483, 0.15394743,
        0.1523474 , 0.15067108, 0.14892344, 0.14711166, 0.1452429 ,
        0.14332431, 0.14136306, 0.13936631, 0.13734123, 0.13529497,
        0.1332347 , 0.13116758, 0.12910077, 0.12704144, 0.12499674,
        0.12297385, 0.12097991, 0.1190221 , 0.11710757, 0.1152435 ,
        0.11343703, 0.11169533, 0.11063591, 0.10927353, 0.10793184,
        0.10399528, 0.10270071, 0.10140899]
                 ])

C_1=np.array([[-2.  , -1.99, -1.98, -1.97, -1.96, -1.95, -1.94, -1.93, -1.92,
        -1.91, -1.9 , -1.89, -1.88, -1.87, -1.86, -1.85, -1.84, -1.83,
        -1.82, -1.81, -1.8 , -1.79, -1.78, -1.77, -1.76, -1.75, -1.74,
        -1.73, -1.72, -1.71, -1.7 , -1.69, -1.68, -1.67, -1.66, -1.65,
        -1.64, -1.63, -1.62, -1.61, -1.6 , -1.59, -1.58, -1.57, -1.56,
        -1.55, -1.54, -1.53, -1.52, -1.51, -1.5 , -1.49, -1.48, -1.47,
        -1.46, -1.45, -1.44, -1.43, -1.42, -1.41, -1.4 , -1.39, -1.38,
        -1.37, -1.36, -1.35, -1.34, -1.33, -1.32, -1.31, -1.3 , -1.29,
        -1.28, -1.27, -1.26, -1.25, -1.24, -1.23, -1.22, -1.21, -1.2 ,
        -1.19, -1.18, -1.17, -1.16, -1.15, -1.14, -1.13, -1.12, -1.11,
        -1.1 , -1.09, -1.08, -1.07, -1.06, -1.05, -1.04, -1.03, -1.02,
        -1.01, -1.  , -0.99, -0.98, -0.97, -0.96, -0.95, -0.94, -0.93,
        -0.92, -0.91, -0.9 , -0.89, -0.88, -0.87, -0.86, -0.85, -0.84,
        -0.83, -0.82, -0.81, -0.8 , -0.79, -0.78, -0.77, -0.76, -0.75,
        -0.74, -0.73, -0.72, -0.71, -0.7 , -0.69, -0.68, -0.67, -0.66,
        -0.65, -0.64, -0.63, -0.62, -0.61, -0.6 , -0.59, -0.58, -0.57,
        -0.56, -0.55, -0.54, -0.53, -0.52, -0.51, -0.5 , -0.49, -0.48,
        -0.47, -0.46, -0.45, -0.44, -0.43, -0.42, -0.41, -0.4 , -0.39,
        -0.38, -0.37, -0.36, -0.35, -0.34, -0.33, -0.32, -0.31, -0.3 ,
        -0.29, -0.28, -0.27, -0.26, -0.25, -0.24, -0.23, -0.22, -0.21,
        -0.2 , -0.19, -0.18, -0.17, -0.16, -0.15, -0.14, -0.13, -0.12,
        -0.11, -0.1 , -0.09, -0.08, -0.07, -0.06, -0.05, -0.04, -0.03,
        -0.02, -0.01],
       [0.35607484, 0.35607349, 0.35606772, 0.35606324, 0.35605258, 
        0.35602986, 0.35604364, 0.35601426, 0.356     , 0.35597465,
        0.35596344, 0.35592438, 0.35592062, 0.35587198, 0.35586299, 
        0.35581796, 0.35579006, 0.355759  , 0.35570514, 0.35569555, 
        0.35562805, 0.35560779, 0.35555692, 0.35549756, 0.35548263, 
        0.3554056 , 0.35537403, 0.35532627, 0.35523674, 0.3552451 , 
        0.35516251, 0.35508526, 0.35507896, 0.35499487, 0.35491915, 
        0.3549107 , 0.35482687, 0.35474384, 0.35473796, 0.35466205, 
        0.35458192, 0.35454126, 0.3543286 , 0.35409954, 0.35385365,
        0.35359047, 0.35330958, 0.35301053, 0.35269287, 0.35235618,
        0.352     , 0.35162398, 0.35122806, 0.35081226, 0.35037661,
        0.34992114, 0.34944587, 0.34895082, 0.34843602, 0.34790149,
        0.34734726, 0.34677335, 0.34617979, 0.3455666 , 0.3449338 ,
        0.34428142, 0.34360948, 0.34291802, 0.34220704, 0.34147658,
        0.34072667, 0.33995731, 0.33916855, 0.33836041, 0.3375329 ,
        0.33668606, 0.3358199 , 0.33493447, 0.33403026, 0.33310851,
        0.33217052, 0.33121758, 0.33025101, 0.32927209, 0.32828212,
        0.3272824 , 0.32627424, 0.32525892, 0.32423775, 0.32321203,
        0.32218306, 0.32115212, 0.32012054, 0.31908959, 0.31806058,
        0.31703481, 0.31601358, 0.31499818, 0.31398992, 0.3129901 ,
        0.312     , 0.31101971, 0.31004441, 0.30906807, 0.30808463,
        0.30708807, 0.30607234, 0.30503141, 0.30395922, 0.30284976,
        0.30169696, 0.3004948 , 0.29923724, 0.29791823, 0.29653174,
        0.29507173, 0.29353215, 0.29190705, 0.29019492, 0.28840116,
        0.28653178, 0.28459279, 0.28259019, 0.28052999, 0.27841818,
        0.27626078, 0.27406379, 0.27183321, 0.26957505, 0.26729531,
        0.265     , 0.26269512, 0.26038667, 0.25808067, 0.25578245,
        0.25348982, 0.25119569, 0.24889289, 0.24657425, 0.2442326 ,
        0.24186077, 0.23945159, 0.2369979 , 0.23449252, 0.23192829,
        0.22929804, 0.22659459, 0.22381088, 0.2209455 , 0.21800583,
        0.215     , 0.21193616, 0.20882244, 0.20566697, 0.2024779 ,
        0.19926337, 0.1960315 , 0.19279044, 0.18954833, 0.18631329,
        0.18309348, 0.1798965 , 0.17672794, 0.17359286, 0.17049632,
        0.16744338, 0.1644391 , 0.16148855, 0.15859678, 0.15576885,
        0.15300984, 0.15032479, 0.14771877, 0.14519684, 0.14276364,
        0.14041885, 0.13815895, 0.13598038, 0.13387957, 0.13185296,
        0.12989697, 0.12800805, 0.12618263, 0.12441713, 0.12270799,
        0.12105165, 0.11944453, 0.11788308, 0.11636372, 0.11488289,
        0.11343703, 0.11202256, 0.11063591, 0.10927353, 0.10793184,
        0.10660728, 0.10529628, 0.10399528, 0.10270071, 0.10140899]
             ])

# %%
fig, ax = plt.subplots(figsize=(12,9))#figsize=(12,9)

plt.axhline(y=0.158, color = '#959595', ls='-')
plt.axhline(y=4/9, color='#959595', ls='-')
plt.axhline(y=1/2, color='#959595', ls='-')
plt.axhline(y=C_GR[:,1], color='#959595', ls='-')

# intercepto
#ax.plot(inter[:,0], inter[:,1],'ko')
#plt.text(-0.5, 0.13, '(-0.3, 0.153)', {'color': 'k', 'fontsize': 15})

# GR
#ax.plot(C_GR[:,0], C_GR[:,1],'*', color='darkgrey',ms=12)

#H X
ax.plot(np.log10(np.power(-1/C_1[0], 1/3)), C_1[1], label = r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0$', color = '#5079b9')


#BY X
ax.plot(np.log10(np.power(-1/C_005[0], 1/3)), C_005[1], label = r'$c_{4}^{(1)}=1/2,\; d_{4}^{(-1)}=1$', color = '#b45c1f')

# textos

plt.text(np.log10(np.power(-1/C_005[0][1]+0.09,1/3)), C_GR[:,1]-0.02, 'boson star', {'color': '#6b6968'})
plt.text(np.log10(np.power(-1/C_005[0][1]+0.09, 1/3)), 0.158-0.02, 'self-interacting boson star', {'color': '#6b6968'})#, 'fontsize': 20
plt.text(np.log10(np.power(-1/C_005[0][1]+0.09, 1/3)), 4/9-0.02, 'fluid star', {'color': '#6b6968'})
plt.text(np.log10(np.power(-1/C_005[0][1]+0.09, 1/3)), 0.505-0.025, 'black hole', {'color': '#6b6968'})

x1, x2, y1, y2 = np.log10(np.power(-1/C_005[0][1], 1/3))+0.02, 0.5, 0, 0.55
ax.set_xlim(x1, x2) # apply the x-limits
ax.set_ylim(y1, y2)

ax.set_ylabel(r'$C_{\mathrm{max}}$')#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax.set_xlabel(r'$\mathrm{Log}_{10}(\Lambda_{3}\,[M_{\mathrm{Pl}}^{1/3} \mathrm{m}^{2/3}])$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')


ax2 = ax.twinx()
ax2.set_ylim(y1, y2)
#ax2.set_ylim(0, ax.get_ylim)

ax.legend(loc='lower right',frameon=False); #loc=(.02, .01)

# %%
plt.savefig('comp.pgf', 
            #This is simple recomendation for publication plots
            dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

#plt.savefig('rho_profile.pgf')
plt.savefig("comp.png",dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

# %%
(np.power(-1/C_1[0,-1], 1/3), np.power(-1/C_1[0,-1], 1/2))
# Out:
# (4.641588833612778, 10.0)

# %%
(np.log10(np.power(-1/C_1[0,-1], 1/3)), np.log10(np.power(-1/C_1[0,-1], 1/2)))
# Out:
# (0.6666666666666666, 1.0)

# %%
np.log10(1.5)
# Out:
# 0.17609125905568124

# %%
C_0 = sorted(C_005[1], reverse=True)
C1 = sorted(C_1[1], reverse=True)

from scipy.interpolate import interp1d, Rbf, InterpolatedUnivariateSpline

CbHS = InterpolatedUnivariateSpline(C_005[0], C_0)
CHS = InterpolatedUnivariateSpline(C_1[0], C1)

# %%
import matplotlib.ticker as ticker

rad=np.arange(C_005[0][1], 0, 0.01)  # radios barras


fig, ax = plt.subplots(figsize=(12,9))

plt.axhline(y=0.158, color = '#6b6968', ls='-')
plt.axhline(y=4/9, color='#6b6968', ls='-')
plt.axhline(y=1/2, color='#6b6968', ls='-')
plt.axhline(y=C_GR[:,1], color='#6b6968', ls='-')

#H X
ax.plot(np.sqrt(-1/rad), CHS(rad), label=r'HS ($c_{1}=-1, \;c_{2}=0$)', color = '#5079b9')

#BY X
ax.plot(np.sqrt(-1/rad), CbHS(rad) ,label=r'bHS ($c_{1}=c_{2}=-1$)', color = '#b45c1f')

# textos

plt.text(np.sqrt(-1/C_005[0][1]+0.04), C_GR[:,1]-0.02, 'boson star', {'color': '#6b6968', 'fontsize': 20})
plt.text(np.sqrt(-1/C_005[0][1]+0.04), 0.158-0.02, 'self-interacting boson star', {'color': '#6b6968', 'fontsize': 20})
plt.text(np.sqrt(-1/C_005[0][1]+0.04), 4/9-0.02, 'fluid star', {'color': '#6b6968', 'fontsize': 20})
plt.text(np.sqrt(-1/C_005[0][1]+0.04), 0.505-0.025, 'black hole', {'color': '#6b6968', 'fontsize': 20})


x1, x2, y1, y2 = np.sqrt(-1/C_005[0][1])+0.02, 3, 0, 0.55
ax.set_xlim(x1, x2) # apply the x-limits
ax.set_ylim(y1, y2)

ax.set_xscale('log')
ax.xaxis.set_major_locator(ticker.LogLocator(base=10.0, numticks=3))


locmin = mpl.ticker.LogLocator(base=10.0, subs=(0.9), numticks=3)
ax.xaxis.set_minor_locator(locmin)
ax.xaxis.set_minor_formatter(mpl.ticker.NullFormatter())


ax.xaxis.set_minor_locator(plt.MultipleLocator(1))

#ax.xaxis.set_minor_locator(ticker.LogLocator(base=10.0, numticks=5))

ax.set_ylabel(r'$C^{\mathrm{max}}$')#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax.set_xlabel(r'$\mathrm{Log}_{10}(\Lambda\,[m])$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

#ax2 = ax.twinx()
#ax2.set_ylim(y1, y2)

#ax2.set_ylim(0, ax.get_ylim)

ax.legend(frameon=False); #loc=(.02, .01)

# %%
# Case Beyond Horndeski with X, 
# phi0=0.035
# eta=-0.3
datag = np.loadtxt('BHXgm03A035.dat', usecols=(0,1)) 
dataN = np.loadtxt('BHXNm03A035.dat', usecols=(0,1)) 

dataM = np.loadtxt('BHX_Mm03A035.dat', usecols=(0,1))

# %%
#  Uso raiz, pq mi definición de NN y gg es al cuadrado
NN = lambda r: np.power(1-2*Mass/r, 0.5)
gg = lambda r: np.power((1-2*Mass/r)**-1,0.5)

# %%
rad1 = np.arange(3, dataN[-1,0], 0.1)
rad = np.arange(4., datag[-1,0], 0.1)

#y=[1,2,3,4,5,4,3,2,1,1,1,1,1,1,1,1]
#col_labels=['col1','col2','col3']
#row_labels=['row1','row2','row3']
#table_vals=[11,12,13,21,22,23,31,32,33]
#table = r'''\begin{tabular}{ c | c | c | c } \multicolumn{4}{c}{$c_{4}^{(1)}=d_{4}^{(-1)}=-1$ (bHS)}\\[0.2cm]\hline\hline $\Lambda_{3}$ & \multicolumn{3}{c}{$1.493\;\,[M_{\mathrm{Pl}}^{1/3} \mathrm{m}^{2/3}]$} \\\hline $\sigma_{0}$ & \multicolumn{3}{c}{$0.15\;\,[M_{\mathrm{Pl}}]$} \\\hline $N_{0}$ & 1 & $N_{0}^{\mathrm{new}}$ & $0.8$ \\\hline $\omega_{1}$ & $1.121058$ [m]& $\omega^{\mathrm{new}}$& $0.896736$ [m] \\\hline \end{tabular}'''

table = r'''\begin{tabular}{l} $c_{4}^{(1)}=1/2$, $d_{4}^{(-1)}=1$\\[0.2cm]$\Lambda_{3}=1.5\, M_{\mathrm{Pl}}^{1/3} m^{2/3}$\\[0.2cm]$\sigma_{0}= 0.175\, M_{\mathrm{Pl}}$\\ \end{tabular}'''


Mass = dataM[-1,1]

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 5.5))

ax[0].plot(dataN[:,0], dataN[:,1], label=r'$N$')
ax[0].plot(rad1, NN(rad1),':', color='#918f8e', label=r'$N_{\mathrm{schw}}$')

# These are in unitless percentages of the figure size. (0,0 is bottom left)
#left, bottom, width, height = [0.31, 0.26, 0.15, 0.3] # [0.52, 0.25, 0.35, 0.35]
#ax1 = fig.add_axes([left, bottom, width, height])


#ax1.plot(dataN[:,0],dataN[:,1], color='red', label=r'$\hat{N}$')
#ax1.plot(rad1, NN(rad1),'--', color='#918f8e')

ax[0].set_xticks(np.arange(0, 20, 5))
#ax1.set_xticks(np.arange(0, 20, 5))

ax[0].text(10, .795, table, size=15)

x1, x2 = datag[0,0], datag[-1,0]
ax[0].set_xlim(x1, x2) # apply the x-limits
ax[0].set_ylim(0.75, .98)
#ax1.set_ylim(0.75, 1.25)
#ax1.set_xlim(x1, x2)

ax[0].set_xlabel(r'$r\,[m^{-1}]$')

#ax1.legend(loc='lower right',frameon=False)
ax[0].legend(loc='upper left',frameon=False);

# g

ax[1].plot(datag[:,0],datag[:,1], label=r'$g$')
ax[1].plot(rad, gg(rad),':' ,color='#918f8e', label=r'$g_{\mathrm{schw}}$')

# These are in unitless percentages of the figure size. (0,0 is bottom left)
left, bottom, width, height = [0.765, 0.55, 0.13, 0.28]
ax1 = fig.add_axes([left, bottom, width, height])

ax1.plot(dataM[:,0], 8*np.pi*dataM[:,1])

angle2=0
plt.figtext(.843, .78, '{0:.2f}'.format(8*np.pi*Mass), {'color': 'black'},
            rotation=angle2, rotation_mode='anchor')#, 'fontsize': 20


ax[1].set_xticks(np.arange(0, 20, 5))
ax1.set_xticks(np.arange(0, 20, 5))

x1, x2 = datag[0,0], datag[-1,0]
ax[1].set_ylim(0.98, 1.2)
ax[1].set_xlim(x1, x2) 
ax1.set_xlim(x1, x2)

ax[1].set_xlabel(r'$r\,[m^{-1}]$')

ax1.set_ylabel(r'$M [M_{\mathrm{Pl}}^{2} m^{-1}]$') #, fontsize=25
ax[1].legend(loc='upper left',frameon=False);

# %%
plt.savefig('Nterm2.pgf', 
            #This is simple recomendation for publication plots
            dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

#plt.savefig('rho_profile.pgf')
plt.savefig("Nterm2.png",dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

# %%
sigma_teorico = lambda r: P_0/(1+(0.230*np.power(P_0, 0.5)*r)**2)**4
    
def dens_fisica(r):
    conds = [r<rMin, r>=rMin]
    funcs = [lambda r: P_0, lambda r: sigma_teorico(r)] 
    return np.piecewise(r, conds, funcs)

# %%
# -0.3
data_sigma = np.loadtxt('HXm03Am001.dat', usecols=(0,1)) 
data_sigma2 = np.loadtxt('HXm03Am0001.dat', usecols=(0,1)) 

# -0.2
data_sigmaH0001 =  np.loadtxt('HXm2A0001.dat', usecols=(0,1)) 
data_sigmaH =  np.loadtxt('HXm2A07.dat', usecols=(0,1)) 

###

data_sigmaBS = np.loadtxt('BSAm0001.dat', usecols=(0,1)) 

data_sigmaBS2 = np.loadtxt('BSA07.dat', usecols=(0,1))

# %%
######

P_0 = np.sqrt(8*np.pi)*data_sigmaH0001[0,1]
rMin = data_sigmaH0001[0,0]

rad = np.arange(data_sigmaH0001[0,0], data_sigmaH0001[-1,0])

#######

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 5.5))

ax[0].plot(data_sigmaH0001[:,0], np.sqrt(8*np.pi)*data_sigmaH0001[:,1], 
           label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0$', color = '#419ede') # (HS)

ax[0].plot(data_sigmaBS[:, 0], np.sqrt(8*np.pi)*data_sigmaBS[:, 1], label='BS', linestyle = '--',
           color = '#566874') # (BS)

ax[0].plot(rad, dens_fisica(rad), label='SP', linestyle = ':', color = '#566874') # (SP)

ax[0].set_xlim(data_sigma2[0,0], 100) # apply the x-li4mits
#ax.set_ylim(0.5, 1.4)

ax[0].set_ylabel(r'$\sigma\,[M_{\mathrm{Pl}}]$')#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax[0].set_xlabel(r'$r\,[m^{-1}]$')#, fontsize=17

ax[0].legend(loc='upper right', frameon=False)
#ax.legend(loc=(.72, .6),frameon=False);


######

P_0 = np.sqrt(8*np.pi)*data_sigmaH[0,1]
rMin = data_sigmaH[0,0]

rad = np.arange(data_sigmaH[0,0], data_sigmaH[-1,0], 0.1)

#######

ax[1].plot(data_sigmaH[:,0], np.sqrt(8*np.pi)*data_sigmaH[:,1], 
           label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0$', color = '#419ede') # (HS)

ax[1].plot(data_sigmaBS2[:,0], np.sqrt(8*np.pi)*data_sigmaBS2[:,1], label='BS',  linestyle = '--',
           color = '#566874') # (BS)

ax[1].plot(rad, dens_fisica(rad), label='SP', linestyle = ':', color = '#566874') # (SP)

ax[1].set_xlim(data_sigmaH[0,0], data_sigmaH[-1,0]) # apply the x-li4mits
#ax.set_ylim(0.5, 1.4)

ax[1].set_ylabel(r'$\sigma \,[M_{\mathrm{Pl}}]$')# , fontsize=17
ax[1].set_xlabel(r'$r\,[m^{-1}]$')# , fontsize=17

#matplotlib.rcParams['legend.fontsize'] = 25
#ax.legend(('Numerical solution', 'Analytical fitting'),loc='upper right',frameon=False)
ax[1].legend(loc='best',frameon=False) # loc=(0.41, 0.001)

# %%
plt.savefig('SP.pgf', 
            #This is simple recomendation for publication plots
            dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

#plt.savefig('rho_profile.pgf')
plt.savefig("SP.png",dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

# %%
Bs = np.loadtxt('BSA007.dat', usecols=(0,1)) 
Hx = np.loadtxt('HX_m03A007.dat', usecols=(0,1)) 
Hx2 = np.loadtxt('HX_m2A007.dat', usecols=(0,1)) 


bBs = np.loadtxt('BSBoxA007.dat', usecols=(0,1)) 
bHx = np.loadtxt('HBoxX_m03A007.dat', usecols=(0,1)) 
bHx2 = np.loadtxt('HBoxX_m2A007.dat', usecols=(0,1))

# %%
# X/Lambda^2
rad = np.arange(0,7.5, 0.1)
#mpl.rcParams['text.latex.preamble'] = [r'\usepackage{amssymb}'] # \usepackage{txfonts}

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 5.5))

ax[0].plot(Bs[:,0], 8*np.pi*Bs[:,1]*0, 
           label='$c_{4}^{(1)}=d_{4}^{(-1)}=0, \eta=0$', color = '#566874') # (BS)

ax[0].plot(Hx2[:,0], 8*np.pi*Hx2[:,1]*0.3, 
           label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0, \eta=-0.3$', color = '#5079b9') # (HS)

ax[0].plot(Hx[:,0], 8*np.pi*Hx[:,1]*2, 
           label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0 , \eta=-2$', color = '#db141e') # (HS)

ax[0].set_xlim(0, 10) # apply the x-li4mits

ax[0].set_ylabel(r'$X\;[\Lambda_{2}^{4}]$')#
ax[0].set_xlabel(r'$r\;[m^{-1}]$')#

ax[0].legend(frameon=False)

# box
ax[1].plot(bBs[:,0], np.sqrt(8*np.pi)*bBs[:,1]*0, 
           label='$c_{4}^{(1)}=d_{4}^{(-1)}=0, \eta=0$', color = '#566874') # (BS)

ax[1].plot(bHx[:,0], np.sqrt(8*np.pi)*bHx[:,1]*0.3, 
           label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0, \eta=-0.3$', color = '#5079b9') # (HS)

ax[1].plot(bHx2[:,0], np.sqrt(8*np.pi)*bHx2[:,1]*2, 
           label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0, \eta=-2$', color = '#db141e') # (HS)

ax[1].axhline(y=1, linestyle = ':', color = '#6b6968')


ax[1].set_xlim(0, 10) # apply the x-li4mits
##ax.set_ylim(0.5, 1.4)

ax[1].set_ylabel(r'$|\Box \phi|\;[\Lambda_{3}^{3}]$')#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax[1].set_xlabel(r'$r\;[m^{-1}]$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

ax[1].legend(frameon=False)

# %%
plt.savefig('XN.pgf', 
            #This is simple recomendation for publication plots
            dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

#plt.savefig('rho_profile.pgf')
plt.savefig("XN.png",dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

# %%
# esta

# %%
XH = np.loadtxt('HX_m2A0001.dat', usecols=(0,1)) 
bHx1 = np.loadtxt('HBoxX_m2A0001.dat', usecols=(0,1)) 

NH = np.loadtxt('HXNm2A0001.dat', usecols=(0,1)) 
NH2 = np.loadtxt('HXNm2A007.dat', usecols=(0,1))

# %%
######

P_0 = np.sqrt(8*np.pi)*data_sigmaH0001[0,1]
rMin = data_sigmaH0001[0,0]

rad = np.arange(data_sigmaH0001[0,0], data_sigmaH0001[-1,0])

#######

fig, (ax, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(16, 5.5))

ax.plot(rad, dens_fisica(rad), label='SP', linestyle = ':', color = '#566874') # (SP)

ax.plot(data_sigmaBS[:, 0], np.sqrt(8*np.pi)*data_sigmaBS[:, 1], label='BS', linestyle = '--',
           color = '#566874') # (BS)

ax.plot(data_sigmaH0001[:,0], np.sqrt(8*np.pi)*data_sigmaH0001[:,1], 
           label=r'$c_{4}^{(1)}=1/2, \,d_{4}^{(-1)}=0$', color = '#419ede') # (HS)

ax.set_xlim(data_sigma2[0,0], 150) # apply the x-li4mits
#ax.set_ylim(0.5, 1.4)

ax.set_ylabel(r'$\sigma\,[M_{\mathrm{Pl}}]$')#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax.set_xlabel(r'$r\,[m^{-1}]$')#, fontsize=17

ax.legend(loc = (0.01, 0.01), frameon=False)#'lower left'

# Create inset
# N
axins0 = inset_axes(ax, width="30%", height="40%", loc ='upper center',
                   bbox_to_anchor=(-0.02, 0.2, .8, .8), bbox_transform=ax.transAxes)

#axins0.ticklabel_format(axis='y', style='sci', scilimits=(-2,-1))

axins0.plot(NH[:,0], NH[:,1], 
           label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0 , \eta=-2$', color = '#419ede') # (HS)

axins0.set_ylabel(r'$N$')#
axins0.set_xlim(data_sigma2[0,0], 149) # apply the x-li4mits

# X
axins = inset_axes(ax, width="30%", height="40%", loc ='upper center',
                   bbox_to_anchor=(0.46, 0.195, .8, .8), bbox_transform=ax.transAxes)

#axins.ticklabel_format(axis='y', style='sci', scilimits=(-4,-4))

axins.plot(XH[:,0], 8*np.pi*XH[:,1]*2, 
           label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0 , \eta=-2$', color = '#419ede') # (HS)

axins.set_ylabel(r'$X\,[\Lambda_{2}^{4}]$')#
axins.set_xlim(data_sigma2[0,0], 149) # apply the x-li4mits


# Create inset of width 30% and height 40% of the parent axes' bounding box
# Box
axins2 = inset_axes(ax, width="30%", height="40%", loc='center right',
                   bbox_to_anchor=(0.2, -0.11, .8, .8), bbox_transform=ax.transAxes)

#axins2.ticklabel_format(axis='y', style='sci', scilimits=(-2,-2))

axins2.plot(bHx1[:,0], np.sqrt(8*np.pi)*bHx1[:,1]*2, 
           label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0, \eta=-2$', color = '#419ede') # (HS)

axins2.set_ylabel(r'$|\Box \phi|\,[\Lambda_{3}^{3}]$')
axins2.set_xlim(data_sigma2[0,0], 149) # apply the x-li4mits

######

P_0 = np.sqrt(8*np.pi)*data_sigmaH[0,1]
rMin = data_sigmaH[0,0]

rad = np.arange(data_sigmaH[0,0], data_sigmaH[-1,0], 0.1)

#######

ax2.plot(rad, dens_fisica(rad), label='SP', linestyle = ':', color = '#566874') # (SP)

ax2.plot(data_sigmaBS2[:,0], np.sqrt(8*np.pi)*data_sigmaBS2[:,1], label='BS',  linestyle = '--',
           color = '#566874') # (BS)

ax2.plot(data_sigmaH[:,0], np.sqrt(8*np.pi)*data_sigmaH[:,1], 
           label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0$', color = '#419ede') # (HS)


ax2.set_xlim(data_sigmaH[0,0], data_sigmaH[-1,0]) # apply the x-li4mits
#ax.set_ylim(0.5, 1.4)

ax2.set_ylabel(r'$\sigma \,[M_{\mathrm{Pl}}]$')# , fontsize=17
ax2.set_xlabel(r'$r\,[m^{-1}]$')# , fontsize=17

# Create inset
# N
axins3 = inset_axes(ax2, width="30%", height="40%", loc ='upper center',
                   bbox_to_anchor=(1.25, 0.2, .8, .8), bbox_transform=ax.transAxes)

axins3.plot(NH2[:,0], NH2[:,1], 
           label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0 , \eta=-2$', color = '#419ede') # (HS)

axins3.set_ylabel(r'$N$')#
axins3.set_xlim(data_sigmaH[0,0], data_sigmaH[-1,0]) # apply the x-li4mits


# X
axins3 = inset_axes(ax2, width="30%", height="40%", loc ='upper center',
                   bbox_to_anchor=(1.66, 0.2, .8, .8), bbox_transform=ax.transAxes)

axins3.plot(Hx[:,0], 8*np.pi*Hx[:,1]*2, 
           label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0 , \eta=-2$', color = '#419ede') # (HS)

axins3.set_ylabel(r'$X\,[\Lambda_{2}^{4}]$')#
axins3.set_xlim(data_sigmaH[0,0], data_sigmaH[-1,0]) # apply the x-li4mits


# Create inset of width 30% and height 40% of the parent axes' bounding box
# Box
axins4 = inset_axes(ax2, width="30%", height="40%", loc='center right',
                   bbox_to_anchor=(1.4, -0.11, .8, .8), bbox_transform=ax.transAxes)

axins4.plot(bHx2[:,0], np.sqrt(8*np.pi)*bHx2[:,1]*2, 
           label=r'$c_{4}^{(1)}=1/2, \;d_{4}^{(-1)}=0, \eta=-2$', color = '#419ede') # (HS)

#axins4.axhline(y=1, linestyle = ':', color = '#6b6968')

axins4.set_ylabel(r'$|\Box \phi|\,[\Lambda_{3}^{3}]$')
axins4.set_xlim(data_sigmaH[0,0], data_sigmaH[-1,0]) # apply the x-li4mits

ax2.legend(loc='lower left',frameon=False) # loc=(0.41, 0.001)

# %%
plt.savefig('XN.pgf', 
            #This is simple recomendation for publication plots
            dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

#plt.savefig('rho_profile.pgf')
plt.savefig("XN.png",dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

# %%
alb = np.loadtxt('alb.dat', usecols=(0,1))

# %%
rad = np.e**np.linspace(-85.4554, 63.0613, 100)

lam3 = lambda m: 5.53108e-19*np.power(m, 2/3) 
lam32 = lambda m: m/(2.431e27)
lm4 = lambda x: 1

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 5.5))

ax[0].loglog(rad, lam3(rad), linewidth = 0.0001)
ax[0].loglog(rad, lam32(rad), linewidth = 0.0001, color = '#5f6769')

# Shade the area between y1 and line y=0
ax[0].fill_between(rad, lam3(rad), lam32(rad),
                 facecolor='#5aaadb', # The fill color
                 color='#5aaadb',       # The outline color
                 alpha=0.3)          # Transparency of the fill

ax[0].fill_between(rad, lam32(rad), 0,
                 facecolor='#5f6769', # The fill color
                 color='#5f6769',       # The outline color
                 alpha=0.3)          # Transparency of the fill

angle2 = 0
ax[0].text(1e-35, 20e-31, r'$10^{-3}\,\mathrm{eV}$', {'color': '#5f6769', 'fontsize': 16},
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim


ax[0].text(1e-35, 50e-41, r'$(M_{\mathrm{Pl}}$\textit{H}$_{0}^{2})^{1/3}$', {'color': '#1b4b57', 'fontsize': 16},
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim


#ax[0].text(1e-30, 1e-8, r'Boson', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')
#ax[0].text(1e-30, 40e-13, r'stars', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')

#ax[0].text(1e-3, 1e-29, r'Horndeski', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')
#ax[0].text(1e7, 1e-33, r'stars', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')

ax[0].text(1e-30, 1e-20, r'BS', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor')

ax[0].text(1e-10, 1e-29, r'HS', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor')

ax[0].text(1e5, 1e-37, r'$m>\Lambda_{3}$', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor')

ax[0].text(1e-35, 0.012, r'GUT', {'color': '#5f6769', 'fontsize': 16},
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim

angle2 = 90
ax[0].text(5e-05, 1e-22, r'$10^{-3}\,\mathrm{eV}$ (screening)', {'color': '#5f6769', 'fontsize': 16},
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim


ax[0].axhline(y=4.11353e-31, color='#756f6b', ls=':')
ax[0].axhline(y=5.34759e-41, color='#756f6b', ls=':')

ax[0].axhline(y=0.00411353, color = '#756f6b', ls=':')
ax[0].axvline(1e-03, color='#756f6b', ls=':')


ax[0].set_xlim(5e-38, 1e27) # apply the x-li4mits
ax[0].set_ylim(1e-43, 1e0)

ax[0].set_ylabel(r'$\Lambda_{3}\,[M_{\mathrm{Pl}}]$')#
ax[0].set_xlabel(r'$m\,\mathrm{[eV]}$')#

#ax[0].legend(frameon=False)

# dos

y = lambda x: x
rad = np.arange(0, 1, 0.001)

ax[1].plot(rad, y(rad), linewidth = 0.0001)

#ax[1].axhline(y=1, xmin = 0, xmax = 0.9, color = '#756f6b', ls=':')

ax[1].plot(0.01*alb[:,0]+1, 0.01*alb[:,1], color ='#5f6769')

# Shade the area between y1 and line y=0
ax[1].fill_between(rad, y(rad), 0,
                 facecolor='#5aaadb', # The fill color
                 color='#5aaadb',       # The outline color
                 alpha=0.3)          # Transparency of the fill

ax[1].fill_between(0.01*alb[:,0]+1, 0.01*alb[:,1], 0,
                 facecolor="orange", # The fill color
                 color='#5f6769',       # The outline color
                 alpha=0.3) 


ax[1].fill_between(rad, lm4(rad), 0,
                 facecolor="orange", # The fill color
                 color='#5aaadb',       # The outline color
                 alpha=0.3) 


#ax[1].axhspan(0, 1, facecolor='#5aaadb', alpha=0.5)


ax[1].axvspan(1, 1.3, alpha=0.3, color='#5f6769', linewidth = 0.0001)


ax[1].text(1.13, 0.4, r'unstable', {'color': '#5f6769', 'fontsize': 25},
            rotation=90, rotation_mode='anchor')
angle2 = 0
#ax[1].text(0.2, 0.8, r'Boson', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')
#ax[1].text(0.2, 0.7, r'stars', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')


#ax[1].text(0.6, 0.4, r'Horndeski', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')
#ax[1].text(0.78, 0.3, r'stars', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')

ax[1].text(0.5, 1.05, r'BS', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor')

ax[1].text(0.2, 0.7, r'BS regime', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor')

ax[1].text(0.55, 0.3, r'HS regime', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor')



ax[1].set_xlim(0, 1.2) # apply the x-li4mits
ax[1].set_ylim(0, 1.2)

ax[1].set_ylabel(r'$\Lambda_3^{3/2} M_{\mathrm{Pl}}^{-1/2} m^{-1}$')#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax[1].set_xlabel(r'$\sigma_{0}\,[M_{\mathrm{Pl}}]$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

#ax[1].legend(frameon=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8b279733b9df> in <module>
# ----> 1 rad = np.e**np.linspace(-85.4554, 63.0613, 100)
#       2
#       3 lam3 = lambda m: 5.53108e-19*np.power(m, 2/3)
#       4 lam32 = lambda m: m/(2.431e27)
#       5 lm4 = lambda x: 1
#
# NameError: name 'np' is not defined

# %%
rad = np.e**np.linspace(-85.4554, 63.0613, 100)

lam3 = lambda m: 5.53108e-19*np.power(m, 2/3) 
lam32 = lambda m: m/(2.431e27)
lm4 = lambda x: 1

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 5.5))

ax[0].loglog(rad, lam3(rad), linewidth = 0.0001)
ax[0].loglog(rad, lam32(rad), linewidth = 0.0001, color = '#5f6769')

# Shade the area between y1 and line y=0
ax[0].fill_between(rad, lam3(rad), lam32(rad),
                 facecolor='#5aaadb', # The fill color
                 color='#5aaadb',       # The outline color
                 alpha=0.3)          # Transparency of the fill

ax[0].fill_between(rad, lam32(rad), 0,
                 facecolor='#5f6769', # The fill color
                 color='#5f6769',       # The outline color
                 alpha=0.3)          # Transparency of the fill

angle2 = 0
ax[0].text(2e-32, 1e-31, r'$10^{-3}\,\mathrm{eV}$', {'color': '#5f6769', 'fontsize': 16},
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim

ax[0].text(8e-19, 2e-41, r'cc problem', {'color': '#1b4b57', 'fontsize': 16},
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim

ax[0].text(2e-32, 2e-41, r'$\left(M_{\mathrm{Pl}}{\textit{H}_{0}}^{2}\right)^{1/3}$', {'color': '#1b4b57', 'fontsize': 16},
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim



#ax[0].text(1e-30, 1e-8, r'Boson', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')
#ax[0].text(1e-30, 40e-13, r'stars', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')

#ax[0].text(1e-3, 1e-29, r'Horndeski', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')
#ax[0].text(1e7, 1e-33, r'stars', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')

ax[0].text(1e-30, 1e-20, r'BS', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor')

ax[0].text(1e-10, 1e-29, r'HS', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor')

ax[0].text(1e5, 1e-37, r'$m>\Lambda_{3}$', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor')

#ax[0].text(1e-35, 0.012, r'GUT', {'color': '#5f6769', 'fontsize': 16},
#            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim

angle2 = 90
ax[0].text(5e-03, 1e-25, r'$10^{-3}\,\mathrm{eV}$', {'color': '#5f6769', 'fontsize': 16},
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim
ax[0].text(5e-05, 5e-18, r'IR modification', {'color': '#5f6769', 'fontsize': 16},
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim
ax[0].text(5e-01, 5e-18, r'UV modification', {'color': '#5f6769', 'fontsize': 16},#
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim

#ax[0].text(5e-33, 1e-25, r'${\textit{H}_{0}}$', {'color': '#5f6769', 'fontsize': 16},
#            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim
#ax[0].text(8e-35, 5e-22, r'cc problem', {'color': '#5f6769', 'fontsize': 16},
#            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim
ax[0].text(5e-33, .5e-15, r'${\textit{H}_{0}}$', {'color': '#5f6769', 'fontsize': 16},
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim
ax[0].text(5e-33, 2e-12, r'cc problem', {'color': '#5f6769', 'fontsize': 16},
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim





ax[0].axhline(y=4.11353e-31, xmin=0, xmax=0.08, color='#756f6b', ls='-', alpha=0.4)
ax[0].axhline(y=4.11353e-31, xmin=0.22, xmax=1, color='#756f6b', ls='-', alpha=0.4)


# linestyle='--', dashes=(5, 5)) #length of 5, space of 5
ax[0].axhline(y=5.34759e-41, xmin=0, xmax=0.08, color='#756f6b', ls='--', dashes=(1.5, 1.5), alpha=0.4)
ax[0].axhline(y=5.34759e-41, xmin=0.25, xmax=0.29, color='#756f6b', ls='--', dashes=(1.5, 1.5), alpha=0.4)
ax[0].axhline(y=5.34759e-41, xmin=0.5, xmax=1, color='#756f6b', ls='--', dashes=(1.5, 1.5), alpha=0.4)

# vertical line
#ax[0].axhline(y=0.00411353, color = '#756f6b', ls=':')
ax[0].axvline(1e-03, ymin=0.6, ymax=1, color='#756f6b', ls='-', alpha=0.4)
ax[0].axvline(1e-03, ymin=0, ymax=0.4, color='#756f6b', ls='-', alpha=0.4)

ax[0].axvline(1e-33, ymin=0, ymax=0.64, color='#756f6b', ls='--', dashes=(1.5, 1.5), alpha=0.4)
ax[0].axvline(1e-33, ymin=0.70, ymax=0.72, color='#756f6b', ls='--', dashes=(1.5, 1.5), alpha=0.4)
ax[0].axvline(1e-33, ymin=0.975, ymax=1, color='#756f6b', ls='--', dashes=(1.5, 1.5), alpha=0.4)





ax[0].set_xlim(5e-38, 1e27) # apply the x-li4mits
ax[0].set_ylim(1e-43, 1e0)

ax[0].set_ylabel(r'$\Lambda_{3}\,[M_{\mathrm{Pl}}]$')#
ax[0].set_xlabel(r'$m\,\mathrm{[eV]}$')#

#ax[0].legend(frameon=False)

# dos

y = lambda x: x
x2 = lambda y: 0.2
rad = np.arange(0, 1, 0.001)
rad2 = np.arange(0, .2, 0.001)

ax[1].plot(rad, y(rad), linewidth = 0.0001)

#ax[1].axhline(y=1, xmin = 0, xmax = 0.9, color = '#756f6b', ls=':')

ax[1].plot(0.01*alb[:,0]+1, 0.01*alb[:,1], color ='#5f6769')

# Shade the area between y1 and line y=0
ax[1].fill_between(rad, y(rad), 0,
                 facecolor='#5aaadb', # The fill color
                 color='#5aaadb',       # The outline color
                 alpha=0.3)          # Transparency of the fill

ax[1].fill_between(0.01*alb[:,0]+1, 0.01*alb[:,1], 0,
                 facecolor="orange", # The fill color
                 color='#5f6769',       # The outline color
                 alpha=0.3) 


ax[1].fill_between(rad, lm4(rad), 0,
                 facecolor="orange", # The fill color
                 color='#5aaadb',       # The outline color
                 alpha=0.3) 


ax[1].fill_between(rad2, y(rad2), 1.3,
                 facecolor="orange", # The fill color
                 color='blue',       # The outline color
                 alpha=0.1) 
#ax[1].axvline(0.2, ymin=0.17, ymax=1.4, color='#756f6b', ls='-', alpha=0.4)

ax[1].axvspan(1, 1.3, alpha=0.3, color='#5f6769', linewidth = 0.0001)


ax[1].text(1.13, 0.4, r'unstable', {'color': '#5f6769', 'fontsize': 25},
            rotation=90, rotation_mode='anchor')
angle2 = 0

#ax[1].text(0.2, 0.7, r'stars', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')


#ax[1].text(0.6, 0.4, r'Horndeski', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')
#ax[1].text(0.78, 0.3, r'stars', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')

ax[1].text(0.5, 1.05, r'BS', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor')

#ax[1].text(0.15, 0.7, r'EKG', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')
ax[1].text(0.35, 0.7, r'EKG', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor')
#ax[1].text(0.22, 0.6, r'regime', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')
ax[1].text(0.05, 0.7, r'SP', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor')


ax[1].text(0.6, 0.33, r'strong', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor')
ax[1].text(0.6, 0.23, r'coupling', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor')
#ax[1].text(0.6, 0.15, r'regime', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')



#ax[1].text(0.45, 0.3, r'strong coupling', {'color': '#5f6769', 'fontsize': 28},
#            rotation=angle2, rotation_mode='anchor')
#ax[1].text(0.45, 0.2, r'regime', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')


#ax[1].text(0.55, 0.2, r'regime', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')




ax[1].set_xlim(0, 1.2) # apply the x-li4mits
ax[1].set_ylim(0, 1.2)

ax[1].set_ylabel(r'$\Lambda_3^{3/2} M_{\mathrm{Pl}}^{-1/2} m^{-1}$')#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax[1].set_xlabel(r'$\sigma_{0}\,[M_{\mathrm{Pl}}]$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

#ax[1].legend(frameon=False)
# Out:
# Text(0.5, 0, '$\\sigma_{0}\\,[M_{\\mathrm{Pl}}]$')

# %%
rad = np.e**np.linspace(-85.4554, 63.0613, 100)

lam3 = lambda m: 5.53108e-19*np.power(m, 2/3) 
lam32 = lambda m: m/(2.431e27)
lm4 = lambda x: 1

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 5.5))

ax[0].loglog(rad, lam3(rad), linewidth = 0.0001)
ax[0].loglog(rad, lam32(rad), linewidth = 0.0001, color = '#5f6769')

# Shade the area between y1 and line y=0
ax[0].fill_between(rad, lam3(rad), lam32(rad),
                 facecolor='#5aaadb', # The fill color
                 color='#5aaadb',       # The outline color
                 alpha=0.3)          # Transparency of the fill

ax[0].fill_between(rad, lam32(rad), 0,
                 facecolor='#5f6769', # The fill color
                 color='#5f6769',       # The outline color
                 alpha=0.3)          # Transparency of the fill

angle2 = 0
ax[0].text(2e-32, 1e-31, r'$10^{-3}\,\mathrm{eV}$', {'color': '#5f6769', 'fontsize': 16},
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim

ax[0].text(8e-19, 2e-41, r'cc problem', {'color': '#1b4b57', 'fontsize': 16},
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim

ax[0].text(2e-32, 2e-41, r'$\left(M_{\mathrm{Pl}}{\textit{H}_{0}}^{2}\right)^{1/3}$', {'color': '#1b4b57', 'fontsize': 16},
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim



#ax[0].text(1e-30, 1e-8, r'Boson', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')
#ax[0].text(1e-30, 40e-13, r'stars', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')

#ax[0].text(1e-3, 1e-29, r'Horndeski', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')
#ax[0].text(1e7, 1e-33, r'stars', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')

ax[0].text(1e-27, 0.2e-19, r'BS', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor')

ax[0].text(1e-10, 1e-29, r'HS', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor')

ax[0].text(1e5, 1e-37, r'$m>\Lambda_{3}$', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor')

#ax[0].text(1e-35, 0.012, r'GUT', {'color': '#5f6769', 'fontsize': 16},
#            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim

angle2 = 90
ax[0].text(5e-03, 1e-25, r'$10^{-3}\,\mathrm{eV}$', {'color': '#5f6769', 'fontsize': 16},
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim
ax[0].text(5e-05, 5e-18, r'IR modification', {'color': '#5f6769', 'fontsize': 16},
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim
ax[0].text(5e-01, 5e-18, r'UV modification', {'color': '#5f6769', 'fontsize': 16},#
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim

#ax[0].text(5e-33, 1e-25, r'${\textit{H}_{0}}$', {'color': '#5f6769', 'fontsize': 16},
#            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim
#ax[0].text(8e-35, 5e-22, r'cc problem', {'color': '#5f6769', 'fontsize': 16},
#            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim






ax[0].axhline(y=4.11353e-31, xmin=0, xmax=0.08, color='#756f6b', ls='-', alpha=0.4)
ax[0].axhline(y=4.11353e-31, xmin=0.22, xmax=1, color='#756f6b', ls='-', alpha=0.4)


# linestyle='--', dashes=(5, 5)) #length of 5, space of 5
ax[0].axhline(y=5.34759e-41, xmin=0, xmax=0.08, color='#756f6b', ls='--', dashes=(1.5, 1.5), alpha=0.4)
ax[0].axhline(y=5.34759e-41, xmin=0.25, xmax=0.29, color='#756f6b', ls='--', dashes=(1.5, 1.5), alpha=0.4)
ax[0].axhline(y=5.34759e-41, xmin=0.5, xmax=1, color='#756f6b', ls='--', dashes=(1.5, 1.5), alpha=0.4)

# vertical line
#ax[0].axhline(y=0.00411353, color = '#756f6b', ls=':')
ax[0].axvline(1e-03, ymin=0.6, ymax=1, color='#756f6b', ls='-', alpha=0.4)
ax[0].axvline(1e-03, ymin=0, ymax=0.4, color='#756f6b', ls='-', alpha=0.4)






ax[0].set_xlim(5e-38, 1e27) # apply the x-li4mits
ax[0].set_ylim(1e-43, 1e0)

ax[0].set_ylabel(r'$\Lambda_{3}\,[M_{\mathrm{Pl}}]$')#
ax[0].set_xlabel(r'$m\,\mathrm{[eV]}$')#

#ax[0].legend(frameon=False)

# dos

y = lambda x: x
y2 = lambda x: 1+x*0
x2 = lambda y: 0.2
rad = np.arange(0, 1, 0.001)
rad2 = np.arange(0, .2, 0.001)

ax[1].plot(rad, y2(rad), linewidth = 0.0001)
ax[1].plot(rad, y(rad), color='#756f6b', ls='-', alpha=0.4)#, linewidth = 0.0001
ax[1].plot(0.01*alb[:,0]+1, 0.01*alb[:,1], color ='#5f6769')

# Shade the area between y1 and line y=0
#ax[1].fill_between(rad, y(rad), 0,
#                 facecolor='#5aaadb', # The fill color
#                 color='#5aaadb',       # The outline color
#                 alpha=0.3)          # Transparency of the fill

ax[1].fill_between(0.01*alb[:,0]+1, 0.01*alb[:,1], 0,
                 facecolor="orange", # The fill color
                 color='#5f6769',       # The outline color
                 alpha=0.3
                ) 


ax[1].fill_between(rad, lm4(rad), 0,
                 facecolor="orange", # The fill color
                 color='#5aaadb',       # The outline color
                 alpha=0.3) 

#ax[1].fill_between(rad2, y(rad2), 1.3,
#                 facecolor="orange", # The fill color
#                 color='blue',       # The outline color
#                 alpha=0.1) 
ax[1].axvline(0.2, ymin=0.17, ymax=1.4, color='#756f6b', ls='-', alpha=0.4)

ax[1].axvspan(1, 1.3, alpha=0.3, color='#5f6769', linewidth = 0.0001, hatch='/')


ax[1].text(1.13, 0.4, r'unstable', {'color': '#5f6769', 'fontsize': 25},
            rotation=90, rotation_mode='anchor')
angle2 = 0

#ax[1].text(0.2, 0.7, r'stars', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')


#ax[1].text(0.6, 0.4, r'Horndeski', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')
#ax[1].text(0.78, 0.3, r'stars', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')

#ax[1].text(0.5, 1.05, r'BS', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')

#ax[1].text(0.15, 0.7, r'EKG', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')
ax[1].text(0.35, 0.7, r'EKG', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor') # 0.35, 0.7
#ax[1].text(0.22, 0.6, r'regime', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')
#angle2=90 0.15, 0.68
ax[1].text(0.06, 0.7, r'SP', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor')

angle2=0
ax[1].text(0.6, 0.33, r'strong', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor')
ax[1].text(0.57, 0.23, r'coupling', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor') # 0.6, 0.23
#ax[1].text(0.6, 0.15, r'regime', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')



#ax[1].text(0.45, 0.3, r'strong coupling', {'color': '#5f6769', 'fontsize': 28},
#            rotation=angle2, rotation_mode='anchor')
#ax[1].text(0.45, 0.2, r'regime', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')


#ax[1].text(0.55, 0.2, r'regime', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')

angle2=90
ax[0].text(5e-33, .5e-17, r'${\textit{H}_{0}}$', {'color': '#5f6769', 'fontsize': 16},
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim
ax[0].text(5e-33, 2e-13, r'cc problem', {'color': '#5f6769', 'fontsize': 16},
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim

ax[1].set_xlim(0, 1.2) # apply the x-li4mits
ax[1].set_ylim(0, 1.2)

ax[1].set_ylabel(r'$\Lambda_3^{3/2} M_{\mathrm{Pl}}^{-1/2} m^{-1}$')#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax[1].set_xlabel(r'$\sigma_{0}\,[M_{\mathrm{Pl}}]$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

ax[0].axvline(1e-33, ymin=0, ymax=0.585, color='#756f6b', ls='--', dashes=(1.5, 1.5), alpha=0.4)
ax[0].axvline(1e-33, ymin=0.665, ymax=0.69, color='#756f6b', ls='--', dashes=(1.5, 1.5), alpha=0.4)
ax[0].axvline(1e-33, ymin=0.96, ymax=1, color='#756f6b', ls='--', dashes=(1.5, 1.5), alpha=0.4)



#ax[1].legend(frameon=False)

# %%
rad = np.e**np.linspace(-85.4554, 63.0613, 100)

lam3 = lambda m: 5.53108e-19*np.power(m, 2/3) 
lam32 = lambda m: m/(2.431e27)
lm4 = lambda x: 1

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 5.5))

ax[0].loglog(rad, lam3(rad), linewidth = 0.0001)
ax[0].loglog(rad, lam32(rad), linewidth = 0.0001, color = '#5f6769')

# Shade the area between y1 and line y=0
ax[0].fill_between(rad, lam3(rad), lam32(rad),
                 facecolor='#5aaadb', # The fill color
                 color='#5aaadb',       # The outline color
                 alpha=0.3)          # Transparency of the fill

ax[0].fill_between(rad, lam32(rad), 0,
                 facecolor='#5f6769', # The fill color
                 color='#5f6769',       # The outline color
                 alpha=0.3)          # Transparency of the fill

angle2 = 0
ax[0].text(2e-32, 1e-31, r'$10^{-3}\,\mathrm{eV}$', {'color': '#5f6769', 'fontsize': 16},
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim

ax[0].text(8e-19, 2e-41, r'cc problem', {'color': '#1b4b57', 'fontsize': 16},
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim

ax[0].text(2e-32, 2e-41, r'$\left(M_{\mathrm{Pl}}{\textit{H}_{0}}^{2}\right)^{1/3}$', {'color': '#1b4b57', 'fontsize': 16},
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim



#ax[0].text(1e-30, 1e-8, r'Boson', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')
#ax[0].text(1e-30, 40e-13, r'stars', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')

#ax[0].text(1e-3, 1e-29, r'Horndeski', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')
#ax[0].text(1e7, 1e-33, r'stars', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')

ax[0].text(1e-27, 0.2e-19, r'BS', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor')

ax[0].text(1e-10, 1e-29, r'HS', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor')

ax[0].text(1e5, 1e-37, r'$m>\Lambda_{3}$', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor')

#ax[0].text(1e-35, 0.012, r'GUT', {'color': '#5f6769', 'fontsize': 16},
#            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim

angle2 = 90
ax[0].text(5e-03, 1e-25, r'$10^{-3}\,\mathrm{eV}$', {'color': '#5f6769', 'fontsize': 16},
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim
ax[0].text(5e-05, 5e-18, r'IR modification', {'color': '#5f6769', 'fontsize': 16},
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim
ax[0].text(5e-01, 5e-18, r'UV modification', {'color': '#5f6769', 'fontsize': 16},#
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim

#ax[0].text(5e-33, 1e-25, r'${\textit{H}_{0}}$', {'color': '#5f6769', 'fontsize': 16},
#            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim
#ax[0].text(8e-35, 5e-22, r'cc problem', {'color': '#5f6769', 'fontsize': 16},
#            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim






ax[0].axhline(y=4.11353e-31, xmin=0, xmax=0.08, color='#756f6b', ls='-', alpha=0.4)
ax[0].axhline(y=4.11353e-31, xmin=0.22, xmax=1, color='#756f6b', ls='-', alpha=0.4)


# linestyle='--', dashes=(5, 5)) #length of 5, space of 5
ax[0].axhline(y=5.34759e-41, xmin=0, xmax=0.08, color='#756f6b', ls='--', dashes=(1.5, 1.5), alpha=0.4)
ax[0].axhline(y=5.34759e-41, xmin=0.25, xmax=0.29, color='#756f6b', ls='--', dashes=(1.5, 1.5), alpha=0.4)
ax[0].axhline(y=5.34759e-41, xmin=0.5, xmax=1, color='#756f6b', ls='--', dashes=(1.5, 1.5), alpha=0.4)

# vertical line
#ax[0].axhline(y=0.00411353, color = '#756f6b', ls=':')
ax[0].axvline(1e-03, ymin=0.6, ymax=1, color='#756f6b', ls='-', alpha=0.4)
ax[0].axvline(1e-03, ymin=0, ymax=0.4, color='#756f6b', ls='-', alpha=0.4)






ax[0].set_xlim(5e-38, 1e27) # apply the x-li4mits
ax[0].set_ylim(1e-43, 1e0)

ax[0].set_ylabel(r'$\Lambda_{3}\,[M_{\mathrm{Pl}}]$')#
ax[0].set_xlabel(r'$m\,\mathrm{[eV]}$')#

#ax[0].legend(frameon=False)

# dos

y = lambda x: x
y2 = lambda x: 1+x*0
x2 = lambda y: 0.2
rad = np.arange(0, 1, 0.001)
rad1 = np.arange(0, .36, 0.001)
rad2 = np.arange(0.52, 0.53, 0.001)
rad3 = np.arange(0.64, 1., 0.001)

ax[1].plot(rad, y2(rad), linewidth = 0.0001)

ax[1].plot(rad1, y(rad1), color='#756f6b', ls='-', alpha=0.4)#, linewidth = 0.0001
ax[1].plot(rad2, y(rad2), color='#756f6b', ls='-', alpha=0.4)#, linewidth = 0.0001
ax[1].plot(rad3, y(rad3), color='#756f6b', ls='-', alpha=0.4)#, linewidth = 0.0001

ax[1].plot(0.01*alb[:,0]+1, 0.01*alb[:,1], color ='#5f6769')

# Shade the area between y1 and line y=0
#ax[1].fill_between(rad, y(rad), 0,
#                 facecolor='#5aaadb', # The fill color
#                 color='#5aaadb',       # The outline color
#                 alpha=0.3)          # Transparency of the fill

ax[1].fill_between(0.01*alb[:,0]+1, 0.01*alb[:,1], 0,
                 facecolor="orange", # The fill color
                 color='#5f6769',       # The outline color
                 alpha=0.3
                ) 


ax[1].fill_between(rad, lm4(rad), 0,
                 facecolor="orange", # The fill color
                 color='#5aaadb',       # The outline color
                 alpha=0.3) 

#ax[1].fill_between(rad2, y(rad2), 1.3,
#                 facecolor="orange", # The fill color
#                 color='blue',       # The outline color
#                 alpha=0.1) 
ax[1].axvline(0.2, ymin=0.17, ymax=1.4, color='#756f6b', ls='-', alpha=0.4)

ax[1].axvspan(1, 1.3, alpha=0.3, color='#5f6769', linewidth = 0.0001, hatch='/')


ax[1].text(1.13, 0.4, r'unstable', {'color': '#5f6769', 'fontsize': 25},
            rotation=90, rotation_mode='anchor')
angle2 = 0

#ax[1].text(0.2, 0.7, r'stars', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')


#ax[1].text(0.6, 0.4, r'Horndeski', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')
#ax[1].text(0.78, 0.3, r'stars', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')

#ax[1].text(0.5, 1.05, r'BS', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')

#ax[1].text(0.15, 0.7, r'EKG', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')
ax[1].text(0.35, .97, r'EKG', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor') # 0.35, 0.7
#ax[1].text(0.22, 0.6, r'regime', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')
#angle2=90 0.15, 0.68
ax[1].text(0.06, .97, r'SP', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor')

angle2=0
ax[1].text(0.6, 0.33, r'strong', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor')
ax[1].text(0.57, 0.23, r'coupling', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor') # 0.6, 0.23
#ax[1].text(0.6, 0.15, r'regime', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')

ax[1].text(0.38, 0.35, r'strong field', {'color': '#5f6769', 'fontsize': 30},
            rotation=36, rotation_mode='anchor')
 
ax[1].text(0.22, 0.7, r'weak', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor')
ax[1].text(0.22, 0.6, r'field', {'color': '#5f6769', 'fontsize': 30},
            rotation=angle2, rotation_mode='anchor')

#ax[1].text(0.45, 0.3, r'strong coupling', {'color': '#5f6769', 'fontsize': 28},
#            rotation=angle2, rotation_mode='anchor')
#ax[1].text(0.45, 0.2, r'regime', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')


#ax[1].text(0.55, 0.2, r'regime', {'color': '#5f6769', 'fontsize': 30},
#            rotation=angle2, rotation_mode='anchor')

angle2=90
ax[0].text(5e-33, .5e-17, r'${\textit{H}_{0}}$', {'color': '#5f6769', 'fontsize': 16},
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim
ax[0].text(5e-33, 2e-13, r'cc problem', {'color': '#5f6769', 'fontsize': 16},
            rotation=angle2, rotation_mode='anchor')#\Lambda_{3}\sim

ax[1].set_xlim(0, 1.2) # apply the x-li4mits
ax[1].set_ylim(0, 1.2)

ax[1].set_ylabel(r'$\Lambda_3^{3/2} M_{\mathrm{Pl}}^{-1/2} m^{-1}$')#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax[1].set_xlabel(r'$\sigma_{0}\,[M_{\mathrm{Pl}}]$')#(r'$\bar{r}\;\;[f_{a}\,m_{a}]$')

ax[0].axvline(1e-33, ymin=0, ymax=0.585, color='#756f6b', ls='--', dashes=(1.5, 1.5), alpha=0.4)
ax[0].axvline(1e-33, ymin=0.665, ymax=0.69, color='#756f6b', ls='--', dashes=(1.5, 1.5), alpha=0.4)
ax[0].axvline(1e-33, ymin=0.96, ymax=1, color='#756f6b', ls='--', dashes=(1.5, 1.5), alpha=0.4)

# %%
plt.savefig('Lim.pgf', 
            #This is simple recomendation for publication plots
            dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

#plt.savefig('rho_profile.pgf')
plt.savefig("Lim.png",dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

# %%
bs = np.loadtxt('Bs0035.dat', usecols=(0,1)) # dataphiKG
h = np.loadtxt('Horndeski0035.dat', usecols=(0,1)) # it is the same that dataH03A035
bh = np.loadtxt('BHorndeski0035.dat', usecols=(0,1)) # dataBHm03A035
dataphiKG = np.loadtxt('KGA035.dat', usecols=(0,1)) 
dataH03A035 = np.loadtxt('HX03A035.dat', usecols=(0,1))

phi0=0.0350000000000000033306690738755
# BS
f2 = lambda r: -0.0017411848367949876207167306797*r**2+phi0
f4 = lambda r: -0.0017411848367949876207167306797*r**2+0.0000496529190034140656460327126*r**4+phi0
f6 = lambda r: -0.0017411848367949876207167306797*r**2+0.0000496529190034140656460327126*r**4-8.2242400005940214174117601e-07*r**6+phi0
f8 = lambda r: -0.0017411848367949876207167306797*r**2+0.0000496529190034140656460327126*r**4-8.2242400005940214174117601e-07*r**6-4.1355008887520532054620e-10*r**8+phi0
f10 = lambda r:-0.0017411848367949876207167306797*r**2+0.0000496529190034140656460327126*r**4-8.2242400005940214174117601e-07*r**6-4.1355008887520532054620e-10*r**8+4.493907729002365001927e-10*r**10+phi0

# horndeski
fH2 = lambda r: -0.00195626*r**2+phi0
fH4 = lambda r: 0. - 0.00195626*r**2+0.0000708633*r**4+phi0
fH6 = lambda r: 0.-0.00195626*r**2+0.0000708633*r**4-2.00356e-06*r**6+phi0
fH8 = lambda r: 0. - 0.00195626*r**2 + 0.0000708633*r**4-2.00356e-06*r**6+4.74133e-08*r**8+phi0
fH10 = lambda r: 0.-0.00195626*r**2+0.0000708633*r**4-2.00356e-06*r**6+4.74133e-08*r**8-1.16984e-09*r**10+phi0

# Beyond
fBH2 = lambda r: -0.00230764*r**2 +phi0
fBH4 = lambda r: 0.-0.00230764*r**2+0.000115854*r**4+phi0
fBH6 = lambda r: 0.-0.00230764*r**2+0.000115854*r**4-5.90254e-06*r**6+phi0
fBH8 = lambda r: 0.-0.00230764*r**2+0.000115854*r**4-5.90254e-06*r**6+3.54426e-07*r**8+phi0
fBH10 = lambda r: 0.-0.00230764*r**2+0.000115854*r**4-5.90254e-06*r**6+3.54426e-07*r**8-2.59859e-08*r**10+phi0

# %%
# phi
rad = np.arange(0, 10, 0.1)

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 5.5))

ax[0].plot(dataphiKG[:,0], np.sqrt(8*np.pi)*dataphiKG[:,1], label='shooting', 
           linewidth='2.5', color = 'black') # (BS)

ax[0].plot(rad, np.sqrt(8*np.pi)*f2(rad), label=r' $\mathcal{O}(r^2)$', linestyle = '-', 
        linewidth='0.5')#,color = '#5079b9') # (O2)
ax[0].plot(rad, np.sqrt(8*np.pi)*f4(rad), label=r' $\mathcal{O}(r^4)$', linestyle = '-', 
           linewidth='0.5')#, color = '#5079b9') # (O5)
ax[0].plot(rad, np.sqrt(8*np.pi)*f6(rad), label=r' $\mathcal{O}(r^6)$', linestyle = '-', 
           linewidth='0.5')#, color = '#419ede') # (O6)
ax[0].plot(rad, np.sqrt(8*np.pi)*f8(rad), label=r' $\mathcal{O}(r^8)$', linestyle = '-', 
           linewidth='0.5')#, color = '#b45c1f') # (O8)
ax[0].plot(rad, np.sqrt(8*np.pi)*f10(rad), label=r' $\mathcal{O}(r^{10})$', linestyle = '-', 
           linewidth='0.5')#, color = '#de8241') # (O10)

ax[0].set_xlim(0, 10) # apply the x-li4mits
ax[0].set_ylim(0, np.sqrt(8*np.pi)*phi0+0.01)

ax[0].set_ylabel(r'$\sigma\;\,[M_{\mathrm{Pl}}]$')#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax[0].set_xlabel(r'$r\;[m^{-1}]$')#, fontsize=17

ax[0].legend(loc='upper right', frameon=False, title=r'$c_{4}^{(1)}=d_{4}^{(-1)}=0$')
#ax.legend(loc=(.72, .6),frameon=False);

ax[0].axvspan(1.605, 13, alpha=0.1, color='#5f6769') 
ax[0].axvspan(2.6, 13, alpha=0.1, color='#5f6769') 
ax[0].axvspan(3.79, 13, alpha=0.1, color='#5f6769')
ax[0].axvspan(3.83, 13, alpha=0.1, color='#5f6769')
ax[0].axvspan(4., 13, alpha=0.1, color='#5f6769') # , linewidth = 0.0001, hatch='/'

# %%
plt.savefig('orig2.pgf', 
            #This is simple recomendation for publication plots
            dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

#plt.savefig('rho_profile.pgf')
plt.savefig("orig2.png",dpi=1000, 
            # Plot will be occupy a maximum of available space
            bbox_inches='tight', 
            )

# %%
from scipy.interpolate import interp1d

rad=np.arange(1e-02,7,0.01)
KG = interp1d(dataphiKG[:,0], np.sqrt(8*np.pi)*dataphiKG[:,1], kind='cubic')
Num = interp1d(dataH03A035[:,0], np.sqrt(8*np.pi)*dataH03A035[:,1], kind='cubic')
#plt.plot(rad, KG(rad))

# %%
plt.plot(rad, np.abs((np.sqrt(8*np.pi)*f2(rad)-KG(rad)))/KG(rad)*100, label=r' $\mathcal{O}(r^2)$', linestyle = '-', 
        linewidth='0.5',color = '#5079b9') # (O2)
plt.plot(rad, np.abs((np.sqrt(8*np.pi)*f4(rad)-KG(rad)))/KG(rad)*100, label=r' $\mathcal{O}(r^4)$', linestyle = '-', 
           linewidth='0.5', color = '#5079b9')
plt.plot(rad, np.abs((np.sqrt(8*np.pi)*f6(rad)-KG(rad)))/KG(rad)*100, label=r' $\mathcal{O}(r^6)$', linestyle = '-', 
           linewidth='0.5', color = '#419ede') # (O6)
plt.plot(rad, np.abs((np.sqrt(8*np.pi)*f8(rad)-KG(rad)))/KG(rad)*100, label=r' $\mathcal{O}(r^8)$', linestyle = '-', 
           linewidth='0.5', color = '#b45c1f') # (O8)
plt.plot(rad, np.abs((np.sqrt(8*np.pi)*f10(rad)-KG(rad)))/KG(rad)*100, label=r' $\mathcal{O}(r^{10})$', linestyle = '-', 
           linewidth='0.5', color = '#de8241') # (O10)
plt.xlim(0,3.8)
plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
plt.plot(rad, np.abs((np.sqrt(8*np.pi)*fH2(rad)-Num(rad)))/Num(rad)*100, label=r'$\mathcal{O}(r^2)$', linestyle = '-', 
           linewidth='0.5', color = '#5079b9') # (O2)
plt.plot(rad, np.abs((np.sqrt(8*np.pi)*fH4(rad)-Num(rad)))/Num(rad)*100, label=r' $\mathcal{O}(r^4)$', linestyle = '-', 
           linewidth='0.5', color = '#5079b9') # (O5)
plt.plot(rad, np.abs((np.sqrt(8*np.pi)*fH6(rad)-Num(rad)))/Num(rad)*100, label=r' $\mathcal{O}(r^6)$', linestyle = '-', 
           linewidth='0.5', color = '#419ede') # (O6)
plt.plot(rad, np.abs((np.sqrt(8*np.pi)*fH8(rad)-Num(rad)))/Num(rad)*100, label=r' $\mathcal{O}(r^8)$', linestyle = '-', 
           linewidth='0.5', color = '#b45c1f') # (O8)
plt.plot(rad, np.abs((np.sqrt(8*np.pi)*fH10(rad)-Num(rad)))/Num(rad)*100, label=r' $\mathcal{O}(r^{10})$', linestyle = '-', 
           linewidth='0.5', color = '#de8241') # (O10)

plt.xlim(0,3.72)
plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
# phi
rad = np.arange(0, 10, 0.1)

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 5.5))

ax[0].plot(dataphiKG[:,0], np.sqrt(8*np.pi)*dataphiKG[:,1], label='$c_{4}^{(1)}=d_{4}^{(-1)}=0$', 
           color = '#566874') # (BS)

ax[0].plot(rad, np.sqrt(8*np.pi)*f2(rad), label=r'O(2)', linestyle = ':', color = '#5079b9') # (O2)
ax[0].plot(rad, np.sqrt(8*np.pi)*f4(rad), label=r'O(4)', linestyle = ':', color = '#5079b9') # (O5)
ax[0].plot(rad, np.sqrt(8*np.pi)*f6(rad), label=r'O(6)', linestyle = ':', color = '#419ede') # (O6)
ax[0].plot(rad, np.sqrt(8*np.pi)*f8(rad), label=r'O(8)', linestyle = ':', color = '#b45c1f') # (O8)
ax[0].plot(rad, np.sqrt(8*np.pi)*f10(rad), label=r'O(10)', linestyle = ':', color = '#de8241') # (O10)

ax[0].set_xlim(0, 10) # apply the x-li4mits
ax[0].set_ylim(0, np.sqrt(8*np.pi)*phi0+0.01)

ax[0].set_ylabel(r'$\sigma\;\,[M_{\mathrm{Pl}}]$')#(r'$\bar{\rho} \;\;[2\,f_{a}^{4}\,m_{a}^{2}\, M_{pl}^{2}]$')
ax[0].set_xlabel(r'$r\;[m^{-1}]$')#, fontsize=17

ax[0].legend(loc='upper right', frameon=False)
#ax.legend(loc=(.72, .6),frameon=False);


ax[1].plot(dataBH03A035[:,0], np.sqrt(8*np.pi)*dataBH03A035[:,1],
           label=r'$c_{4}^{(1)}=-1/2,\;d_{4}^{(-1)}=-1$', color = '#de8241') # (bHS)

ax[1].plot(rad, np.sqrt(8*np.pi)*fBH2(rad), label=r'O(2)', linestyle = ':', color = '#5079b9') # (O2)
ax[1].plot(rad, np.sqrt(8*np.pi)*fBH4(rad), label=r'O(4)', linestyle = ':', color = '#5079b9') # (O5)
ax[1].plot(rad, np.sqrt(8*np.pi)*fBH6(rad), label=r'O(6)', linestyle = ':', color = '#419ede') # (O6)
ax[1].plot(rad, np.sqrt(8*np.pi)*fBH8(rad), label=r'O(8)', linestyle = ':', color = '#b45c1f') # (O8)
ax[1].plot(rad, np.sqrt(8*np.pi)*fBH10(rad), label=r'O(10)', linestyle = ':', color = '#de8241') # (O10)


ax[1].set_xlim(0, 10) # apply the x-li4mits
ax[1].set_ylim(0, np.sqrt(8*np.pi)*phi0+0.01)

ax[1].set_ylabel(r'$\sigma\;\,[M_{\mathrm{Pl}}]$')# , fontsize=17
ax[1].set_xlabel(r'$r\;[m^{-1}]$')# , fontsize=17

#matplotlib.rcParams['legend.fontsize'] = 25
#ax.legend(('Numerical solution', 'Analytical fitting'),loc='upper right',frameon=False)
ax[1].legend(loc='center right',frameon=False) # loc=(0.41, 0.001)
